# %% [markdown]
# ## DUPLICATES
#
# (https://www.clrn.org/how-to-handle-duplicate-data-in-machine-learning/)
#
# From the first analysis:
#
# - development set
#   - duplicate rows: 1559
#   - NaN article col: 1875
# - evaluation set
#   - dupliacte rows: 96
#   - NaN article col: 449

# %%
from src.preprocessing import Preprocessor, initial_prep
from src.config import *
from src.preprocessing import *
from src.utils import load_data
import matplotlib.pyplot as plt

df = load_data(DEVELOPMENT_PATH)
df = initial_prep(df)

# %%
df['title'] = Preprocessor.clean_text(df['title'])
df['article'] = Preprocessor.clean_text(df['article'])
df.loc[df['article'].str.len() < 5, "article"] = pd.NA

# Timestamp formatting
ts = df["timestamp"].replace("0000-00-00 00:00:00", pd.NA)
ts = pd.to_datetime(ts, errors="coerce")  # invalid -> NaT
df["timestamp"] = ts

# DUPLICATES

# If all cols match and also the target => keep only one row
df.drop_duplicates(inplace=True)

# If all cols match but NOT the target => drop all rows
df.drop_duplicates(subset=['source', 'title', 'article', 'page_rank', 'timestamp'], keep=False, inplace=True)

# If title, article, source, page_rank match but NOT timestamp => keep only one row with y=majority_voting and timestamp the first/not null
for a, g in df[df.duplicated(subset=['source', 'title', 'article', 'page_rank'], keep=False)].sort_values(['title', 'timestamp']).groupby(['source', 'title', 'article', 'page_rank']):
    y = g['y'].value_counts().index[0]
    timestamp = g[g['y']==y]['timestamp'].min()
    df.loc[g.index[0], 'y'] = y
    df.loc[g.index[0], 'timestamp'] = timestamp
    df.drop(index=g.index[1:], inplace=True)

# %%
df
# Out:
#                  source                                              title  \
# Id
# 0         AllAfrica.com      opec boosts nigeria's oil revenue by .82m bpd
# 1                Xinhua  yearender: mideast peace roadmap reaches dead-...
# 2                 Yahoo  battleground dispatches for oct. 5 \ (cqpoliti...
# 3                   BBC                   air best to resuscitate newborns
# 4                 Yahoo  high tech german train crash kills at least on...
# ...                 ...                                                ...
# 79992             Yahoo  italy's embattled prodi faces vote of confiden...
# 79993  All-Baseball.com                        ding dong, the deal is dead
# 79994             Yahoo  two bombs discovered in sardinia after berlusc...
# 79995             Voice  red cross report alleges us detainee abuse at ...
# 79996             Yahoo    un: myanmar allows early visit by envoy \ (ap)\
#
#                                                  article  page_rank  \
# Id
# 0      the organisation of petroleum exporting countr...          5
# 1      looking back at the major events that took pla...          5
# 2      cqpolitics.com - here are today's battleground...          5
# 3      air rather than oxygen should be used to resus...          5
# 4      <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
# ...                                                  ...        ...
# 79992  <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
# 79993  as yesterday began, there was widespread antic...          5
# 79994  afp - police discovered two bombs near the sar...          5
# 79995  a report by the international committee of the...          5
# 79996  <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
#
#                 timestamp  y
# Id
# 0     2004-09-16 22:39:53  5
# 1     2004-12-17 19:01:14  0
# 2     2006-10-05 18:42:29  0
# 3                     NaT  0
# 4     2006-09-22 17:28:57  0
# ...                   ... ..
# 79992 2008-01-23 11:39:35  0
# 79993                 NaT  4
# 79994                 NaT  0
# 79995                 NaT  3
# 79996 2007-10-24 17:15:44  0
#
# [78697 rows x 6 columns]

# %%
for a, g in df[df.duplicated(subset=['source', 'title', 'article', 'timestamp'], keep=False)].groupby(['source', 'title', 'article', 'timestamp']):
    print(g)

# %%
news_df
# Out:
#               source                                              title  \
# Id
# 0      AllAfrica.com      opec boosts nigeria's oil revenue by .82m bpd
# 1             Xinhua  yearender: mideast peace roadmap reaches dead-...
# 2              Yahoo  battleground dispatches for oct. 5 \ (cqpoliti...
# 3                BBC                   air best to resuscitate newborns
# 4              Yahoo  high tech german train crash kills at least on...
# ...              ...                                                ...
# 79991        RedNova                leds move into home lighting market
# 79992          Yahoo  italy's embattled prodi faces vote of confiden...
# 79994          Yahoo  two bombs discovered in sardinia after berlusc...
# 79995          Voice  red cross report alleges us detainee abuse at ...
# 79996          Yahoo    un: myanmar allows early visit by envoy \ (ap)\
#
#                                                  article  page_rank  \
# Id
# 0      the organisation of petroleum exporting countr...          5
# 1      looking back at the major events that took pla...          5
# 2      cqpolitics.com - here are today's battleground...          5
# 3      air rather than oxygen should be used to resus...          5
# 4      <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
# ...                                                  ...        ...
# 79991  by mark jewell everett, mass. - joey nicotera'...          4
# 79992  <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
# 79994  afp - police discovered two bombs near the sar...          5
# 79995  a report by the international committee of the...          5
# 79996  <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
#
#                 timestamp  y
# Id
# 0     2004-09-16 22:39:53  5
# 1     2004-12-17 19:01:14  0
# 2     2006-10-05 18:42:29  0
# 3                     NaT  0
# 4     2006-09-22 17:28:57  0
# ...                   ... ..
# 79991 2007-06-25 07:08:21  2
# 79992 2008-01-23 11:39:35  0
# 79994                 NaT  0
# 79995                 NaT  3
# 79996 2007-10-24 17:15:44  0
#
# [76652 rows x 6 columns]

# %%
news_df.drop_duplicates(inplace=True)

# %%
news_df
# Out:
#                  source                                              title  \
# Id
# 0         AllAfrica.com      opec boosts nigeria's oil revenue by .82m bpd
# 1                Xinhua  yearender: mideast peace roadmap reaches dead-...
# 2                 Yahoo  battleground dispatches for oct. 5 \ (cqpoliti...
# 3                   BBC                   air best to resuscitate newborns
# 4                 Yahoo  high tech german train crash kills at least on...
# ...                 ...                                                ...
# 79992             Yahoo  italy's embattled prodi faces vote of confiden...
# 79993  All-Baseball.com                        ding dong, the deal is dead
# 79994             Yahoo  two bombs discovered in sardinia after berlusc...
# 79995             Voice  red cross report alleges us detainee abuse at ...
# 79996             Yahoo    un: myanmar allows early visit by envoy \ (ap)\
#
#                                                  article  page_rank  \
# Id
# 0      the organisation of petroleum exporting countr...          5
# 1      looking back at the major events that took pla...          5
# 2      cqpolitics.com - here are today's battleground...          5
# 3      air rather than oxygen should be used to resus...          5
# 4      <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
# ...                                                  ...        ...
# 79992  <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
# 79993  as yesterday began, there was widespread antic...          5
# 79994  afp - police discovered two bombs near the sar...          5
# 79995  a report by the international committee of the...          5
# 79996  <p><a href="http://us.rd.yahoo.com/dailynews/r...          5
#
#                  timestamp  y
# Id
# 0      2004-09-16 22:39:53  5
# 1      2004-12-17 19:01:14  0
# 2      2006-10-05 18:42:29  0
# 3      0000-00-00 00:00:00  0
# 4      2006-09-22 17:28:57  0
# ...                    ... ..
# 79992  2008-01-23 11:39:35  0
# 79993  0000-00-00 00:00:00  4
# 79994  0000-00-00 00:00:00  0
# 79995  0000-00-00 00:00:00  3
# 79996  2007-10-24 17:15:44  0
#
# [79661 rows x 6 columns]

# %%
for a,g in news_df[news_df.drop(columns='y').duplicated(keep=False)].groupby(['source', 'title', 'article', 'page_rank', 'timestamp']):
    if len(g) != 2:
        print(len(g))
        print(g['y'])
# Out:
# 3
# Id
# 8076     0
# 28144    1
# 78809    5
# Name: y, dtype: int64
# 3
# Id
# 23106    5
# 52194    4
# 65990    3
# Name: y, dtype: int64
# 3
# Id
# 15708    3
# 18532    5
# 51791    2
# Name: y, dtype: int64
# 3
# Id
# 25516    2
# 28103    5
# 72653    3
# Name: y, dtype: int64
# 3
# Id
# 12505    5
# 29696    2
# 64346    3
# Name: y, dtype: int64
# 3
# Id
# 4315     0
# 28835    3
# 34474    5
# Name: y, dtype: int64

# %%
news_df.drop_duplicates(subset=['source', 'title', 'article', 'page_rank', 'timestamp'], keep=False, inplace=True)
news_df.shape
# Out:
# (78697, 6)

# %%
news_df.isna().sum()
# Out:
# source        294
# title           1
# article      1880
# page_rank       0
# timestamp       0
# y               0
# dtype: int64

# %% [markdown]
# ---
#
# Deduplication rules.
# Records are grouped at content level using (article, title).
#
# - (article, title) with different target labels (y) → drop entire cluster
# - (article, title, y) identical → collapse records into a single instance, aggregating metadata as follows:
#   - source → unique non-null list of sources
#   -  page_rank → median value across observations
#   -  timestamp → single representative value earliest
#
# This procedure removes spurious duplicates while preserving informative metadata variability.

# %%
df[df.duplicated(subset=['page_rank', 'title', 'article', 'timestamp'], keep=False)]
# Out:
#                 source                                              title  \
# Id
# 1061           Ananova                     adv: advance your career today
# 2323   Telegraph.co.uk            brussels lets big spenders off the hook
# 3108        Washington          adv: free 4-room digital satellite system
# 4607               BBC                   world 'ignoring' war torn darfur
# 7394               BCC                    wireless net to get speed boost
# 9178         Topix.Net            brussels lets big spenders off the hook
# 9582           Calgary  goosen fires 64 to edge woods at tour champion...
# 10352           Boston                        bonds hits home run no. 700
# 11838         National  iraq car bomb kills 8 us marines in deadliest ...
# 14395              BCC                  pay-as-you-drive car cover tested
# 15026              BBC                    wireless net to get speed boost
# 15202         Newsweek   adv: trade shares and currencies commission-free
# 15569           Forbes                            adv: give bush the boot
# 15664              CNN                     adv: advance your career today
# 20472       Washington   adv: trade shares and currencies commission-free
# 26151           Sunday  disney pay-off case sets a precedent for us firms
# 28995       Canada.com  iraq car bomb kills 8 us marines in deadliest ...
# 29090              BBC                   mobile phone sales grow strongly
# 29996             WPBF      allawi's female relatives released by captors
# 30172              NaN                   world 'ignoring' war torn darfur
# 31228       Washington                     adv: advance your career today
# 32384              BBC                     real in online music price war
# 35091              CNN          adv: free 4-room digital satellite system
# 35371              CNN                            adv: give bush the boot
# 38729              NaN                     adv: advance your career today
# 52995       Canada.com  goosen fires 64 to edge woods at tour champion...
# 53418       Washington                   adv: distance learning directory
# 53496              BCC                     real in online music price war
# 54059              BBC                  pay-as-you-drive car cover tested
# 55856           Forbes                   adv: distance learning directory
# 61755              BBC                  microsoft makes mobile media push
# 62918              BCC                  microsoft makes mobile media push
# 63649           Boston  the past costs backman his job, only four days...
# 65895            Times  disney pay-off case sets a precedent for us firms
# 72204              BCC                   mobile phone sales grow strongly
# 73982              BCC                  google warns sales growth to slow
# 74750              New                        bonds hits home run no. 700
# 76634              NaN  the past costs backman his job, only four days...
# 78833         Carolina      allawi's female relatives released by captors
# 79067              BBC                  google warns sales growth to slow
#
#                                                  article  page_rank timestamp  \
# Id
# 1061   increase your earning potential with an accred...          5       NaT
# 2323   the european commission yesterday abandoned ef...          5       NaT
# 3108   free installation for your free system in up t...          5       NaT
# 4607   the world has shown "callous disregard" for th...          5       NaT
# 7394   wireless computer networks could soon be runni...          5       NaT
# 9178   the european commission yesterday abandoned ef...          5       NaT
# 9582   atlanta (cp) - a dreadful front nine sunday le...          5       NaT
# 10352  barry bonds hit his 700th home run friday nigh...          5       NaT
# 11838  a car bomb killed eight us marines outside fal...          5       NaT
# 14395  a uk insurer is fitting mobile technology to s...          5       NaT
# 15026  wireless computer networks could soon be runni...          5       NaT
# 15202  gci offers commission-free online trading in s...          5       NaT
# 15569  help take back america! donate $50 to moveon p...          5       NaT
# 15664  increase your earning potential with an accred...          5       NaT
# 20472  gci offers commission-free online trading in s...          5       NaT
# 26151  there was room for only 50 people in the tiny ...          5       NaT
# 28995  a car bomb killed eight us marines outside fal...          5       NaT
# 29090  global mobile phone sales grew 35% to over 150...          5       NaT
# 29996  allawi's office confirms that his cousin's wif...          5       NaT
# 30172  the world has shown "callous disregard" for th...          5       NaT
# 31228  increase your earning potential with an accred...          5       NaT
# 32384  realnetworks halves the price of music downloa...          5       NaT
# 35091  free installation for your free system in up t...          5       NaT
# 35371  help take back america! donate $50 to moveon p...          5       NaT
# 38729  increase your earning potential with an accred...          5       NaT
# 52995  atlanta (cp) - a dreadful front nine sunday le...          5       NaT
# 53418  bachelor, master and post-grad degrees online ...          5       NaT
# 53496  realnetworks halves the price of music downloa...          5       NaT
# 54059  a uk insurer is fitting mobile technology to s...          5       NaT
# 55856  bachelor, master and post-grad degrees online ...          5       NaT
# 61755  microsoft has unveiled a series of handheld ga...          5       NaT
# 62918  microsoft has unveiled a series of handheld ga...          5       NaT
# 63649  the arizona diamondbacks fired new manager wal...          5       NaT
# 65895  there was room for only 50 people in the tiny ...          5       NaT
# 72204  global mobile phone sales grew 35% to over 150...          5       NaT
# 73982  google, the world's most-used internet search ...          5       NaT
# 74750  barry bonds hit his 700th home run friday nigh...          5       NaT
# 76634  the arizona diamondbacks fired new manager wal...          5       NaT
# 78833  allawi's office confirms that his cousin's wif...          5       NaT
# 79067  google, the world's most-used internet search ...          5       NaT
#
#        y
# Id
# 1061   1
# 2323   1
# 3108   5
# 4607   5
# 7394   2
# 9178   0
# 9582   3
# 10352  4
# 11838  3
# 14395  2
# 15026  0
# 15202  5
# 15569  1
# 15664  5
# 20472  5
# 26151  1
# 28995  5
# 29090  1
# 29996  0
# 30172  0
# 31228  5
# 32384  5
# 35091  5
# 35371  5
# 38729  5
# 52995  4
# 53418  5
# 53496  2
# 54059  5
# 55856  1
# 61755  5
# 62918  2
# 63649  4
# 65895  1
# 72204  2
# 73982  2
# 74750  0
# 76634  4
# 78833  0
# 79067  0

# %%
news_df = news_df.sort_values(['title', 'timestamp']).drop_duplicates(subset=['source', 'title', 'article', 'page_rank', 'y'], keep='first')

# %%
news_df[news_df.duplicated(subset=['source', 'title', 'article', 'timestamp',], keep=False)]
# Out:
#         source                                    title  \
# Id
# 22505  RedNova  'high street' sign is among most stolen
#
#                                                  article  page_rank timestamp  \
# Id
# 22505  eugene, ore. - the signs marking high street h...          4       NaT
#
#        y
# Id
# 22505  3
