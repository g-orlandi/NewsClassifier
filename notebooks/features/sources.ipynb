# %%
import pandas as pd 
from src.config import *

news_df = pd.read_csv(DEVELOPMENT_PATH, index_col=0, na_values=NAN_PATTERNS)

# %%
print(news_df['source'].nunique())
print(news_df['source'].value_counts(True))
# Out:
# 1358
# source
# Yahoo              0.198863
# Reuters            0.149492
# BBC                0.100009
# New                0.080675
# Washington         0.042445
#                      ...
# just-food.com      0.000013
# Skipressworld      0.000013
# Destination        0.000013
# SaddoBoxing.com    0.000013
# Kinston            0.000013
# Name: proportion, Length: 1358, dtype: float64

# %%
for label in sorted(news_df['label'].unique()):
    sub_news_df = news_df[news_df['label'] == label]
    print('='*30)
    print(label)
    print(sub_news_df['source'].value_counts(True)[:10])
    print('='*30)
# Out:
# ==============================
# 0
# source
# Yahoo         0.359309
# BBC           0.187716
# Reuters       0.135082
# Topix.Net     0.056771
# New           0.049648
# Washington    0.035530
# RedNova       0.023033
# Boston        0.018255
# CSMonitor     0.013094
# Time          0.010450
# Name: proportion, dtype: float64
# ==============================
# ==============================
# 1
# source
# Reuters          0.220703
# New              0.129725
# Yahoo            0.089934
# Motley           0.085565
# International    0.052422
# Forbes           0.051377
# Washington       0.047863
# BBC              0.044444
# Boston           0.044065
# Ananova          0.029155
# Name: proportion, dtype: float64
# ==============================
# ==============================
# 2
# source
# RedNova          0.176232
# Yahoo            0.165167
# CNET             0.119288
# New              0.083303
# Register         0.074037
# Computerworld    0.041562
# InfoWorld        0.038053
# PCWorld          0.036794
# Wired            0.031396
# Reuters          0.031036
# Name: proportion, dtype: float64
# ==============================
# ==============================
# 3
# source
# Yahoo         0.223495
# Reuters       0.128831
# New           0.124008
# BBC           0.040599
# Syfy.com      0.028238
# RedNova       0.020299
# Rediff        0.018089
# ABC           0.017486
# Washington    0.016983
# Xinhua        0.012662
# Name: proportion, dtype: float64
# ==============================
# ==============================
# 4
# source
# Yahoo         0.207324
# New           0.127062
# Reuters       0.110565
# Washington    0.097110
# Boston        0.084942
# San           0.030069
# ESPN          0.012753
# Sports        0.012519
# CNN/SI        0.009945
# ABC           0.009828
# Name: proportion, dtype: float64
# ==============================
# ==============================
# 5
# source
# Reuters       0.245390
# BBC           0.170559
# CNN           0.117240
# Guardian      0.056469
# Washington    0.046328
# News          0.030347
# Time          0.027581
# New           0.015366
# Newsweek      0.013061
# ABC           0.011294
# Name: proportion, dtype: float64
# ==============================
# ==============================
# 6
# source
# Reuters       0.212395
# Yahoo         0.203357
# New           0.146546
# BBC           0.070691
# Washington    0.060039
# Forbes        0.011943
# Medical       0.007747
# ABC           0.006779
# Seattle       0.006779
# Newsday       0.006779
# Name: proportion, dtype: float64
# ==============================

# %%
news_df["source"].value_counts(True)[:50].sum()
# Out:
# np.float64(0.8685745831399069)
