# %%
from src.config import *
from src.preprocessing import *
from src.utils import load_data
import matplotlib.pyplot as plt

prep = Preprocessor()

# %%
news_df = load_data('../'+DEVELOPMENT_PATH)
X = news_df.drop(columns='y')
X_prep, idxs = prep.fit_transform(X.copy())

# %%
X_prep
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 816301 stored elements and shape (79996, 6335)>

# %%
import pandas as pd
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import csr_matrix, hstack

from src.config import *


class Preprocessor2:
    
    def __init__(self):
        self.df = None
        self.is_fit = False
        self.vectorizer = None
        self.ohe = None
        self.top_50 = None
        self.title_cols_to_keep_idxs = []

    def timestamp_management(self):
        # 1) Parse timestamp: treat invalid placeholders as missing (NaT)
        ts = self.df["timestamp"].replace("0000-00-00 00:00:00", pd.NA)
        ts = pd.to_datetime(ts, errors="coerce")  # invalid -> NaT
        self.df["timestamp"] = ts

        # 2) Missingness flag (important!)
        self.df["timestamp_missing"] = self.df["timestamp"].isna().astype(int)

        # 3) Create time features ONLY where timestamp is valid
        valid = self.df["timestamp"].notna()

        # is_weekend: keep as 0/1; set to 0 for missing (or leave NaN if you prefer)
        self.df["is_weekend"] = 0
        self.df.loc[valid, "is_weekend"] = (
            self.df.loc[valid, "timestamp"].dt.day_of_week.isin([5, 6]).astype(int)
        )

        # hour sin/cos
        self.df["hour_sin"] = 0.0
        self.df["hour_cos"] = 0.0
        h = self.df.loc[valid, "timestamp"].dt.hour.astype(float)
        self.df.loc[valid, "hour_sin"] = np.sin(2 * np.pi * h / 24)
        self.df.loc[valid, "hour_cos"] = np.cos(2 * np.pi * h / 24)

        # month sin/cos
        self.df["month_sin"] = 0.0
        self.df["month_cos"] = 0.0
        m = self.df.loc[valid, "timestamp"].dt.month.astype(float)
        self.df.loc[valid, "month_sin"] = np.sin(2 * np.pi * m / 12)
        self.df.loc[valid, "month_cos"] = np.cos(2 * np.pi * m / 12)

        # year (numeric): set to -1 for missing (or keep NaN)
        self.df["year"] = -1
        self.df.loc[valid, "year"] = self.df.loc[valid, "timestamp"].dt.year.astype(int)

    def pagerank_manegement(self):
        self.df['page_rank'] = self.df['page_rank'].map({2:0, 3:0, 4:1, 5:2})

    def na_management(self): 
        null_title_idx = self.df[self.df['title'].isna()].index 
        self.df.drop(null_title_idx, inplace=True)
        
    def title_management(self):
        if self.is_fit:
            self.vectorizer = TfidfVectorizer(stop_words="english", min_df=10, ngram_range=(1,3), sublinear_tf=True)
            tfidf_matrix = self.vectorizer.fit_transform(self.df["title"].fillna(""))
            pattern = r"^\d+$"
            feat = self.vectorizer.get_feature_names_out()
            matches = [m[0] for w in feat if (m := re.findall(pattern, w))]
            title_cols_to_drop = [c for c in feat if len(c) <= 2] + matches    
            self.title_cols_to_keep_idxs = [i for i,c in enumerate(feat) if c not in title_cols_to_drop]

        else:
            tfidf_matrix = self.vectorizer.transform(self.df["title"].fillna(""))

        tfidf_matrix = tfidf_matrix[:, self.title_cols_to_keep_idxs]
        return tfidf_matrix,  [f for f in feat if f not in title_cols_to_drop]

    def source_management(self):
        df = self.df["source"].fillna("MISSING")

        if self.is_fit:
            self.top_50 = df.value_counts()[:50].index.to_list()
            self.ohe = OneHotEncoder(categories=[self.top_50], handle_unknown="ignore", sparse_output=True)
            X = df.where(df.isin(self.top_50), np.nan).to_frame()
            X_ohe = self.ohe.fit_transform(X)
        else:
            X = df.where(df.isin(self.top_50), np.nan).to_frame()
            X_ohe = self.ohe.transform(X)
        
        return X_ohe

    def full_prep(self,df):
        self.df = df
        self.na_management()
        self.timestamp_management()
        X_ohe = self.source_management()
        tfidf_matrix = self.title_management()
        output = self.df.copy()
        idxs = output.index
        self.df = None


        output.drop(columns=COLUMNS_TO_DROP, inplace=True, errors='ignore')
        output = csr_matrix(output.to_numpy(dtype=np.float32))
        X = hstack([tfidf_matrix, X_ohe, output], format="csr")
        return X, idxs


    def fit_transform(self, df):
        self.is_fit = True
        return self.full_prep(df)

    def transform(self, df):
        if self.vectorizer is None or self.ohe is None or self.top_50 is None:
            raise RuntimeError("Preprocessor.fit_transform called before fit.")
        
        self.is_fit = False
        return self.full_prep(df)

# %%
prep2 = Preprocessor2()
prep2.is_fit = True

prep2.df = news_df
prep2.na_management()
prep2.timestamp_management()
tfidf_matrix, feat = prep2.title_management()
# output = prep2.df.copy()
# idxs = output.index

# %%
row = tfidf_matrix[0]
nonzero_idxs = row.nonzero()[1]

tokens = np.array(feat)[nonzero_idxs]
values = row.data

pd.Series(values, index=tokens).sort_values(ascending=False)
# Out:
# revenue    0.473376
# nigeria    0.457874
# opec       0.453730
# boosts     0.446236
# oil        0.321272
# dtype: float64

# %%
news_df.loc[0, 'title']
# Out:
# 'OPEC Boosts Nigeria&#39;s Oil Revenue By .82m Bpd'

# %%
feat
# Out:
# ['000 jobs',
#  '000 mortgage',
#  '000 mortgage 690',
#  '000 mortgage 730',
#  '10 000',
#  '10 killed',
#  '10 million',
#  '10 percent',
#  '10 year',
#  '10 years',
#  '100 000',
#  '100 million',
#  '100m',
#  '10th',
#  '11th',
#  '12 000',
#  '12 percent',
#  '12th',
#  '13th',
#  '14 ap',
#  '15 years',
#  '150 000',
#  '150 000 mortgage',
#  '175 000',
#  '175 000 mortgage',
#  '1bn',
#  '1st',
#  '20 years',
#  '2008 race',
#  '24 hours',
#  '25 million',
#  '25 percent',
#  '25 years',
#  '2nd',
#  '30 days',
#  '30 year',
#  '36 billion',
#  '36 million',
#  '39 39',
#  '39 afp',
#  '39 best',
#  '39 bid',
#  '39 big',
#  '39 death',
#  '39 end',
#  '39 future',
#  '39 health',
#  '39 husband',
#  '39 iraq',
#  '39 latest',
#  '39 law',
#  '39 life',
#  '39 ll',
#  '39 moon',
#  '39 neal',
#  '39 new',
#  '39 nuclear',
#  '39 plan',
#  '39 return',
#  '39 shark',
#  '39 star',
#  '39 win',
#  '3bn',
#  '3q profit',
#  '3rd',
#  '3rd quarter',
#  '49ers',
#  '4th',
#  '50 barrel',
#  '500 000',
#  '500 jobs',
#  '5th',
#  '690 month',
#  '6th',
#  '70 000',
#  '730 month',
#  '76ers',
#  'a380',
#  'abandoned',
#  'abbas',
#  'abbey',
#  'abc',
#  'abducted',
#  'abduction',
#  'abe',
#  'able',
#  'abn',
#  'aborigines',
#  'abortion',
#  'abroad',
#  'absence',
#  'abu',
#  'abu ghraib',
#  'abuse',
#  'abuses',
#  'academy',
#  'acc',
#  'accept',
#  'accepts',
#  'access',
#  'accident',
#  'accord',
#  'account',
#  'accounting',
#  'accounts',
#  'accusations',
#  'accused',
#  'accuser',
#  'accuses',
#  'ace',
#  'aceh',
#  'acer',
#  'acid',
#  'acknowledges',
#  'acquire',
#  'acquires',
#  'acquisition',
#  'acquisitions',
#  'acquitted',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activate',
#  'active',
#  'activist',
#  'activists',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'acupuncture',
#  'ad ap',
#  'adams',
#  'add',
#  'added',
#  'addiction',
#  'addicts',
#  'adding',
#  'additional',
#  'address',
#  'addresses',
#  'adds',
#  'administration',
#  'admit',
#  'admits',
#  'adobe',
#  'adopt',
#  'adoption',
#  'adopts',
#  'ads',
#  'ads ap',
#  'adult',
#  'adultery',
#  'adults',
#  'adv',
#  'adv 150',
#  'adv 150 000',
#  'adv 175',
#  'adv 175 000',
#  'adv distance',
#  'adv distance learning',
#  'adv free',
#  'adv free career',
#  'adv health',
#  'adv health insurance',
#  'adv refinance',
#  'adv refinance rates',
#  'adv trade',
#  'adv trade shares',
#  'adv try',
#  'adv try currency',
#  'advance',
#  'advanced',
#  'advances',
#  'advantage',
#  'advertisers',
#  'advertising',
#  'advice',
#  'adviser',
#  'advisers',
#  'adweek',
#  'adweek com',
#  'affair',
#  'affect',
#  'affected',
#  'affects',
#  'afghan',
#  'afghan election',
#  'afghan president',
#  'afghan vote',
#  'afghanistan',
#  'afghanistan afp',
#  'afghanistan ap',
#  'afghans',
#  'afp',
#  'africa',
#  'african',
#  'african union',
#  'aftershocks',
#  'agassi',
#  'age',
#  'aged',
#  'agencies',
#  'agency',
#  'agency ap',
#  'agenda',
#  'agent',
#  'agents',
#  'aging',
#  'ago',
#  'agree',
#  'agreed',
#  'agreement',
#  'agreement reached',
#  'agrees',
#  'agriculture',
#  'ahead',
#  'ahmadinejad',
#  'aid',
#  'aid ap',
#  'aid worker',
#  'aid workers',
#  'aide',
#  'aide says',
#  'aides',
#  'aiding',
#  'aids',
#  'aids day',
#  'aids drug',
#  'aig',
#  'ailing',
#  'aim',
#  'aimed',
#  'aiming',
#  'aims',
#  'air',
#  'air crash',
#  'air force',
#  'air france',
#  'air raid',
#  'air strike',
#  'air strike kills',
#  'air strikes',
#  'airbus',
#  'aircraft',
#  'aires',
#  'airline',
#  'airlines',
#  'airport',
#  'airports',
#  'airs',
#  'airstrike',
#  'airwaves',
#  'airways',
#  'al jazeera',
#  'al qaeda',
#  'al qaida',
#  'al sadr',
#  'al wrap',
#  'al zarqawi',
#  'alabama',
#  'alarm',
#  'alaska',
#  'album',
#  'alcan',
#  'alcatel',
#  'alcoa',
#  'alcohol',
#  'alert',
#  'alexander',
#  'algeria',
#  'ali',
#  'alitalia',
#  'alive',
#  'allawi',
#  'allegations',
#  'alleged',
#  'allegedly',
#  'alleges',
#  'allen',
#  'allergy',
#  'alliance',
#  'allies',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'ally',
#  'alonso',
#  'alpine',
#  'alternative',
#  'altria',
#  'alzheimer',
#  'alzheimer 39',
#  'amazing',
#  'amazon',
#  'amazon com',
#  'ambassador',
#  'ambitious',
#  'ambulance',
#  'ambush',
#  'amd',
#  'amendment',
#  'america',
#  'american',
#  'american idol',
#  'americans',
#  'americas',
#  'amid',
#  'amish',
#  'amnesty',
#  'amp',
#  'amy',
#  'analysis',
#  'analyst',
#  'analysts',
#  'anbar',
#  'anc',
#  'anchor',
#  'ancient',
#  'anderson',
#  'andreas',
#  'angeles',
#  'angels',
#  'anger',
#  'angers',
#  'anglican',
#  'angry',
#  'anheuser',
#  'animal',
#  'animals',
#  'animated',
#  'ankle',
#  'anna',
#  'anna nicole',
#  'anna nicole smith',
#  'annan',
#  'anniversary',
#  'announce',
#  'announced',
#  'announces',
#  'announces new',
#  'annual',
#  'answer',
#  'answers',
#  'anthony',
#  'anthrax',
#  'anti',
#  'anti bush',
#  'anti gay',
#  'anti kerry',
#  'anti missile',
#  'anti piracy',
#  'anti terror',
#  'anti terrorism',
#  'antidepressant',
#  'antidepressants',
#  'antitrust',
#  'anwar',
#  'aol',
#  'ap poll',
#  'apart',
#  'apartment',
#  'apec',
#  'apologize',
#  'apologizes',
#  'apology',
#  'app',
#  'apparent',
#  'appeal',
#  'appeals',
#  'appeals court',
#  'appear',
#  'appearance',
#  'appears',
#  'apple',
#  'apple 39',
#  'apple iphone',
#  'application',
#  'applications',
#  'appoints',
#  'apprentice',
#  'approach',
#  'approaches',
#  'approval',
#  'approve',
#  'approved',
#  'approves',
#  'apps',
#  'april',
#  'arab',
#  'arabia',
#  'arabs',
#  'arafat',
#  'arafat 39',
#  'arbitration',
#  'archbishop',
#  'archive',
#  'arctic',
#  'area',
#  'areas',
#  'aren',
#  'arena',
#  'argentina',
#  'argentine',
#  'arguments',
#  'aristide',
#  'arizona',
#  'arkansas',
#  'arm',
#  'armed',
#  'arms',
#  'armstrong',
#  'army',
#  'army chief',
#  'arrest',
#  'arrest man',
#  'arrested',
#  'arrested ap',
#  'arrests',
#  'arrival',
#  'arrive',
#  'arrives',
#  'arroyo',
#  'arsenal',
#  'arson',
#  'art',
#  'art review',
#  'artest',
#  'arthritis',
#  'arthritis drug',
#  'arthur',
#  'artificial',
#  'artist',
#  'artists',
#  'arts',
#  'arts briefly',
#  'asbestos',
#  'asean',
#  'ash',
#  'ashcroft',
#  'ashes',
#  'ashlee',
#  'ashlee simpson',
#  'asia',
#  'asia europe',
#  'asia pacific',
#  'asian',
#  'asian shares',
#  'asian stocks',
#  'aside',
#  'ask',
#  'asked',
#  'asks',
#  'assails',
#  'assassination',
#  'assault',
#  'assembly',
#  'asset',
#  'assets',
#  'assistant',
#  'associates',
#  'association',
#  'asthma',
#  'aston',
#  'astrazeneca',
#  'astronaut',
#  'astronauts',
#  'astros',
#  'asylum',
#  'ata',
#  'athens',
#  'athletes',
#  'athletics',
#  'atkins',
#  'atlanta',
#  'atlantic',
#  'atlantis',
#  'atom',
#  'atomic',
#  'atonement',
#  'atop',
#  'atp',
#  'attack',
#  'attack ap',
#  'attack iraqi',
#  'attack kills',
#  'attack risk',
#  'attacked',
#  'attackers',
#  'attacks',
#  'attacks iraq',
#  'attacks kill',
#  'attempt',
#  'attempts',
#  'attend',
#  'attendants',
#  'attention',
#  'attorney',
#  'attorney general',
#  'attorneys',
#  'auburn',
#  'auction',
#  'auctions',
#  'audience',
#  'audio',
#  'audit',
#  'aug',
#  'august',
#  'aussie',
#  'aussies',
#  'australia',
#  'australia 39',
#  'australian',
#  'australian pm',
#  'australians',
#  'austria',
#  'austrian',
#  'author',
#  'authorities',
#  'authority',
#  'autism',
#  'auto',
#  'autonomy',
#  'autopsy',
#  'available',
#  'average',
#  'avian',
#  'avian flu',
#  'aviation',
#  'aviv',
#  'avoid',
#  'avoids',
#  'await',
#  'awaited',
#  'awaiting',
#  'awaits',
#  'award',
#  'award ap',
#  'awarded',
#  'awards',
#  'awards ap',
#  'away',
#  'axe',
#  'aziz',
#  'babies',
#  'baby',
#  'backed',
#  'backers',
#  'backing',
#  'backlash',
#  'backs',
#  'backup',
#  'bad',
#  'bad news',
#  'badly',
#  'bae',
#  'bag',
#  'baghdad',
#  'baghdad ap',
#  'baghdad car',
#  'baghdad car bomb',
#  'baghdad kills',
#  'bags',
#  'bahamas',
#  'bail',
#  'bailout',
#  'baker',
#  'balance',
#  'balco',
#  'bali',
#  'ball',
#  'ballmer',
#  'ballot',
#  'ballots',
#  'baltimore',
#  'ban',
#  'ban reuters',
#  'band',
#  'band aid',
#  'bandit',
#  'bang',
#  'bangladesh',
#  'bank',
#  'bank america',
#  'banker',
#  'banking',
#  'bankruptcy',
#  'banks',
#  'banned',
#  'bans',
#  'bar',
#  'barcelona',
#  'barclays',
#  'bargain',
#  'barred',
#  'barrel',
#  'barrichello',
#  'barrier',
#  'barroso',
#  'barry',
#  'bars',
#  'base',
#  'baseball',
#  'based',
#  'bases',
#  'basic',
#  'basketball',
#  'basque',
#  'basra',
#  'bat',
#  'bats',
#  'battered',
#  'batteries',
#  'batters',
#  'battery',
#  'battle',
#  'battleground',
#  'battles',
#  'battling',
#  'bay',
#  'bayer',
#  'bayern',
#  'bbc',
#  'bcs',
#  'bea',
#  'beach',
#  'beaches',
#  'bear',
#  'bear stearns',
#  'bears',
#  'beat',
#  'beaten',
#  'beating',
#  'beatles',
#  'beats',
#  'beauty',
#  'beckham',
#  'bed',
#  'beef',
#  'beer',
#  'begin',
#  'beginning',
#  'begins',
#  'behavior',
#  'behead',
#  'beheaded',
#  'beheading',
#  'beijing',
#  'beirut',
#  'belarus',
#  'belfast',
#  'belgian',
#  'belgium',
#  'believe',
#  'believed',
#  'bell',
#  'belt',
#  'beltran',
#  'ben',
#  'benefit',
#  'benefits',
#  'bengals',
#  'benitez',
#  'berkshire',
#  'berkshire hathaway',
#  'berlin',
#  'berlusconi',
#  'bernanke',
#  'berth',
#  'beslan',
#  'best',
#  'best buy',
#  'bet',
#  'beta',
#  'bets',
#  'better',
#  'betting',
#  'beware',
#  'bextra',
#  'beyonce',
#  'bhopal',
#  'bhp',
#  'bhutto',
#  'bhutto killing',
#  'bias',
#  'bid',
#  'bid ap',
#  'bid reuters',
#  'bidders',
#  'bidding',
#  'biden',
#  'bids',
#  'bids farewell',
#  'big',
#  'big brother',
#  'bigger',
#  'biggest',
#  'bigley',
#  'bike',
#  'billing',
#  'billion',
#  'billionaire',
#  'billions',
#  'bills',
#  'billy',
#  'billy joel',
#  'bin',
#  'bin laden',
#  'bin laden tape',
#  'binge',
#  'biotech',
#  'bird',
#  'bird flu',
#  'birds',
#  'birth',
#  'birthday',
#  'bishop',
#  'bishops',
#  'bit',
#  'bite',
#  'bites',
#  'bits',
#  'bitter',
#  'bittorrent',
#  'biz',
#  'bizarre',
#  'black',
#  'black watch',
#  'blackberry',
#  'blackburn',
#  'blacks',
#  'blackstone',
#  'blackwater',
#  'bladder',
#  'bladder cancer',
#  'blade',
#  'blair',
#  'blair 39',
#  'blake',
#  'blame',
#  'blamed',
#  'blames',
#  'blast',
#  'blast hits',
#  'blast kills',
#  'blasts',
#  'blasts kill',
#  'blaze',
#  'blazers',
#  'bleak',
#  'blind',
#  'blitz',
#  'bln',
#  'bloc',
#  'block',
#  'blockade',
#  'blockbuster',
#  'blocked',
#  'blocking',
#  'blocks',
#  'blog',
#  'blogger',
#  'bloggers',
#  'blogs',
#  'blood',
#  'blood pressure',
#  'bloody',
#  'bloomberg',
#  'blow',
#  'blown',
#  'blows',
#  'blu',
#  'blu ray',
#  'blue',
#  'blue chips',
#  'blue jays',
#  'blues',
#  'bluetooth',
#  'blunder',
#  'blunkett',
#  'bmg',
#  'bmw',
#  'bnp',
#  'board',
#  'boards',
#  'boat',
#  'bob',
#  'bobby',
#  'bobcats',
#  'bodies',
#  'body',
#  'boeing',
#  'bold',
#  'bolivia',
#  'bollywood',
#  'bolster',
#  'bolsters',
#  'bolton',
#  'bomb',
#  'bomb alert',
#  'bomb attack',
#  'bomb blast',
#  'bomb explodes',
#  'bomb kills',
#  'bomb kills 10',
#  'bomb near',
#  'bomb plot',
#  'bomb scare',
#  'bomb threat',
#  'bombed',
#  'bomber',
#  'bomber kills',
#  'bombers',
#  'bombing',
#  'bombing kills',
#  'bombings',
#  'bombs',
#  'bombs kill',
#  'bond',
#  'bonds',
#  'bones',
#  'bono',
#  'bonuses',
#  'book',
#  'books',
#  'boom',
#  'booming',
#  'boost',
#  'boosted',
#  'boosts',
#  'boot',
#  'borat',
#  'border',
#  'borders',
#  'born',
#  'bosnia',
#  'bosnian',
#  'bosnian serb',
#  'bosox',
#  'boss',
#  'bosses',
#  'boston',
#  'boston scientific',
#  'bought',
#  'bounce',
#  'bounces',
#  'bound',
#  'bounty',
#  'bourses',
#  'bow',
#  'bowl',
#  'bowl win',
#  'bows',
#  'box',
#  'box office',
#  'box office reuters',
#  'boxes',
#  'boxing',
#  'boy',
#  'boycott',
#  'boys',
#  'brace',
#  'braced',
#  'braces',
#  'brady',
#  'brain',
#  'brains',
#  'branch',
#  'brand',
#  'brando',
#  'brands',
#  'branson',
#  'brave',
#  'braves',
#  'brawl',
#  'brazil',
#  'brazil lula',
#  'brazilian',
#  'breach',
#  'breaches',
#  'break',
#  'breaking',
#  'breaks',
#  'breakthrough',
#  'breast',
#  'breast cancer',
#  'breath',
#  'breathing',
#  'brewers',
#  'bribes',
#  'bridge',
#  'brief',
#  'briefing',
#  'briefly',
#  'briefs',
#  'bright',
#  'bring',
#  'brings',
#  'brink',
#  'bristol',
#  'brit',
#  'britain',
#  'britain 39',
#  'britain afp',
#  'british',
#  'british girl',
#  'british hostage',
#  'british police',
#  'british soldier',
#  'british soldiers',
#  'british troops',
#  'britney',
#  'britney spears',
#  'briton',
#  'britons',
#  'brits',
#  'broad',
#  'broadband',
#  'broadcast',
#  'broadcom',
#  'broadway',
#  'broke',
#  'broken',
#  'broker',
#  'brokers',
#  'broncos',
#  'bronze',
#  'brooklyn',
#  'bros',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'browns',
#  'browser',
#  'bruins',
#  'brussels',
#  'brutal',
#  'bryant',
#  'bubble',
#  'buck',
#  'buckeyes',
#  'bucks',
#  'bucs',
#  'budget',
#  'buenos',
#  'buenos aires',
#  'buffett',
#  'bug',
#  'bugs',
#  'build',
#  'builder',
#  'building',
#  'buildings',
#  'builds',
#  'buildup',
#  'built',
#  'bulgaria',
#  'bulgarian',
#  'bull',
#  'bulls',
#  'burden',
#  'burger',
#  'burial',
#  'buried',
#  'buries',
#  'burma',
#  'burn',
#  'burning',
#  'burns',
#  'burst',
#  'burundi',
#  'bury',
#  'bus',
#  'bus crash',
#  'busch',
#  'bush',
#  'bush 39',
#  'bush administration',
#  'bush ap',
#  'bush calls',
#  'bush campaign',
#  'bush defends',
#  'bush guard',
#  'bush iraq',
#  'bush kerry',
#  'bush names',
#  'bush says',
#  'bush seeks',
#  'bush signs',
#  'bush urges',
#  'bush visit',
#  'bush vows',
#  'bush wants',
#  'business',
#  'business briefing',
#  ...]

# %% [markdown]
# Number must be for sure managed in a different way...

# %%
titles_with_numbers = news_df[news_df["title"].str.contains(r"\d", regex=True, na=False)]["title"]

len(titles_with_numbers)
# Out:
# 13445

# %%
for title in titles_with_numbers[:20]:
    print(title)
    print('='*30)
# Out:
# OPEC Boosts Nigeria&#39;s Oil Revenue By .82m Bpd
# ==============================
# Yearender: Mideast peace roadmap reaches dead-end in 2004
# ==============================
# Battleground Dispatches for Oct. 5 \
#     (CQPolitics.com)\
#
# ==============================
# Opera Star Robert Merrill Dies at 85
# ==============================
# Â£800M PLEDGED FOR VIRGIN BOSS&#39;S SPACE TRIPS
# ==============================
# Wells Leads Grizzlies Past Spurs 93-90 (AP)
# ==============================
#  Double Bombing Kills At Least 42 in Hyderabad
# ==============================
# MmO2 signs i-mode deal
# ==============================
# German Police to Drop 1970s Mustard/beige Uniforms (Reuters)
# ==============================
# Australia&#39;s Voters to Choose Between Howard, Latham (Update1)
# ==============================
# Thai 2004 growth forecast cut to 6.0-6.5 percent as Q2 growth slows (AFP)
# ==============================
# Schroeder begins 3-day China visit
# ==============================
# US IT Spending to Grow 7% Next Year
# ==============================
# Downer: Hicks lobby &#39;if innocent&#39;
# ==============================
# Tigers to resume &#39;&#39;freedom struggle&#39;&#39; if talks not resumed
# ==============================
# Intel Chips to Shrink to 32-Nanometer Process
# ==============================
# A. D. Lewis, Administrator Behind Conrail, Is Dead at 88
# ==============================
# Pakistan Kills 50 Fighters on Afghan Border
# ==============================
# Bobcats 94 Hornets 93, overtime
# ==============================
# Eros announces 5-year deal with K Sera Sera
# ==============================

# %% [markdown]
# Okay, maybe it's a big work but I want to categorize numbers:
#
# - year: (1900-2025 also with an ending s)
# - percentage: (%number o number%)
# - money: (\$number, number\$, or euros... )
# - score: (number - number)
#
# and I substitute with yeartoken, percentagetoken etc...
#
# Now I need to validate this initial intuitive pattern with real data

# %%
for title in titles_with_numbers:
    print(title)
    print('='*30)
# Out:
# OPEC Boosts Nigeria&#39;s Oil Revenue By .82m Bpd
# ==============================
# Yearender: Mideast peace roadmap reaches dead-end in 2004
# ==============================
# Battleground Dispatches for Oct. 5 \
#     (CQPolitics.com)\
#
# ==============================
# Opera Star Robert Merrill Dies at 85
# ==============================
# Â£800M PLEDGED FOR VIRGIN BOSS&#39;S SPACE TRIPS
# ==============================
# Wells Leads Grizzlies Past Spurs 93-90 (AP)
# ==============================
#  Double Bombing Kills At Least 42 in Hyderabad
# ==============================
# MmO2 signs i-mode deal
# ==============================
# German Police to Drop 1970s Mustard/beige Uniforms (Reuters)
# ==============================
# Australia&#39;s Voters to Choose Between Howard, Latham (Update1)
# ==============================
# Thai 2004 growth forecast cut to 6.0-6.5 percent as Q2 growth slows (AFP)
# ==============================
# Schroeder begins 3-day China visit
# ==============================
# US IT Spending to Grow 7% Next Year
# ==============================
# Downer: Hicks lobby &#39;if innocent&#39;
# ==============================
# Tigers to resume &#39;&#39;freedom struggle&#39;&#39; if talks not resumed
# ==============================
# Intel Chips to Shrink to 32-Nanometer Process
# ==============================
# A. D. Lewis, Administrator Behind Conrail, Is Dead at 88
# ==============================
# Pakistan Kills 50 Fighters on Afghan Border
# ==============================
# Bobcats 94 Hornets 93, overtime
# ==============================
# Eros announces 5-year deal with K Sera Sera
# ==============================
# The Workplace: It&#x27;s called mobbing
# ==============================
# Sharon OKs 1,000 new settlement homes
# ==============================
# Ivan Bears Down on Jamaica, Killing 23
# ==============================
# Google exceeds expectations in Q4
# ==============================
# Get Peachtree Pro Accounting 2008 free after rebate
# ==============================
# State-Owned Russian Bank Buys a 5% Stake in EADS
# ==============================
# U.S., Iraqi troops kill 20 militants
# ==============================
# Pac-10 Women&#39;s Basketball Outlook
# ==============================
# Silverstone Owners Want F1 Deal by End-October
# ==============================
# Bobcats Erase 19-Point Deficit to Beat Magic
# ==============================
# Big Airbus A380 delays expected \
#     (AP)\
#
# ==============================
# Bears hand Favre 1st shutout of career \
#     (AP)\
#
# ==============================
# Israel razes teen bomber&#39;s home
# ==============================
# ISPAT to become world&#39;s biggest steel company:
# ==============================
# Ford 4th-quarter loss narrows; forecasts 2008 loss
# ==============================
# 57 killed in US offensive in Iraq
# ==============================
# Best First Class 2004
# ==============================
# 5 foreigners among death toll of explosion in Kabul
# ==============================
# Fattah Got a $100 Gift From Santa Street
# ==============================
# Haiti&#39;s Death Toll from Ivan Climbs as Waters Recede
# ==============================
# Palm&#39;s Tungsten Gains More Memory
# ==============================
# Freescale 1000-worker cull to cost $65m
# ==============================
# ADV: $175,000 Mortgage for Under $730/Month
# ==============================
# N-bomb equipment &#39;lost in Iraq&#39;
# ==============================
# A 12-Gigabyte Hard Drive That Slips Easily Into Your Pocket
# ==============================
# Beltran's blast in 16th lifts Mets 9-8 \
#     (AP)\
#
# ==============================
# Mortgage insurer MGIC to buy Radian for $5 bln \
#     (Reuters)\
#
# ==============================
# &#39;Law  Order&#39; star Thompson surges in US presidential survey \
#     (AFP)\
#
# ==============================
# California regulators approve world&#39;s toughest smog rules
# ==============================
# Earnings Rise 24% at Kimberly-Clark
# ==============================
# Volcano&#39;s steam cloud wows spectators
# ==============================
# Arafat&#39;s nephew in France to seek medical records
# ==============================
# Jaguar negotiates Â£534m Ford aid
# ==============================
# Suicide truck bomber kills 18 near Baghdad college
# ==============================
# Update: Motorola to buy Symbol for $3.9 billion
# ==============================
#  Time Warner Chief to Decide Over 2 Years When to Retire
# ==============================
# Rabbis &#39;incite violence&#39; over Gaza plan
# ==============================
# Catch Up With Seamless Wi-Fi on MN1.Com
# ==============================
# Schumacher Wins Japanese Grand Prix for 13th Victory of Season
# ==============================
# Aid worker&#39;s husband hopeful of release
# ==============================
# Italy envoy aims to free 2 hostages in Iraq
# ==============================
# Update 2: Unocal, Royal Dutch Withdraw From Project
# ==============================
# ABC announces pick-up orders for 9 shows \
#     (AP)\
#
# ==============================
# More Than 40 Winks From Arena
# ==============================
# Cal-Maine Posts 2Q Loss on Lagging Sales
# ==============================
# '24' Premiere Racks Up Big Numbers for Fox
# ==============================
# Bills Overpower Browns, 37-7 (AP)
# ==============================
# James Hardie&#39;s Macdonald Quits Amid Asbestos Probe (Update5)
# ==============================
# Pennsylvania Turnpike Won&#39;t Waive Tolls
# ==============================
# Twin bill doesn&#39;t promise holiday cheer
# ==============================
# UN pledges help for Darfur refugees, Sudan wants $300 mln
# ==============================
# Suicide bomber kills 2 Pakistani troops \
#     (AP)\
#
# ==============================
# PSP to support MP3s
# ==============================
# 2004 forecast raised on strength of &#39;The Incredibles&#39;
# ==============================
# Forecaster predicts busy 2007 U.S. hurricane season \
#     (Reuters)\
#
# ==============================
# Bank of America plans to cut 4,500 jobs
# ==============================
# ABC Sorry for &#39;Desperate Housewives&#39; Football Plug
# ==============================
# Bonds used steroids in 2003, trainer says on recording
# ==============================
# MLB: Anaheim 9, Minnesota 6
# ==============================
# Who Is Russia&#39;s New Oil Major?
# ==============================
# US recovery &#39;not helping workers&#39;
# ==============================
# Everton reject Â£20m Rooney bid
# ==============================
# Basket Nears $8,800 With 5 Days to Go
# ==============================
# HP to pay $14.5m following probe into boardroom leaks
# ==============================
# Colorado (3-0) At Missouri (2-1)
# ==============================
# 2 CONVICTED IN IMMIGRANT DEATHS
# ==============================
# Ford to offer 3 buyout plans to salaried workers
# ==============================
# Tediously topical &#39;Shark Tale&#39; lacks freshness
# ==============================
# U.N.: 1 Million Refugees Return to Bosnia (AP)
# ==============================
# Kerkorian may buy up to 12 million shares of GM \
#     (Reuters)\
#
# ==============================
# Football film filled with bright &#39;Lights
# ==============================
# Windows XP SP2 respite to end
# ==============================
# CA cutting 5 percent of workforce
# ==============================
# PacifiCare buys AMS for $502 million
# ==============================
#  New Russian Party Faces 1st Electoral Test
# ==============================
# Rice&#39;s crash could be as costly as it was scary
# ==============================
# "Don't Tase Me, Bro" tops '07 memorable quote list
# ==============================
# 2010 World Cup the target as Burley takes charge of Scotland \
#     (AFP)\
#
# ==============================
# General Mills sells Snack Ventures Europe stake for $750 million
# ==============================
# At least 14 killed in U.S. tornadoes
# ==============================
# Suicide car bombs kill 20 Iraqis
# ==============================
# Update 2: Computer Associates to Acquire Netegrity
# ==============================
# CA to acquire Netegrity for $430M
# ==============================
# Households face 15% jump in fuel prices
# ==============================
# As many as 40 hurt on Air Canada flight: reports
# ==============================
# Special Report: 60 Ways To Live It Up This Summer
# ==============================
# Japan jumps on Sony&#39;s PSP
# ==============================
# Thais plan origami &#39;peace bombs&#39;
# ==============================
# Fujitsu ETERNUS4000 Storage System Sets New World Record in Storage Performance
# ==============================
#  LSI to Buy Agere in $4B Stock Swap
# ==============================
# British police arrest 8 in anti-terrorism raids
# ==============================
# Everything You Need to Know About Microsoft&#39;s OS Update
# ==============================
# Japan Economy Up 0.1 Pct. in New Quarter (AP)
# ==============================
# Australia&#39;s Howard Poised for Fourth Term After Nation Votes
# ==============================
# Monster.com took 5 days to disclose data theft
# ==============================
# P2P Tilts Toward Legitimacy
# ==============================
# Panel: Robot Won&#39;t Save Hubble
# ==============================
# &#39;Ladder&#39; captures heroism
# ==============================
# F1: Countdown to British GP
# ==============================
# Pitch count doesn&#39;t really concern Lidge
# ==============================
# WildPackets Adds Vista, Centrino and 11n Support to OmniAnalysis
# ==============================
# Lee's 2-run HR rallies Cubs over Astros \
#     (AP)\
#
# ==============================
# Murder manhunt costs reach Â£1.5m
# ==============================
# US moviemakers go after &#39;parasites&#39;
# ==============================
# Blast at Market in Southern Philippines Kills 13
# ==============================
# Ol&#39; Dirty Bastard&#39;s Death Was Accidental
# ==============================
# LA Film Critics Toast &quot;Sideways&quot; With 5 Prizes
# ==============================
# ADV: $150,000 Mortgage for Under $690/Month
# ==============================
# Makybe Diva becomes first mare to win Australia&#39;s biggest horse <b>...</b>
# ==============================
# Nepal army claims gunning down 80 Maoists
# ==============================
# New swimming head coach aims to deepen men&#39;s pool
# ==============================
# 2004 Presidential Endorsements (AP)
# ==============================
# Cerulean gives Trillian 3.0 IM sneak peek
# ==============================
# Multan blast toll rises to 39 :
# ==============================
# Middle East enters a &#39;post-Arafat era&#39;: News analysis
# ==============================
# US men win 800; Phelps injured
# ==============================
# UK hostage &#39;in hands of new group&#39;
# ==============================
# RPT-UPDATE 3-US Congress analysts see worse long-term deficit
# ==============================
# Update 1: Stewart Asks Court to Overturn Conviction
# ==============================
# Oil prices fall in wake of last week&#39;s run-up
# ==============================
# Drug pipeline brings $80m more to Synta
# ==============================
# Google boys to pocket Â£650m from share sale
# ==============================
# Johnstons&#39; anguish over as parents, gov&#39;t express relief \
#     (AFP)\
#
# ==============================
# Lilly sees slower profit growth in 2007
# ==============================
# eBay snaps up Rent.com for $415m
# ==============================
# No Marion  no problem for US in 100
# ==============================
# More than 400 Filipinos dead as new storm nears
# ==============================
# Newcastle&#39;s Boumsong bid rejected by Rangers
# ==============================
# Webber Leads Kings Past Clippers, 89-83 (AP)
# ==============================
# Spaceflight to cost $40 million in 2009
# ==============================
# Novell SuSE Linux users get &#39;protection&#39;
# ==============================
# Indonesia Raises Tsunami Death Toll to 166,320
# ==============================
# Suicide Bombers, Gunmen Kill 32 in Iraq
# ==============================
# An Unfortunate Event Leads to Number 1
# ==============================
# 5 Frugal 5-Star Stocks
# ==============================
# Update 3: Economic Powers Vow Aid for Poor Nations
# ==============================
# Weir on Verge of Ending 50-Year Canadian Wait
# ==============================
# Update 5: PeopleSoft Extends Its Customer Program
# ==============================
# Tsunami aid pledges top $3bn
# ==============================
# Radio tags to vouch for drugs&#39; legitimacy
# ==============================
# Glen proves he&#39;s the Boss on magic mare
# ==============================
# 'Star Trek' ship fetches over &#36;500,000 \
#     (AP)\
#
# ==============================
# Blast traps 162 as death toll soars in China&#39;s coal mines
# ==============================
# Loews celebrates 100 years of movies
# ==============================
# Suicide Car Bomb in Iraq's Kirkuk Kills 17 - Police (Reuters)
# ==============================
# Rocket scrams at 10 times speed of sound
# ==============================
# Annan finds 13 incidents of illicit arms in Lebanon \
#     (Reuters)\
#
# ==============================
# Knuble nets 2 as Flyers beat Caps 6-4 \
#     (AP)\
#
# ==============================
# The 787 Dreamliner is here
# ==============================
# Manchester United manager Alex Ferguson to coach 1,000th match <b>...</b>
# ==============================
# Savor Beltran while he&#39;s hot
# ==============================
# Afghanistan tenses for Karzai&#39;s swearing-in
# ==============================
# World briefs - November 30, 2004
# ==============================
# Suicide bomber kills 18 troops after Pakistan mosque raid \
#     (AFP)\
#
# ==============================
# 5 Stellar Series to Catch Up with on DVD
# ==============================
# Sony to support MP3 in future players
# ==============================
# &#39;Big Blue&#39; goes &#39;Big Green&#39; in India \
#     (AFP)\
#
# ==============================
# Mariners tab Hargrove for his 3rd managing stint
# ==============================
# Microsoft releases Silverlight 1.0 video technology
# ==============================
# First Look: Delicious Library 2.0 Burns With Animated Cool
# ==============================
# Mother of Michael Jackson&#39;s Accuser to Testify
# ==============================
# Amazon's S3 Down for Several Hours
# ==============================
# Welcome Mat Goes Out at Habitat's 100th House
# ==============================
# Air Canada to Buy 30 Bombardier Jets
# ==============================
# Adobe to release Intel-native Photoshop CS3 beta \
#     (Macworld.com)\
#
# ==============================
# VfB Stuttgart 3-0 Benfica: FT Report
# ==============================
# Afghanistan Says U.S. Frees 81 Taliban Prisoners
# ==============================
# &#39;Morgan wants `four pillars&#39; on reform agenda
# ==============================
# Ambush wipes &#163;4bn off value of online gaming shares
# ==============================
# Sports ; Bucs&#39; Owner Glazer Raises Man United Stake
# ==============================
#  Fannie Mae CEO '07 Pay Cut Not in Line With Stock Fall
# ==============================
# A chapter of &#x27;Jackass&#x27; as Web test
# ==============================
# Team exercises Wagner&#39;s $9 million option
# ==============================
# Blair Presses for $150M in Aid for Darfur
# ==============================
# Energy efficiency firm EnerNoc buys MDEnergy for $7.9 million
# ==============================
# 10 killed in Fallujah blast, Iraq retracts Ibrahim arrest claim
# ==============================
# Group Says It Is Holding 10 New Hostages In Iraq
# ==============================
# US indicts 11 over pump-and-dump stock spam
# ==============================
# 5 More Turnaround Stocks
# ==============================
# Packers lead Eagles 3-0 on Rayner's FG \
#     (AP)\
#
# ==============================
# FDA Advises Limiting Use of Pfizer&#39;s Painkiller Drugs (Update2)
# ==============================
# Rocket Wins &#36;10M Prize for Trip to Space (AP)
# ==============================
# Twin blasts kill 10 in Baghad
# ==============================
# 4 arrested over embassy bombing
# ==============================
# Ronco files for Chapter 11
# ==============================
# British Charge 8 Tied to Terror Plot With Murder Conspiracy
# ==============================
# Menâs Basketball Roundup: Indianaâs Home Streak Reaches 25 With a Rout
# ==============================
# Deal to Sell Clear Channel for $19 Billion Is Approved
# ==============================
# Bomb blast explodes near Australian Embassy in Baghdad, killing 2 <b>...</b>
# ==============================
# Second Bomb Injures 9 in Thai South - Witnesses
# ==============================
# Santa Looks After Pet Owners, Too: First 400 at HSSM to Get Free Supplies
# ==============================
# Regulators Probe Hummer H2 Complaints
# ==============================
# Protein Fuels Melanoma&#39;s Growth
# ==============================
# Marathon Legend Johnny Kelly Dies At 97
# ==============================
# ATA&#39;s Pain Is AirTran&#39;s Gain
# ==============================
# Jamaicans Flee As Ivan Approaches; 23 Dead
# ==============================
# We let fans down - O&#39;Leary
# ==============================
# Paris Embassy Bomb Blast Hurts 10
# ==============================
# Sen. Brownback drops out of 2008 campaign \
#     (Reuters)\
#
# ==============================
# Juventus stretches Serie A lead while Roma and Inter play to 3-3 <b>...</b>
# ==============================
# Update 6: Crude Oil Prices Fall Below $43 a Barrel
# ==============================
# No. 12 Boise State wraps up trip to BCS \
#     (AP)\
#
# ==============================
# Cornerstone Seeks Capital: The Drug Company Begins Its First Fundraiser, Aims to Raise at Least $15 Million
# ==============================
# Pubs sale lifts Foster&#39;s profit
# ==============================
# Sudan flooding kills at least 30 people \
#     (AP)\
#
# ==============================
# FBI Author of Pre-9/11 Memo Talks to Paper (AP)
# ==============================
# Asian mobile growth helps lift SingTel&#x27;s profit in the third quarter
# ==============================
# GE gets $1 billion in Saudi Arabian orders
# ==============================
# Gay bishop diocese &#39;regrets pain&#39;
# ==============================
# It&#39;s back to work for Pistons Pistons return from banner season
# ==============================
# South Korea to end 3-year ban on U.S. beef
# ==============================
# L.A. archdiocese to pay &#36;600M to victims \
#     (AP)\
#
# ==============================
# Flintoff&#39;s absence makes the heart grow fonder
# ==============================
# Siemens and Ningbo Bird Deny They&#39;re in Talks Over Mobile Unit
# ==============================
#  Harding Makes 41 Saves in Wild Win
# ==============================
# At least 22 killed in central Baghdad blast: police
# ==============================
# Drug may block Alzheimer&#39;s
# ==============================
# Bad news for Italy if 53 comes up
# ==============================
# News Corporation Sells 8 TV Stations
# ==============================
# âPiratesâ Haul So Far Estimated at $401 Million
# ==============================
# CIT Group&#39;s Q3 profit up 25%, tops by a penny
# ==============================
# Heineken 1H profit rises 26 percent \
#     (AP)\
#
# ==============================
# Satellite launching successes fix China on world&#39;s top level
# ==============================
# Boeing will stop producing its 717 jet
# ==============================
# Fears over &#39;harmful&#39; platinum in breast implants
# ==============================
# PostgreSQL 8.3 designed for better speed
# ==============================
# Unsafe Abortions Kill 70,000 Women a Year -Report
# ==============================
# Road accident kills 31 in southern Pakistan
# ==============================
# Referee &#39;supports Arsenal or had a blackout&#39;
# ==============================
# Home Depot may accept $1.2 bln less for unit: report
# ==============================
# US, Brazil tied 0-0 in gold medal match
# ==============================
# Nine Atlantic hurricanes expected in &#39;07 \
#     (Reuters)\
#
# ==============================
# Ranieri salutes &#39;incredible&#39; Inter
# ==============================
# SideStep Named Momentum 2006 Company at the IBDNetwork Annual Momentum Growth Conference
# ==============================
# Jackson &#39;offered abuse boy house&#39;
# ==============================
# At Least 6 Are Killed in Afghanistan Explosion
# ==============================
# Germany&#39;s Schroeder confirms adopting Russian toddler
# ==============================
# Kenyan rush-hour blast kills one, hurts 37
# ==============================
# Giants&#8217; New Secondary Will Be Broken In Fast
# ==============================
# 800 hide in UN buildings
# ==============================
# Cisco's CRS-1 router drops a size
# ==============================
# Germany&#39;s last gasp
# ==============================
# Bombs kill 34 in Baghdad, 3 UK troops in Basra
# ==============================
# Patriots, Now a Perfect 16-0, Go For 19
# ==============================
# Bomber kills 13 Iraq volunteers and 1 U.S. soldier
# ==============================
# Two die cleaning sport star&#39;s pool
# ==============================
# What a Square! An Actor&#39;s Life as SpongeBob
# ==============================
# Africa tells G8: we want action not more promises \
#     (Reuters)\
#
# ==============================
# Bush and Kerry Clash on US&#39;s $1.7 Trillion Health Care Bill
# ==============================
# Sale helps deliver Foster&#39;s Group profit boost
# ==============================
# Rudy Giuliani&#39;s Investment Banking Racket
# ==============================
# Kuwait's $3bn plane deal aborted
# ==============================
# Redskins Tied, 3-3
# ==============================
# Microsoft to fix Xbox 360s, take $1B-plus charge \
#     (InfoWorld)\
#
# ==============================
# Dodgers Lead Cardinals 1-0 After One
# ==============================
# Tenn. Man's 5-Day Dive Sets World Record
# ==============================
# Wal-Mart sterling bond with 30-year maturity -source
# ==============================
# Â£141m benefits computer shelved
# ==============================
# Bomb Near Iraqi Shi'ite Shrine Kills 8, Wounds 32
# ==============================
# Miami Upsets No. 22 Maryland, 75-73 (OT) (AP)
# ==============================
# The human side of the firefighters&#39; lives
# ==============================
# Aug. 15, 2004
# ==============================
# Nokia says cellphone future is âsmart&#39;
# ==============================
# SingTel poised to launch first 3G service in Southeast Asia (AFP)
# ==============================
# SPACE PROGRAM NASA&#39;s Shuttle Hanger Badly Damaged by Storm
# ==============================
# Montoya &#39;poised for FIA summons&#39;
# ==============================
# WWF predicts great white shark&#39;s extinction
# ==============================
# Merrill seeking $4 bln, Kuwait could invest: FT \
#     (Reuters)\
#
# ==============================
# Over 300 dead in Kenya unrest: rights group
# ==============================
# FSU&#39;s Thorpe gets one-game suspension
# ==============================
# IBM lays off 1,570 U.S. workers to cut costs
# ==============================
# Text of Bush's News Conference, Part 2 (AP)
# ==============================
# Tough choice: Ukraine&#39;s Jews in quandary over candidates in <b>...</b>
# ==============================
# 2 passenger trains collide head-on in northern India, killing at <b>...</b>
# ==============================
# Britain&#x27;s newfound &#x27;buy now, pay later&#x27; culture starts to wobble
# ==============================
# Spanish poet Angel Gonzalez dead at 82 \
#     (AP)\
#
# ==============================
# Oil hits new record above $92
# ==============================
# Go &quot;Dutch&quot; in 2005: Eat A Polymeal of Wine, Fish, Chocolate <b>...</b>
# ==============================
# Four in 10 smokers 'want to quit'
# ==============================
# Tsunami Toll Jumps To 114,000
# ==============================
# Brian Williams Fills Tom Brokaw&#39;s Chair
# ==============================
# No-smoking law targets No.1 killer
# ==============================
# Hunt for new CEO begins as Telstra&#39;s Ziggy Switkowski steps down
# ==============================
# Man Utd 2-0 Arsenal: FT Report
# ==============================
# Take the 403(b) and Run (The Motley Fool)
# ==============================
# Clarke closes in on No. 11 Scott in ranking
# ==============================
# Nokia signs &#36;2.5B in deals with China \
#     (AP)\
#
# ==============================
# Foodland says don&#39;t sell
# ==============================
# Real Madrid coach: We&#39;re on right track
# ==============================
# US troops, warplanes kill 25 insurgents in fiercest battle
# ==============================
# &#39;Age is just a number&#39; to leader Haas
# ==============================
# UPDATE 2-Ferdinand, Rooney and Campbell back for England
# ==============================
# Freitas Defeats Saucedo in 10-Round Bout
# ==============================
# Kerry hits president&#39;s leadership
# ==============================
# Haiti Storm Jeanne Floods Toll Rises To 100
# ==============================
# Brain Damage Likely for 4 Chinese Kids
# ==============================
# Ex-Goldman Associate Sentenced to More Than 4 Years for Inside Trades
# ==============================
# Qwest agrees to pay $250 million to settle fraud case
# ==============================
# MDs&#39; vote a blow to Liberals
# ==============================
# Hilton&#39;s Lost Chihuahua Turns Up
# ==============================
# Chávez&#39;s Challenge
# ==============================
# Thereâs Ocho Cinco, and Then Thereâs No. 85
# ==============================
# NFL Fines S Darius $75K for Ferguson Hit
# ==============================
# Sony bags MGM film biz for 4.8B
# ==============================
# At least 31 dead in Indonesia jet crash
# ==============================
# Six tribal leaders among 50 killed in Iraq
# ==============================
# Perfect day sees 7 lead Michelin
# ==============================
# Interim Chief at Enron Asks for $25 Million
# ==============================
# Fight heating up after nation&#39;s first spam conviction
# ==============================
# PENN STATE 37, MICHIGAN STATE 13 Rousing Finale for the Seniors <b>...</b>
# ==============================
# Concert celebrates Diana's 46th birthday \
#     (AP)\
#
# ==============================
# TO solution: Don&#39;t show TD antics
# ==============================
# UK's Charles and Camilla to Marry on April 8
# ==============================
# Whatever Happened To . . .  The Stinky Effects of 1996 Chemical Leak?
# ==============================
# G7 draft: Will act to secure stability, growth
# ==============================
# Erat lifts Predators past Flyers 3-2 \
#     (AP)\
#
# ==============================
# Washington St. tops No. 18 Gonzaga 77-67 \
#     (AP)\
#
# ==============================
# Grass biofuels 'cut CO2 by 94%'
# ==============================
# NS health system slammed for $15.5M in overdue accounts
# ==============================
# Workers&#39; Health Coverage Worse Off
# ==============================
# Rick Majerus Named USC Men&#39;s Basketball Coach For 2005-06 Season
# ==============================
#  Oil Futures Rise to $100 a Barrel
# ==============================
# Roundup: Canada&#39;s Weir increases his lead
# ==============================
# 2 Brothers, and the Mob in the Middle
# ==============================
# Tigers, Granderson agree on 5-year deal \
#     (AP)\
#
# ==============================
# Music Review | Focus! 2008: Prototypically American, Atypically Challenging
# ==============================
# Olive oil gets FDA&#39;s blessing
# ==============================
# 3 million ecstacy tablets seized in Australia
# ==============================
# IRA link to $55m bank raid
# ==============================
# Replacement jawbone grown on patient&#39;s back
# ==============================
# Anna Nicole's will, from 2001, released
# ==============================
# Greece 101, United States 95: United States, Yet Again, Falls Short of Gold Medal
# ==============================
#  Alexander Helps Seahawks Earn No. 3 Seed
# ==============================
# SocGen reels from record $7 billion rogue trader fraud
# ==============================
# Rehnquist&#39;s Cancer Isn&#39;t Always Mild
# ==============================
# Nokia announces U.S. availability of Nokia E61i and Nokia E65
# ==============================
# No. 22 Va. Tech Rallies Past Ga. Tech (AP)
# ==============================
# Bally agrees to $280 million in credit deals
# ==============================
# Google&#39;s ups and downs
# ==============================
# Sacrificing freedom for equality in France&#39;s schools
# ==============================
# G8 must focus on energy, not just economy: Russia \
#     (Reuters)\
#
# ==============================
# Deborah Kerr, Actress Known for Genteel Grace and a Sexy Beach Kiss, Dies at 86
# ==============================
# Adobe Creative Suite 3 sales 'on fire'
# ==============================
# US scientist casts doubt on AstraZeneca&#39;s Crestor
# ==============================
# Earnhardt Loses Appeal of 25-Point Penalty (AP)
# ==============================
# Devils Canât Recover After Rookieâs 2 Goals
# ==============================
# Assailants Kill 3 Before Mexico Election (AP)
# ==============================
# Marketing executives say &#39;Oprah&#39; giveaway to be closely watched
# ==============================
# Obama Faces `Glass-Houses&#39; Attacks Over Fund Raising \
#     (Bloomberg)\
#
# ==============================
# Swiss arrest 10 in international crackdown on child pornography (Canadian Press)
# ==============================
# Earnings Fall 32 Percent at Bank of America
# ==============================
# Storm Off Algeria Sinks Ship, 2 Die, 18 Missing (Reuters)
# ==============================
# Britain&#39;s Brown urged to take new approach on Afghanistan \
#     (AFP)\
#
# ==============================
# Nigerian strike over fuel price to start November 16
# ==============================
# Kenya deaths seen at 250
# ==============================
# Oil holds above $62 as supply glut balances OPEC
# ==============================
# Stalker &#39;kept an autographed book&#39;
# ==============================
# Pena Homers Give Reds 6-5 Edge Over Cubs (AP)
# ==============================
# U.S. force in Iraq at 140,000
# ==============================
# Microsoft's $1 Billion Red Ring Of Death
# ==============================
# Valentino Steps Down After 45 Years
# ==============================
# Greece declares nationwide emergency after fires kill 46
# ==============================
# At least 19 killed in Bulgaria bus crash \
#     (AP)\
#
# ==============================
# Insurers&#39; cost: $7.4-billion
# ==============================
# H&M Posts Improved 3Q Profits, Sales (AP)
# ==============================
# 1 dead as French train hits truck \
#     (AP)\
#
# ==============================
# Wildlife under pressure find 2nd chance \
#     (AP)\
#
# ==============================
# Stun gun has a pop at MP3 market
# ==============================
# Chemical Spill Sends 7 to Hospitals
# ==============================
# UN death toll in Algeria raised to 17 \
#     (AP)\
#
# ==============================
# 60 killed as war on Iraqi police is intensified
# ==============================
# Home builder index lowest since Feb 1991: NAHB
# ==============================
# Clippers Edge Heat, 114-112 (2OT) (AP)
# ==============================
# Notre Dame To Interview Utah&#39;s Meyer
# ==============================
# South African could take over No. 2 spot
# ==============================
# China mine blast kills 64
# ==============================
# Limited 2nd-Quarter Earnings Climb
# ==============================
# 86-year-old goes on trial for wartime Nazi massacre
# ==============================
# Update 1: Tokyo Stocks Trading Higher
# ==============================
# FDA Calls Ads for Cholesterol Pill Crestor &#39;False and Misleading&#39;
# ==============================
#  Nintendo to Replace 3.2M Wii Straps
# ==============================
# Japan won&#39;t leave Iraq over hostage
# ==============================
# Car bomb kills 16 in Baghdad book district
# ==============================
# 3Com and 3 Bucks (and Change)
# ==============================
# Taj Mahal Celebrates 350th Anniversary
# ==============================
# China Welcomes IPv6 Internet
# ==============================
# Rifts Seen on Climate and Security at G-8 Summit
# ==============================
# &#39;No experiments&#39; for SpaceShipOne
# ==============================
# Pulling Rank %%head%%Memphis is latest top-25 foe slapped by <b>...</b>
# ==============================
# Russia agrees to US deal that writes off $33bn of Iraq debt
# ==============================
# Reeve&#39;s journey got its start here
# ==============================
# Tesco challenges iTunes&#39; domination
# ==============================
# Tamil faction&#39;s No. 2 killed as violence rises
# ==============================
# Qaeda recruit Padilla sentenced to 17 years
# ==============================
# Julia&#39;s double joy
# ==============================
# Radical Shiite Cleric &#39;Accepts Peace Plan&#39;
# ==============================
# Arsenal held to 1-1 tie by West Brom
# ==============================
# 360 local employees pink-slipped by Mondavi
# ==============================
# SBC May Cut More Than 10,000 Jobs (Reuters)
# ==============================
# Down Democrats, Happy Republicans Look to 2008
# ==============================
# Attacks kill 11 as Rumsfeld makes surprise visit to Iraq
# ==============================
# 6 missing snowmobilers found alive \
#     (AP)\
#
# ==============================
# Gunmen attack Sunnis in Baghdad; 3 dead \
#     (AP)\
#
# ==============================
# Kindred: Forfeit request from Yankees &#39;ill&#39; conceived
# ==============================
# Bills Beat Dolphins, 42-32 (AP)
# ==============================
# Royal &amp; Sun moves 1,100 jobs to India
# ==============================
# Arkansas loses 2 track titles \
#     (AP)\
#
# ==============================
# It&#39;s fun &#39;n&#39; games again at Florida
# ==============================
# ADV: Try Currency Trading Risk-Free 30 Days
# ==============================
# Sophia Loren Turns 70 -- That's Right, 70!
# ==============================
# Gordon, Hoosiers hold on for 10th in row \
#     (AP)\
#
# ==============================
# Stocks Rally as Investors Welcome Election&#39;s End
# ==============================
# Australia &#39;working hard&#39; to prevent terrorists from entering <b>...</b>
# ==============================
#  Freddie Mac Profit Down 45 Percent in 2Q
# ==============================
# Suicide Attack Kills 2 in Israel; 16 Hurt
# ==============================
# &#39;Black boxes failed before planes went down&#39;
# ==============================
# Tiny telescope&#39;s big discovery opens new doors
# ==============================
# Nation splurges $126m on Cup
# ==============================
# Arrington out 2-4 weeks
# ==============================
# Police charge 19 after drug raids
# ==============================
# A-level top grade will need 90%
# ==============================
# Peoplesoft, Siebel predict rosy Q3
# ==============================
#  Baseball Cap Leads to Arrest in 1997 Slaying
# ==============================
# Bhutto&#39;s husband secures new bail
# ==============================
# Citi mulls cutting work force by 5 to 10 percent: report
# ==============================
# Iraq&#39;s deadly insurgency continues at a ferocious pace
# ==============================
# Reinsurer Munich Re's 2007 profit rises \
#     (AP)\
#
# ==============================
# Merrill chief&#x27;s merger proposal irked the board
# ==============================
# Hughes to Rejoin Cavaliers for Game 6 \
#     (AP)\
#
# ==============================
# Vista SP1 coming sooner for some
# ==============================
# US Military in Iraq Suffers Deadliest Month (Update1)
# ==============================
# Rapper&#39;s 7 children to share his money
# ==============================
# Research Firms Can&#39;t Get Enough Of AAPL
# ==============================
# Roche wins Ventana with raised $3.4 bln bid
# ==============================
# Novar close to Â£800m cash deal with US giant
# ==============================
# City, officer battle over 9/11 photos \
#     (AP)\
#
# ==============================
# British military plane crashes near Baghdad, as many as 15 dead (AFP)
# ==============================
# Ching Scores Late Goal To Give National Team 1-1 Tie
# ==============================
# Iran: Proposals won&#39;t stop nuclear program
# ==============================
# Will the iPhone violate GPL 3?
# ==============================
# WRAPUP-1-Glamour ties dominate Champions League draw
# ==============================
# Royals rip Yankees for 17-8 win
# ==============================
# U.S. military deaths in Iraq at 3,117 \
#     (AP)\
#
# ==============================
# Huawei wins 3G contract from Telfort
# ==============================
# CORRECTED - US Treasury&#39;s Snow-Tax code overhaul a priority
# ==============================
# Israeli Troops Raid Nablus, Jenin, Kill 11 Palestinians
# ==============================
# Sony promises more games to boost PS3 demand
# ==============================
# Crude Oil Surges 33.6 Percent in 2004
# ==============================
# Kremlin dark horse is Russia&#39;s new oil tsar
# ==============================
# Wariner leads 400 sweep while destroying stereotypes
# ==============================
# Look to 8-Ks for Exec. Benefit Details
# ==============================
# Stanford rolls to 43-3 football win
# ==============================
#  Citigroup Profits Jump 18 Percent in 2Q
# ==============================
# Huygens probe may inform about Saturn&#39;s moon
# ==============================
# At least 500 dead in Philippines storms
# ==============================
# Nokia&#39;s Series 80 handsets to include Blackberry software
# ==============================
# Brazilian Attacked During Men&#39;s Marathon
# ==============================
# Consumer Group Calls for Probe of &#39;Rip-Off&#39; ITunes
# ==============================
# &#39;Why the Bombings?&#39; Ask Bangladesh Protesters
# ==============================
# Bus Collision in Afghanistan Kills 40
# ==============================
# US worker survives 47-storey fall
# ==============================
# U.S. Census Bureau Daily Feature for May 29
# ==============================
# Australian PM calls election on Oct. 9
# ==============================
# Off the Charts: Good news about the U.S. trade deficit &#x2014; or is it?
# ==============================
# G-7 finance ministers meet in Washington; China agrees to work on <b>...</b>
# ==============================
# THE OLYMPICS 2004: MODERN PENTATHLON: HARLAND BRONZED
# ==============================
# Cold Reception For Scott&#39;s Mother
# ==============================
# Army Official Requests Probe of Halliburton Contracts (Update5)
# ==============================
# Probe says Black 'looted $400m'
# ==============================
# Fed raises rates in U.S. for a 6th time, to 2.5%
# ==============================
# '300' becomes 2007's 1st blockbuster \
#     (AP)\
#
# ==============================
# Car Blast Kills 2 Palestinians in W.Bank-Witnesses (Reuters)
# ==============================
# IPO Gives 17 Percent Hike to Shares at DivX
# ==============================
#  Intel Raises 3Q Sales Outlook
# ==============================
# New bird flu strain &#39;will be worse than Sars&#39;
# ==============================
# Update 23: Crude Prices Stay Above $50 Per Barrel
# ==============================
# Highlights from the SEW Blog: May 29, 2007
# ==============================
# 7 Growth Stocks on Sale
# ==============================
# Alcoa, others buying pipeline for $1.3B
# ==============================
# Iraqi Airways Resumes Int&#39;l Flights
# ==============================
# 14 Palestinian Militants Killed in Gaza
# ==============================
# Four key steps in Murdoch&#39;s US march
# ==============================
# Russia&#39;s Putin Calls US Policy &#39;Dictatorial&#39;
# ==============================
# A TEST IN SPACE: Redford Township school&#39;s experiments to be <b>...</b>
# ==============================
# Europeans To Make Iran &#39;Last Offer&#39; On Nukes
# ==============================
# Kelly&#39;s greatest triumph
# ==============================
# ICI rejects $14.2 bln Akzo Nobel bid approach
# ==============================
# US stocks remain lower after Greenspan&#39;s comment
# ==============================
# VimpelCom Hit With &#36;157M Back Tax Claim (AP)
# ==============================
# Musgrave Announces Earmarks for 2007
# ==============================
# Magan scans Sainsbury&#39;s
# ==============================
# 2 Americans, 4 Afghans killed in bombing \
#     (AP)\
#
# ==============================
# Clemens May Take His 7 Cy Youngs and Go Home
# ==============================
# Anita Roddick, Body Shop Founder, Dies at 64
# ==============================
# 18 Terror Suspects Nabbed in France Sting (AP)
# ==============================
# Violence in Iraq leaves at least 51 dead \
#     (AP)\
#
# ==============================
# Soccer - Croatia 2, Bulgaria 2
# ==============================
# Brazil beats U.S. 4-2 in exhibition \
#     (AP)\
#
# ==============================
# Movie review: Animated &#39;Shark Tales&#39; is a good bet for families
# ==============================
# Spurrier to Florida: Don&#39;t look back
# ==============================
# Comic Rodney Dangerfield dies at 82
# ==============================
# ADV: Free 4-Room Digital Satellite System
# ==============================
# In the &#39;Phantom&#39; Movie, Over-the-Top Goes Higher
# ==============================
# Asthma risk &#39;exacerbated by house air fresheners&#39;
# ==============================
# Kobe Bryant prosecutors lose their bid to bar testimony on victim&#39;s sex life
# ==============================
# Japan PM Says Won&#39;t Pull Troops Out of Iraq -Media
# ==============================
# Eisner&#39;s challenge in court is to field tough questions
# ==============================
# UPDATE 1-Pathmark loss widens, hires investment bank
# ==============================
# Clinical Trials Update: July 11, 2007 \
#     (HealthDay)\
#
# ==============================
# CRICKET: ENGLAND V ZIMBABWE, EDGBASTON, TODAY: FANS SHUN ENGLAND&#39;S <b>...</b>
# ==============================
# NASA Capsule Containing Solar Wind Particles Crashes (Update1)
# ==============================
# SBC, Microsoft in $400 mn IP-based TV deal
# ==============================
# Storms kill 36 in India, wreak havoc in financial capital \
#     (AFP)\
#
# ==============================
# Militants kill 3 foreigners in Iraq city
# ==============================
# 13 dead in fresh wave of Iraq violence
# ==============================
# France rallies to beat Spain 3-1 \
#     (AP)\
#
# ==============================
# Nokia Posts Drop in 3Q Earnings, Sales (AP)
# ==============================
# Bike bomber targets police recruits, kills 24
# ==============================
# NBC Names Trump's 18 New 'Apprentice' Candidates
# ==============================
# Three important tasks of Chirac&#39;s visit to China
# ==============================
# 50 Iraq Soldiers Apparent Ambush Victims
# ==============================
# AMD invests $7.5 million in Transmeta
# ==============================
# Duke hits longest skid in 11 seasons \
#     (AP)\
#
# ==============================
# O's Lose 10th Straight
# ==============================
# Red Sox beat Rivera, Yankees to pull within 2 1/2
# ==============================
# $31.5M Online Gambling Settlement
# ==============================
# Langer&#39;s calming influence
# ==============================
# Music industry overstates threat of P2P piracy
# ==============================
# Kahne ends Johnson's Coca-Cola 600 reign \
#     (AP)\
#
# ==============================
# An Ex-Officer Now Believes Guard Memo Isn&#39;t Genuine
# ==============================
# Clemens nabs 7th Cy Young
# ==============================
# Solaris 10 Released, Updated &amp; Free (Like Speech)
# ==============================
# Deutsche Bank sells 109 properties to Eurocastle Investment (AFP)
# ==============================
# Eddie: &#39;Ford&#39;s behaviour is appalling&#39;
# ==============================
#  Sun Devils Reach Pac-10 Championship
# ==============================
# Kodak to Shut 3 European Labs (Reuters)
# ==============================
# Bomb at Iraqi Shiite shrine Kills 7, wounds 32
# ==============================
# Nanny May Have Been Kerik&#39;s Least Problem
# ==============================
# Harley-Davidson Posts Higher 3Q Profits
# ==============================
# NBA Wrap: Spurs Top Mavs for 11th Straight Home Win
# ==============================
# Googleâs SearchMash : Google 2.0
# ==============================
# Coalition forces kill 20 insurgents \
#     (AP)\
#
# ==============================
# SAD HOME BECOMES A MOURNERS&#39; MECCA
# ==============================
# Hansbrough powers top-ranked UNC to 14-0 \
#     (AP)\
#
# ==============================
# Colorado man says he commited 48 murders \
#     (AP)\
#
# ==============================
# Reeve&#39;s super courage inspiring
# ==============================
# Tsunami toll tops 16,400
# ==============================
# &#39;Psycho&#39; star Janet Leigh dies at 77
# ==============================
# IBM Sells PC Business for $1.75B
# ==============================
# 2 arrested in Indian courthouse blasts \
#     (AP)\
#
# ==============================
# Scientists build nanomachine envisioned 150 yrs ago
# ==============================
# Cashed-up Scott&#39;s Open pledge
# ==============================
# Largest IPv6 network launched in China
# ==============================
# Office Depot Says It Will Cut 900 Jobs
# ==============================
# Amtrak in Another Hole with $1.3 Bln Loss
# ==============================
# Cadbury salmonella bill hits Â£30m
# ==============================
# UPDATE 2-West Bromwich Albion part company with Megson
# ==============================
# Separatist attacks kill 57 in north-east India
# ==============================
# New Harry Potter Book Due July 16
# ==============================
# Kerry claims victory after Redskins&#39; loss
# ==============================
# Shell profit slips to 6.4 billion dollars as oil output declines \
#     (AFP)\
#
# ==============================
# Payton ... again Padre torments Schmidt, wasting No. 701 by Bonds
# ==============================
# Divisions over Iraq extend to 2008 race \
#     (AP)\
#
# ==============================
# 'Transformers' generates &#36;67.6 million \
#     (AP)\
#
# ==============================
# Hawks Top Pacers to Claim 5th in Row
# ==============================
# Walking May Protect Against Alzheimer&#39;s And Dementia
# ==============================
# Sony slashes price tag for delay-hit PlayStation 3 \
#     (AFP)\
#
# ==============================
# Campbell 9 Pct. Profit &#39;Hmmm Hmmm Good&#39;
# ==============================
# Delta Auditor Issues Doubt on Airline&#39;s Future
# ==============================
# Bush Recalls 9/11 Leadership with Victim Relatives (Reuters)
# ==============================
# Stover's 52-yard FG lifts Ravens \
#     (AP)\
#
# ==============================
# Dem Leader to Senate: Don&#39;t Buy Non-Refundable Tickets for August Break \
#     (CQPolitics.com)\
#
# ==============================
# Parents begin &#39;right-to-life&#39; bid
# ==============================
# Johnny Depp &#39;I enjoy Growing Old&#39;
# ==============================
# Sports: Patriots 24 Dolphins 10
# ==============================
# 2 Americans, a Briton kidnapped in Baghdad
# ==============================
# News Corp., Supersport Pay $323 Mln for Rugby Rights (Update1)
# ==============================
# Kenya poll violence deaths hit 300
# ==============================
# China rainstorms kill 55
# ==============================
# Pinegar TD Pass Drives Fresno to 37-34 Win Vs. Virginia
# ==============================
# '18 dead' after Iranian bombing
# ==============================
# Allyson Felix leads three Americans into 200 semis
# ==============================
# Intel to announce new 500 million-transistor chip
# ==============================
# US base in Mosul attacked, 22 die
# ==============================
# Dell 3Q Earnings Seen in Line With Views
# ==============================
# Sprint near deal to buy Nextel for $35 billion
# ==============================
# Larger cache to keep Pentium 4 competitive until arrival of dual <b>...</b>
# ==============================
# Knee op puts Man Utd&#39;s Saha out until November \
#     (AFP)\
#
# ==============================
# Telstra completes $750m buyback
# ==============================
# At least 66 killed in India train blast
# ==============================
# Order bars &#39;pay-to-play&#39; system
# ...
# ==============================
# 18 dead after Japanese earthquakes
# ==============================
# Softbank to raise $12 bln on Vodafone: source
# ==============================
# HTC to use Qualcomm chips in 10 handsets this year
# ==============================
# World growth highest since 1973
# ==============================
# Photos: Top 10 reviews of the week
# ==============================
# Hopefuls begin to dream of Euro 2008 with one year to go
# ==============================
# Enjoy Being a Girl? De la Renta&#39;s Your Guy
# ==============================
# Allawi&#39;s Female Relatives Released By Captors
# ==============================
# Three men guilty of botched 2005 London bomb plot
# ==============================
# From Near Death to an $8.2 Billion Deal
# ==============================
# Green&#39;s Bhs Department Stores Make Record Profit (Update1)
# ==============================
# 8 oil pipelines sabotaged in southern Iraq: TV
# ==============================
# Britain &#39;did not disclose warning of coup plot&#39;
# ==============================
# Cigarette Makers Strengthen No 1 Status
# ==============================
# Early Visual Studio 2008 to bolster Vista?
# ==============================
# U.S. Military Deaths in Iraq Pass 1,000
# ==============================
# Worst Stock for 2008: Amazon.com
# ==============================
# Update 8: Crude Futures Change Little
# ==============================
# Troops seal off Pakistani mosque after 11 killed
# ==============================
# Afghanistan hostages &#39;call home&#39;
# ==============================
# Norodom Sihamoni crowned Cambodia&#39;s new king
# ==============================
# Music pioneer Ahmet Ertegun dies at 83 \
#     (AP)\
#
# ==============================
# Continental cuts 425 jobs
# ==============================
# Private rocket&#39;s wild ride lands it closer to big prize
# ==============================
# Serbia to offer Kosovo 95 pct autonomy \
#     (AP)\
#
# ==============================
# In '08, a curtailed agenda for Congress
# ==============================
# MSN streams Live Earth to 8 million people
# ==============================
# Frontier justice won&#39;t stop the spam
# ==============================
# Blast in Afghanistan kills 2, injures 48 \
#     (AP)\
#
# ==============================
# British World War II hero dies at age 87 \
#     (AP)\
#
# ==============================
# Parliament will decide if troops stay into 2005
# ==============================
# Graner Gets 10 Years in Iraq Prison Abuse (AP)
# ==============================
# Montreal at San Francisco, 7:05 PM
# ==============================
# UPDATE: Australia&#39;s Orica Triples FY Net To A$327.8M
# ==============================
# How to Achieve 20% Yields
# ==============================
# KMart Same-Store Sales Fall 4.6 Pct (Reuters)
# ==============================
# 5 More Top Growth Stocks
# ==============================
# My No. 1 Top Holding
# ==============================
# Mexican firm bids Â£2.3bn for RMC
# ==============================
# Google Results Revive &#39;Dot-Com&#39; Fervor
# ==============================
# Strike to go ahead despite arrest of Nigeria&#39;s union leader
# ==============================
# Chalmers, No. 10 Kansas beats Ball St. \
#     (AP)\
#
# ==============================
# Road Trip 2007: Hoover Dam and the Grand Canyon
# ==============================
# Deutsche Boerse to buy 5 percent stake in Mumbai stock exchange \
#     (AFP)\
#
# ==============================
# US Says Over 100 Arrested in Internet Crime Sweep
# ==============================
# Mortgage Applications Off in Aug. 20 Week (Reuters)
# ==============================
# California Pizza Boosts 3Q Outlook
# ==============================
# Microsoft&#39;s Passport to be tossed by eBay
# ==============================
# Don&#39;t view that image, it may have hidden code
# ==============================
# ADV: $2400 Scholarship
# ==============================
# Congress approves $800B increase in federal debt
# ==============================
# UPDATE: Australia&#39;s Fortescue Signs China Railway Group
# ==============================
# 15 U.S. Agencies Told to Share Earth Data (AP)
# ==============================
# France's $7.2 Billion Hit
# ==============================
# Linux available on ThinkPad T61 and R61
# ==============================
# Klitschko wins in 8th
# ==============================
# Early Success For Â£140bn Fighter Project
# ==============================
# CEA announces 2008 CES celeb lineup
# ==============================
# 50 Suspects Detained in Najaf Bombing
# ==============================
# 50 Cent Lamborghini ride leads to ticket \
#     (AP)\
#
# ==============================
# Toshiba Wins HD DVD Support from 4 in Hollywood
# ==============================
# Hartford executive&#39;s stock sale probed
# ==============================
# &#39;Iran producing uranium feed to make bomb&#39;
# ==============================
# Spain Arrests 11 Suspected Militants
# ==============================
# U.S.: 60 pct of Baghdad not controlled \
#     (AP)\
#
# ==============================
# Vodafone Targets 10 Million 3G Wireless Users by 2006 (Update2)
# ==============================
#  Citigroup Posts $10B Quarterly Loss
# ==============================
# Manchester United Receives &#39;Preliminary Approach&#39; For Financial <b>...</b>
# ==============================
# Blair: Iraq report shows sanctions weren&#39;t working
# ==============================
# Fall Out Boy Hosts Video 6 Pack on the Heels of Their Latest Album Release
# ==============================
# Barbra Streisand launches first U.S. tour since '94 \
#     (Reuters)\
#
# ==============================
# Google B&#39;lore to be &#39;ideas&#39; centre
# ==============================
# Parker: &#39;Rathergate&#39; illustrates the promise of blogs
# ==============================
# Sleeping bus driver crashes vehicle in Iran, killing 24 passengers
# ==============================
# Ken Caminiti, Former NL MVP, Dies of Heart Attack at Age 41
# ==============================
# Eisner: Trial Begins Re Disney&#39;s Ovitz Compensation
# ==============================
# Musharraf says he&#39;ll stay as Pakistan&#39;s army chief, president
# ==============================
# Wal-Mart Earnings Climb 13 Percent
# ==============================
# 30 killed, 65 wounded in Najaf bomb blast
# ==============================
# Al-Qaeda suspect Farooqui&#39;s Killing &#39;Major Success&#39;
# ==============================
# Amsterdam home of Ken Bigley&#39;s brother raided
# ==============================
# Jennings: I lost on &#39;Jeopardy!&#39;
# ==============================
# Man bids 9.6bn euros for Scania
# ==============================
# Federal inmate 55170-054 Martha Stewart checks in
# ==============================
# <em>Manhunt 2</em> rated 18+ in US
# ==============================
# 2003 Crime Rate Steady at 30-Year Low (AP)
# ==============================
# MSN vs. Apple &#39;Spotlight&#39;
# ==============================
# AIG earnings fall 29 percent \
#     (Reuters)\
#
# ==============================
# Ky. mines yield over 100 faulty air packs \
#     (AP)\
#
# ==============================
# Fire at California's Lake Tahoe destroys 50 homes
# ==============================
# Polls Show Nov. 2 Race Even as Bush Bounce Fades (Reuters)
# ==============================
# W&amp;D buys another 40 sites
# ==============================
# No Shortage of 411 on iPhone -- Apple PR Blitz Keeps Market on Toes; Early Reviews to Push Stocks
# ==============================
# Uefa Cup: Newcastle 2 - 1 Celta Vigo
# ==============================
# Minimum wage increases to Â£5.35
# ==============================
# 4 flamingos found dead at zoo in Germany \
#     (AP)\
#
# ==============================
# Scania rejects Man bid of 9.6 billion euros \
#     (AFP)\
#
# ==============================
# Henry scores two as Arsenal crushes Charlton 4-0
# ==============================
# Publisher sues Imus for more than $4M \
#     (AP)\
#
# ==============================
# Afghan President Campaigns; 7 Killed by Mine
# ==============================
# OPEC may raise output at Feb 1 meet: Indonesia OPEC gov \
#     (Reuters)\
#
# ==============================
# Abbas Assails 'Zionist Enemy' After Tank Kills 7
# ==============================
# Google opens up 200 years of news
# ==============================
# Militants Kill 7 Abducted Iraqi National Guards - Web
# ==============================
# Analyst sees iPod delay, Apple dips to 8-month low \
#     (Reuters)\
#
# ==============================
# Cowboys&#39; Darren Woodson retires
# ==============================
# It&#39;s UC-Marshall at Fort Worth
# ==============================
# Haitian death toll rises to 1,500
# ==============================
# Clintons to be honored at VH1 gala \
#     (AP)\
#
# ==============================
# Tokyo&#39;s defence review names China and North Korea as security <b>...</b>
# ==============================
# EarthLink to Test Yahoo&#39;s Antispam Technology
# ==============================
# Hungary to remove 300 troops
# ==============================
# Airbus to bid for Â£13 bn US tanker contract
# ==============================
# 2 lanes of I-70 reopen; repair to take months
# ==============================
# Beckham unable to lift Galaxy in 3-0 defeat
# ==============================
# CA Sales Head to Pay $29.7M in Restitution
# ==============================
# NFL: Tennessee Titans Crush Green Bay 48-27
# ==============================
# Weapons that weren&#39;t
# ==============================
# Tuesday Morning Lowers 2004 Guidance
# ==============================
# Review: SimpleTech USB 2.0 1TB external hard drive
# ==============================
# Thieves steal paintings worth over $160 million in Zurich: police \
#     (AFP)\
#
# ==============================
# Ford U.S. January sales down 19 pct
# ==============================
# Clinton: Angiogram &#39;probably saved my life&#39;
# ==============================
# Jan. 22, 1980: Sakharov Carries His Dissent Into Exile
# ==============================
# Orbach was &#39;Law &amp; Order&#39; star
# ==============================
# Echoes of Iraq: 3 kidnapped in Kabul
# ==============================
# Geiberger Holds On For First Victory Since 1999
# ==============================
# Manufacturers 'could cut 22,000'
# ==============================
# Briefly: ContextWeb nabs $3 million
# ==============================
# Hershey Profit Tumbles 66 Percent
# ==============================
# Trail Blazers Win 13th Game in a Row
# ==============================
# Shorthanded Mizzou upsets No. 22 K-State \
#     (AP)\
#
# ==============================
# 3 indicted in Norwegian terror case \
#     (AP)\
#
# ==============================
# Finland to eliminate infantry land mines by 2016; defence personnel...
# ==============================
# US Air Strike Kills 11 in Iraq&#39;s Falluja
# ==============================
# Siemens Claims Solution to 802.11n Power Problem
# ==============================
# Boozer gives Utah's Sloan No. 999 \
#     (AP)\
#
# ==============================
# Ogden Signs 7-Year Contract With Ravens (AP)
# ==============================
# No. 21 Oklahoma Drubs Akron 88-40 (AP)
# ==============================
# Duke Wilts at Wake Forest, Ending a 12-Game Win Streak
# ==============================
# Cast of Broadway&#39;s Bombay Dreams Takes Part in Tsunami Relief <b>...</b>
# ==============================
# Marine accused of 2004 desertion fails again to report for duty
# ==============================
# Bryant hits season-high 52 points as Lakers crush Jazz
# ==============================
# 21 killed in Kazakhstan mine blast
# ==============================
# Wakefield to start World Series Game 1
# ==============================
# For 1,000 Troops, There Is No Going Home
# ==============================
# Lawyer Mills and Italy&#39;s Berlusconi go on trial \
#     (AFP)\
#
# ==============================
# Float to help pay for Vector&#39;s takeover attempt
# ==============================
# Clashes in Gaza Kill at Least 7
# ==============================
# 10,000 miles on overseas flights
# ==============================
# 9 at the Movies
# ==============================
# Â£700m valley village plan revived
# ==============================
# Disease cited in White&#39;s death is usually not lethal, experts say
# ==============================
# Heart Scare Questions Tony Blair&#39;s Future
# ==============================
# Moore&#39;s planned TV broadcast of &#39;Fahrenheit 9/11&#39; an Oscar gamble
# ==============================
# &#39;Bangladesh were never in the game&#39;
# ==============================
# UEFA Cup: Sporting gains 1-1 tie to join Newcastle in next round
# ==============================
# U.S.: 109 insurgents killed
# ==============================
# Williams deny BAR&#39;s accusation
# ==============================
# "27 Dresses" a bad fit for Katherine Heigl \
#     (Reuters)\
#
# ==============================
# Frankie Laine dead at 93
# ==============================
# Total Lunar Eclipse: October 27/28
# ==============================
# ADV: Try Currency Trading Risk-Free 30 Days
# ==============================
#  Toyota Worldwide Hybrid Sales Top 1M
# ==============================
# Big day in Little Rock for 42nd president
# ==============================
# Canada, US skate to 1-1 draw at Four Nations Cup
# ==============================
# Off 5th in 100 Oaks to close in January
# ==============================
# Three billion people could speak English by 2015: study (AFP)
# ==============================
# Blast Kills at Least 25 at Shiite Mosque
# ==============================
# Disaster claims 'less than $10bn'
# ==============================
# Tracking Weir&#39;s failed bid for glory
# ==============================
# Mortgage lender Alliance Bancorp files Chapter 7
# ==============================
# U.S. to Russia: Allofmp3.com closes door on your WTO chances
# ==============================
# ADV: $175,000 Mortgage for Under $730/Month
# ==============================
# Germans plan 578m-high Ã¼berpyramid
# ==============================
# Burmese PM &#39;removed from office&#39;
# ==============================
# 2-time champion Stewart misses Chase \
#     (AP)\
#
# ==============================
# Hitachi plans 500GB hard disk, largest ever
# ==============================
# Barrister gets Â£1.1m in  a year from legal aid
# ==============================
# Cleaners, Solvents May Raise Kids&#39; Asthma Risk
# ==============================
# Top End for No. 10 Cal Finally Healthy (AP)
# ==============================
# Sarajevo's war damage totaled $18.5 billion: study
# ==============================
# Dodgers edge Reds 6-5 in 16 innings \
#     (AP)\
#
# ==============================
# Tiger&#39;s&#39; caddie: Woods will return to top of his game
# ==============================
# Could Fly Factor Decide '08 Race?
# ==============================
# Kodak lawsuit cost Sun USD 92 millions
# ==============================
# No. 18 Louisville at No. 3 Miami
# ==============================
# Madonna Heading To Israel With Her &#39;Cult&#39; For Jewish New Year
# ==============================
# Sinopec, amid rising demand, posts 51% rise in net
# ==============================
# Robbers&#39; quandary: Getting rid of the cash
# ==============================
# Iraqi PM calls regional meeting for March 10
# ==============================
# Snowstorm dumps 4 inches an hour
# ==============================
# 49ers&#39; home to be renamed Monster Park after stereo cable company
# ==============================
# Storm Leaves 9 Injured at N.H. Campground (AP)
# ==============================
# Toshiba develops 100GB 1.8-inch HDD
# ==============================
# PepsiCo to build $170 mln Russia snack plant \
#     (Reuters)\
#
# ==============================
# Dow Industrials Close Above 14,000
# ==============================
# Romania look to Piturca for 2006 World Cup
# ==============================
# HBO is big Emmy winner with 32
# ==============================
# BlackBerry 7100t and SureType
# ==============================
# Update 12: Oil Prices Fall; Oil Stocks Rise in US
# ==============================
# Amazon offers discount to A9 search users
# ==============================
# Abbas Escapes Gunfire, Palestinians to Vote Jan. 9
# ==============================
# Dow Jones to buy MarketWatch for $519 mn
# ==============================
# IBM Says &#39;Go&#39; on Dual-Core Opteron Servers
# ==============================

# %%
import re

def titles_by_regex(titles, pattern):
    regex = re.compile(pattern, flags=re.IGNORECASE)

    count = 0
    matches = []
    for t in titles:
        if regex.search(t):
            matches.append(t)


    print(f"\nTotal matches: {len(matches)}")
    return matches

# %%
year_pattern = r"\b(19|20)\d{2}s?\b"
matches = titles_by_regex(titles_with_numbers, year_pattern)
# Out:
# Total matches: 933

# %%
for title in matches[:50]:
    print(title)
    print("="*30)
# Out:
# Yearender: Mideast peace roadmap reaches dead-end in 2004
# ==============================
# German Police to Drop 1970s Mustard/beige Uniforms (Reuters)
# ==============================
# Thai 2004 growth forecast cut to 6.0-6.5 percent as Q2 growth slows (AFP)
# ==============================
# Get Peachtree Pro Accounting 2008 free after rebate
# ==============================
# Ford 4th-quarter loss narrows; forecasts 2008 loss
# ==============================
# Best First Class 2004
# ==============================
# 2004 forecast raised on strength of &#39;The Incredibles&#39;
# ==============================
# Forecaster predicts busy 2007 U.S. hurricane season \
#     (Reuters)\
#
# ==============================
# Bonds used steroids in 2003, trainer says on recording
# ==============================
# 2010 World Cup the target as Burley takes charge of Scotland \
#     (AFP)\
#
# ==============================
# 2004 Presidential Endorsements (AP)
# ==============================
# Lilly sees slower profit growth in 2007
# ==============================
# Spaceflight to cost $40 million in 2009
# ==============================
# World briefs - November 30, 2004
# ==============================
# Sen. Brownback drops out of 2008 campaign \
#     (Reuters)\
#
# ==============================
# SideStep Named Momentum 2006 Company at the IBDNetwork Annual Momentum Growth Conference
# ==============================
# Aug. 15, 2004
# ==============================
# Go &quot;Dutch&quot; in 2005: Eat A Polymeal of Wine, Fish, Chocolate <b>...</b>
# ==============================
# Whatever Happened To . . .  The Stinky Effects of 1996 Chemical Leak?
# ==============================
# Rick Majerus Named USC Men&#39;s Basketball Coach For 2005-06 Season
# ==============================
# Music Review | Focus! 2008: Prototypically American, Atypically Challenging
# ==============================
# Anna Nicole's will, from 2001, released
# ==============================
# Home builder index lowest since Feb 1991: NAHB
# ==============================
# Down Democrats, Happy Republicans Look to 2008
# ==============================
#  Baseball Cap Leads to Arrest in 1997 Slaying
# ==============================
# Reinsurer Munich Re's 2007 profit rises \
#     (AP)\
#
# ==============================
# Crude Oil Surges 33.6 Percent in 2004
# ==============================
# THE OLYMPICS 2004: MODERN PENTATHLON: HARLAND BRONZED
# ==============================
# '300' becomes 2007's 1st blockbuster \
#     (AP)\
#
# ==============================
# Highlights from the SEW Blog: May 29, 2007
# ==============================
# Musgrave Announces Earmarks for 2007
# ==============================
# Clinical Trials Update: July 11, 2007 \
#     (HealthDay)\
#
# ==============================
# Divisions over Iraq extend to 2008 race \
#     (AP)\
#
# ==============================
# India's Mirage 2000 crashes during exercise with Singapore (Reuters)
# ==============================
# OPEC sees 1 million barrels per day demand drop in 2005
# ==============================
# Even the 1927 Yankees would be impressed
# ==============================
# G.M. Europe to Cut 12,000 Jobs by the End of 2006
# ==============================
# Microsoft promises new OS for 2006
# ==============================
# 2003 champ is Classic favorite
# ==============================
# Dell to Go 'Carbon Neutral' by Late 2008
# ==============================
# U.S. health-plan cost growth to tick up in 2008: survey
# ==============================
# APRIL 2000 SLAYING: Leaving U.S. may have saved life of suspect
# ==============================
# EU Lowers 2005 Growth Forecast to 2% on Surge in Oil Prices
# ==============================
# China says aircraft carrier possible by 2010: paper
# ==============================
# 'Sheba,' a 1950s drama of domestic discord, comes back to Broadway with S. Epatha Merkerson \
#     (AP)\
#
# ==============================
# Philip Morris lab discovered passive smoking risk in 1982: Lancet (AFP)
# ==============================
# Floods 'could be worse than 2001'
# ==============================
# E3 2007: Lucasarts' 'Thrillville' gets basic Windows Live features
# ==============================
# 2006: The year in security
# ==============================
# Bloomberg on 2008 race: Time to get real \
#     (AP)\
#
# ==============================

# %%
pct_pattern = r"(\b\d+(\.\d+)?\s?%)|(%\s?\d+(\.\d+)?\b)|\b\d+(?:\.\d+)?\s?percent(?:age)?s?\b"
# pct_pattern2 = r"\b(?:\d+(?:\.\d+)?\s?%|%\s?\d+(?:\.\d+)?|\d+(?:\.\d+)?\s?percent(?:age)?s?)\b"
titles = titles_by_regex(titles_with_numbers, pct_pattern)
# titles.append(titles_by_regex(titles_with_numbers, pct_pattern2))
for title in titles:
    print(title)
    print('='*30)
# Out:
# Total matches: 452
# Thai 2004 growth forecast cut to 6.0-6.5 percent as Q2 growth slows (AFP)
# ==============================
# US IT Spending to Grow 7% Next Year
# ==============================
# State-Owned Russian Bank Buys a 5% Stake in EADS
# ==============================
# Earnings Rise 24% at Kimberly-Clark
# ==============================
# CA cutting 5 percent of workforce
# ==============================
# Households face 15% jump in fuel prices
# ==============================
# CIT Group&#39;s Q3 profit up 25%, tops by a penny
# ==============================
# Heineken 1H profit rises 26 percent \
#     (AP)\
#
# ==============================
# Grass biofuels 'cut CO2 by 94%'
# ==============================
# Earnings Fall 32 Percent at Bank of America
# ==============================
#  Freddie Mac Profit Down 45 Percent in 2Q
# ==============================
# A-level top grade will need 90%
# ==============================
# Citi mulls cutting work force by 5 to 10 percent: report
# ==============================
# Crude Oil Surges 33.6 Percent in 2004
# ==============================
#  Citigroup Profits Jump 18 Percent in 2Q
# ==============================
# Fed raises rates in U.S. for a 6th time, to 2.5%
# ==============================
# IPO Gives 17 Percent Hike to Shares at DivX
# ==============================
# UPDATE 1-Perry acquires 9.89 percent stake in Mylan Labs
# ==============================
# Smithfield 2nd-Qtr Net Soars 61% on Higher Hog Prices (Update3)
# ==============================
# Durable goods orders slid 8.3 percent in Oct
# ==============================
# TXU quarterly earnings rise 33 percent
# ==============================
# Boston Scientific stock climbs 5%
# ==============================
# IMF sees Australian GDP up 4.4 percent \
#     (AP)\
#
# ==============================
# EU Lowers 2005 Growth Forecast to 2% on Surge in Oil Prices
# ==============================
# Bay State Gas seeks 10.2% rate cut over last winter
# ==============================
# Stocks drop 1 percent on Bear Stearns woes
# ==============================
# 9.7% consumption increase &quot;encouraging&quot;
# ==============================
# Ford U.S. May sales down 6.8 percent
# ==============================
# Study: Rate Of False Positive Mammograms Is 20%
# ==============================
# Biogen Takes Itself Off the Block After Failing to Sell High, and Shares Plunge 28%
# ==============================
# Target Q3 up 78%, lifted by Mervyn&#39;s sale
# ==============================
#  Metro Costs For Overtime Are Up 56% Since 2002
# ==============================
# EU new car sales down 1.3 percent in November: ACEA \
#     (Reuters)\
#
# ==============================
# UK set for 15% renewables target
# ==============================
# GDP revised downward to annual 0.2%
# ==============================
# Federal Reserve stuns markets with 0.75% rate cut
# ==============================
# Allianz 3Q Net Profit Dips 8 Percent (AP)
# ==============================
# LVMH First-Half Profit Advances 49% on Airport Stores (Update5)
# ==============================
# ArcelorMittal profit rises 27 percent, in line with analyst expectations
# ==============================
# Oil Minister: Saudi Arabia may boost capacity by 30%
# ==============================
# AstraZeneca to Cut 4.6% of Work Force
# ==============================
# New home sales fell 1.6 percent in May
# ==============================
# Mac market share breaks 8% mark in 2007's final days
# ==============================
# Heinz Profit Up 6 Percent, Lifts View
# ==============================
# Dow Chemicalâs Profit Falls 21.3%
# ==============================
# Wyeth Says It May Cut 10% of Jobs
# ==============================
# Geologists: 70 percent chance of eruption
# ==============================
# Global mobile handset sales up 35% in second quarter
# ==============================
# Dell to lay off 10 percent of workforce
# ==============================
# Brazil accounts for 3 percent of emissions of greenhouse gases in <b>...</b>
# ==============================
# Ahold Raises Stake in ICA to 60 Percent (AP)
# ==============================
# Medicare Part B Monthly Fee to Jump 17.4 Percent in 2005
# ==============================
# EMC Plans Public Offering for 10% of Software Division
# ==============================
# US retail sales rise 0.3 percent in January \
#     (AFP)\
#
# ==============================
# Nextel&#39;s Profit Rose by 69% in 3rd Quarter
# ==============================
# UnitedHealth Profit Rises 22 Percent
# ==============================
# Oracle Raises PeopleSoft Bid by 14% to $8.8 Billion (Update5)
# ==============================
# DaimlerChrysler U.S. sales down 2 percent
# ==============================
# Nikkei Up 1.6 Percent by on Wall St Jump (Reuters)
# ==============================
# Toshiba Extends PMR to 'Short' 1.8-Inch Hard Disk Drive Family; Second-Generation 80GB PMR Drive Delivers 10 Percent Smaller Footprint and Industry's Highest Capacity in This Form Factor for CE and PC Devices
# ==============================
# McGraw-Hill Cos profit falls 31 percent \
#     (Reuters)\
#
# ==============================
# GE to sell 60% stake in Indian call center
# ==============================
# GE sells 60% of pioneering India division
# ==============================
# Cornice Cuts 30 Percent of Work Force
# ==============================
# Ford U.S. December U.S. sales down 9 percent
# ==============================
# Switzerland Raises Key Rates to 0.75 Percent on Increasing Recovery Signs
# ==============================
# Emerson earnings rise 35 percent \
#     (Reuters)\
#
# ==============================
# D.R. Horton Sales Orders Fall 40 Percent
# ==============================
# FedEx quarterly profit rises 4 percent
# ==============================
# Oracle profit increases 21%
# ==============================
# Hockey overnight rating down 12 percent \
#     (AP)\
#
# ==============================
# Consumer Spending Up 0.8 Percent in July
# ==============================
# US Airways&#39; pilots vote for 18% salary reduction
# ==============================
# Singapore Forecasts Growth of 5 Percent (AP)
# ==============================
# Johnson Controls reports 24% earnings increase
# ==============================
# Smart phones to make up 16% of market
# ==============================
# Newsroom Buyouts May Cut Dallas PaperÂs Staff by 20%
# ==============================
# Medicare Premiums To Rise By 17.5%
# ==============================
# Dow Chemical reports 86 percent increase in profit
# ==============================
# Chinese economy surges 9.5% in first 3 quarters
# ==============================
# About 62 percent of Delphi U.S. union workers opt out
# ==============================
# General Motors U.S. Sales Down 24 Percent in June
# ==============================
# IMF chief doubts French growth of 2.25 percent in 2008 \
#     (AFP)\
#
# ==============================
# Euro economy grew 2.7 percent last year
# ==============================
# GDP growth may slow to 6.5% : ADB report
# ==============================
# Tennessee Governor: Bredesen (D) 58%; Bryson (R) 31% \
#     (Rasmussen Reports)\
#
# ==============================
# China GDP growth to ease to 10.5 percent: researcher
# ==============================
# Foremost "Stock Alert" Service Completes Eighth Straight Month of 100% Perfect Picks
# ==============================
# Nordstrom 4Q profits rise 22 percent \
#     (AP)\
#
# ==============================
# NHL Players Offer 24 Percent Pay Cut to End Lockout (Update1)
# ==============================
# Corning Profit Rises 11 Percent
# ==============================
# Oil Prices Tumble Nearly 5 Percent
# ==============================
# Oil Minister: Saudi Arabia may boost capacity by 30%
# ==============================
# Nokia Reports 20 Percent Drop in Profit
# ==============================
# Eurozone interest rate up to 3.5%
# ==============================
# Cott Q3 profit falls 14%, 2004 profit target lowered; makes US <b>...</b>
# ==============================
# World Theme Park Attendance Up 2.2 Percent in '04
# ==============================
# JP Morgan to buy 50% of Cazenove for Â£100 mn
# ==============================
# Deutsche Boerse 'buys 5% of BSE'
# ==============================
# S&P 500 futures extend fall, down 5.3 percent
# ==============================
# US retail sales up 0.1 percent in November
# ==============================
# Travelocity Acquires the Remaining 50% of theTravelocity Europe Joint ...
# ==============================
# Mutual fund assets fall 2 percent in July
# ==============================
# Consumer Prices Surged 0.6 Percent in October
# ==============================
# Govt aims to raise FDI to GDP ratio to 22% in 3 years
# ==============================
# China Bosera Funds 48 percent stake sold in record deal \
#     (Reuters)\
#
# ==============================
# Woolworths Yearly Profits Up 12.3 Percent
# ==============================
# Citigroup profit rises 18 percent
# ==============================
# 70% of Websites at Immediate Risk of Being Hacked!
# ==============================
# Nike Profit Up 25 Percent on U.S. Demand
# ==============================
# Nintendo Operating Profit Up 39 Percent
# ==============================
# An aggressive Fed trims benchmark rate to 4.75%; first cut in four years
# ==============================
# SAP Reports 10% Profit Increase
# ==============================
# China Sinopec 1H Net Rises 51% To CNY16.15 Billion
# ==============================
# India's Net Service About 80 Percent Restored
# ==============================
# Medicine prices to fall 7 percent
# ==============================
# California Public Utilities Commission Raises UNE Rates by 20%
# ==============================
# Findings: In 2008, a 100 Percent Chance of Alarm
# ==============================
# Sharp profit down 12 percent on high materials cost
# ==============================
# USA : Christopher &amp; Banks comparable sales drop 7% in December
# ==============================
# Bank cuts interest rates to 5.25%
# ==============================
#  U.S. to Expand Outposts Across Baghdad by 30%
# ==============================
# Strong laptop demand drives Apple US retail share to 13%
# ==============================
# Profits Are Up 24% at Disney and So, It Says, Is Teamwork
# ==============================
# Survey: 58% of Investors Wouldn't Trade Online
# ==============================
# BT&#39;s Net Profit Rises 14 Percent
# ==============================
# New homes sales rise 16.2 percent in April \
#     (Reuters)\
#
# ==============================
# Wholesale Prices Rose 0.5% in November
# ==============================
# Stocks Extend Slide to Drop 1 Percent
# ==============================
# Third-Quarter Productivity Slows to 1.8%
# ==============================
# Motorola Profit Plunges 84%
# ==============================
# Takeovers drive profit at Oracle up 23%
# ==============================
# Offer gives Harmony 11% of Gold Fields
# ==============================
# Rambus stock falls 13% on appeal failure
# ==============================
#  Sony Cuts PS3 Price by 16.7 Percent
# ==============================
# Open Source Investment Rose 131% in 2006
# ==============================
# UK inflation rate slows to 1.8%
# ==============================
# Update 4: Walgreen Earnings Rise 18 Percent in 4Q
# ==============================
# 100 percent of people carry at least 1 type of pesticide
# ==============================
# Nextel 3Q Profits Increase 69 Percent (AP)
# ==============================
# U.S. Broadband Penetration Tops 51%
# ==============================
#  NVR Profit Falls by 30%, But New-Home Orders Up
# ==============================
# Eurozone rates stay fixed at 3.5%
# ==============================
# Erectile dysfunction affects 18 percent of men
# ==============================
# Nigerian stocks dip 0.4 percent \
#     (AFP)\
#
# ==============================
# Delta to Cut Employee Pay 10 Percent
# ==============================
# Monsanto Net Up 71%; Corn Seed Cited
# ==============================
# Walgreen profit jumps 25 percent \
#     (Reuters)\
#
# ==============================
# India's Infosys beats expectations with 25 percent profit jump \
#     (AFP)\
#
# ==============================
# Hasbro Net Surges 62 Percent
# ==============================
# Medicare Premiums to Rise 17 Percent
# ==============================
# Profit Rises 10% at Health Insurer
# ==============================
# Harmony Puts Brave Face On 11 Percent
# ==============================
# Costly defects lower profit 10% at Siemens
# ==============================
# Bank of England keeps interest rates at 4.75 percent (AFP)
# ==============================
# Sharp profit down 12 percent on high materials cost
# ==============================
# AT&T Profit Up 42% on Wireless Gains
# ==============================
# Post-merger work force at Cingular to shrink 10 percent
# ==============================
# Icahn raises bid 3.5% for auto parts maker Lear
# ==============================
# PeopleSoft fires its CEO; shares rise 15%
# ==============================
# Sony Profit Increases 25 Percent
# ==============================
# Profit at Biogen Rises 84% on 2 Drugs
# ==============================
# Electrolux stocks soar 20 percent on strong 2006 earnings \
#     (AFP)\
#
# ==============================
# Nasdaq rises by more than 1 percent
# ==============================
# EPA: 13 Percent of Airliner Water Unsafe
# ==============================
# US festive online spending up 19%
# ==============================
# Xerox Posts 79% Profit Increase
# ==============================
# Major Buys 40% Stake in Thai Ticket Master
# ==============================
# ReviewMe 50% Off Special
# ==============================
# Red Hat 3Q Profit Up 12 Percent
# ==============================
# Carmakers face 18% CO2 cut
# ==============================
# Countrywide August mortgage fundings slide 17 percent
# ==============================
# Wal-Mart Says Sept. Sales Up 2.3 Percent (Reuters)
# ==============================
# ConocoPhillips Annoucnes Tender to Buy 2.4% of Lukoil Shares
# ==============================
# Xserve shipments soar 119%; trend likely to continue
# ==============================
# IBM to take 5% of Lenovo to seal PC biz deal - report
# ==============================
# Harmony Gets 10.8 Percent of Gold Fields
# ==============================
# Database Demand Gives Oracle 16% Profit Rise
# ==============================
# Blue Chip panel puts U.S. recession odds at 50 percent \
#     (Reuters)\
#
# ==============================
# GM U.S. sales down 24 percent in June
# ==============================
# US consumer prices surge 0.6 percent, industrial output up
# ==============================
# S.African consumer confidence drops 11 percent: survey \
#     (AFP)\
#
# ==============================
# OECD foresees China&#39;s growth at 8 percent in 2005
# ==============================
# US Airways to cut pay by 21 percent; Delta warns it&#39;s near <b>...</b>
# ==============================
# European stock markets drop at open: London down 0.36 percent \
#     (AFP)\
#
# ==============================
# Triangle health-care costs up 17.3%
# ==============================
# Ford U.S. November sales down 10 percent
# ==============================
# DSW shares jump on 65 percent profit rise \
#     (Reuters)\
#
# ==============================
# FCC approves 30 percent limit on cable companies
# ==============================
# Hungarian jobless rate flat at 5.9 percent
# ==============================
# Delta Aims to Cut Jobs 12%, Drop a Hub and Reduce Pay
# ==============================
# Google shares soar 18 percent on first day
# ==============================
# Tokyo Stocks Finish 2.6 Percent Higher (AP)
# ==============================
# Update 6: US Airways May Slash Pay by 21 Percent
# ==============================
# ECB expected to hold rates at 4%
# ==============================
# Toshiba posts 25 percent Q3 profit drop
# ==============================
# Paducah Plant May Get Reprieve As USEC Delays Construction in Ohio: The Estimated Cost of the Centrifuge Plant Has Increased By 30 Percent to More Than $2 Billion.
# ==============================
# Update 1: AOL Users Report 75 Percent Less Spam
# ==============================
# Bank of America net sinks 95 percent
# ==============================
# PC Report: Enterprise, Notebook Sales Drive 12% Increase
# ==============================
# Nissan global output for April drops 21 percent \
#     (Reuters)\
#
# ==============================
# IMF pegs growth at 6.4%
# ==============================
# Sysco profit climbs 8 percent on sales
# ==============================
# '20% chlamydia rate' in young men
# ==============================
# McDonald's August same-store sales up 8.1 percent
# ==============================
# Core PCE index up 0.1 percent in July
# ==============================
# US economy to grow by 3.5 percent in 2005: White House (AFP)
# ==============================
# 9.3% economic growth for China in 2004 expected
# ==============================
# 37 percent of U.S. births out of wedlock \
#     (AP)\
#
# ==============================
# Iraqi oil exports rise by 9.2 percent \
#     (AP)\
#
# ==============================
# Fed Raises Rates Again, to 2%, and Sees No Reason to Stop
# ==============================
# Nasdaq up 1 percent
# ==============================
# Harvard fund soars 21.1 percent
# ==============================
# Campbell Soup Co. Profit Falls 20 Percent
# ==============================
# Wall St falls further, Nasdaq drops 1 percent
# ==============================
# Carmakers face 18% CO2 cut
# ==============================
# Intel: Processors to perform 300 percent better by 2010 \
#     (Macworld.com)\
#
# ==============================
# European cancer cases rise 10 percent in two years \
#     (AFP)\
#
# ==============================
# US August Home Resales Fall 2.7 Percent
# ==============================
# Get Ready for a 25% Drop
# ==============================
# Motorola 4Q profit falls 84 percent \
#     (AP)\
#
# ==============================
# MIT fund adds 22.1% from investments
# ==============================
# 2007 Kicks Off With Red Hot 100% Perfect Stock Picking
# ==============================
# Red Hat 3Q Profit Up 12 Percent
# ==============================
# Starbucks 1Q Earnings Rise 31 Percent (AP)
# ==============================
# Russian government to control 15% of country&#39;s oil production
# ==============================
# Consumer Prices Rise 0.8% in November
# ==============================
# Massive floods hit 75% of Jakarta
# ==============================
# Vivendi to Sell 15 Percent Stake in Veolia (AP)
# ==============================
# Nike Profit Up 25 Percent on US Demand
# ==============================
# Lenders scrap 125% mortgage deals
# ==============================
# American Express profit falls 10 percent
# ==============================
# AstraZeneca to take 20% Cambridge Antibody stake
# ==============================
# New home sales plunge a record 26 percent in '07
# ==============================
# Durable goods orders slid 8.3 percent in Oct \
#     (Reuters)\
#
# ==============================
# FBI Says: Violent Crime Falls 3 Percent (AP)
# ==============================
# China Eastern sells 24 percent stake \
#     (AP)\
#
# ==============================
# Electronic Arts buys 20% stake in Ubisoft
# ==============================
# Lehman Brothers Profit Climbs 27%
# ==============================
# Super distributor Ingram to own 35 percent [updated]
# ==============================
# US Forces Hold 70 Percent of Fallujah
# ==============================
# Earn 100% Per 3 Days
# ==============================
# Oil Steadies After 6 Percent Dive
# ==============================
# Libya cuts illiteracy rate to 11.9 percent: census
# ==============================
# Cost of living soars 66 percent in Zimbabwe \
#     (AFP)\
#
# ==============================
# MG Rover to slash directors&#39; pension payments by 90%
# ==============================
# HBOS profit climbs 19% to Â£5.7bn
# ==============================
# US consumer prices rise 0.2 percent in September
# ==============================
# BT profit dives 75 percent in third quarter \
#     (AFP)\
#
# ==============================
# U.S. Health Care Spending Up 7.7 Percent in 2003
# ==============================
# NTT posts 3.1 percent gain in first-half net profit (AFP)
# ==============================
# ECB Cuts 2005 Growth Forecast to 1.9%, Person Says (Update2)
# ==============================
# In Search of 12.14% Yields
# ==============================
# Online ads surge 40 percent in Britain -- trade group \
#     (Reuters)\
#
# ==============================
# Brussels cuts fishing quotas by 10%
# ==============================
# South Carolina: Obama 43% Clinton 28% Edwards 17% \
#     (Rasmussen Reports)\
#
# ==============================
# Warburg to pick up 2.75% in Kotak Mahindra
# ==============================
# Nike sees 47% profit surge
# ==============================
# 9% of U.S. Kids Have ADHD \
#     (HealthDay)\
#
# ==============================
#  General Dynamics 3Q Earns Up 24 Percent
# ==============================
# Albertsons&#39; profit falls 36 percent
# ==============================
# Lehman Brothers&#39; Profit Up 5.2 Percent
# ==============================
# Japan May core machinery orders up 5.9 percent
# ==============================
# Death knell for 125% mortgages?
# ==============================
# Online sales continue to rise, up 23.1% from a year ago
# ==============================
# Audits of wealthy rise 40%
# ==============================
# UK rates unchanged at 4.75%
# ==============================
# Toyota Motor interim net profit up 11.4 percent to hit record high
# ==============================
# Durable Goods Orders Up 0.2 Percent
# ==============================
# Stryker quarterly earnings rise 21 percent
# ==============================
# Gateway Casinos controlling shareholders sell 25% of casino <b>...</b>
# ==============================
# Intel revenue up 5 percent
# ==============================
# Pak-British trade rise 8% in nine mths
# ==============================
# UK cinema attendance down by 5%
# ==============================
# Yukos shares plunge more than 30 percent
# ==============================
# Economic Growth 5.87 Percent for Taiwan
# ==============================
# Chip Maker Reports Profit Rose by 13%
# ==============================
# BA Profits Up 35% At Â£788m
# ==============================
# 50 percent support president; 41 percent support senator
# ==============================
# Ryanair sees profits rise 15 percent
# ==============================
# CORRECTED: National City net sinks 80 percent on mortgages
# ==============================
# British Airways profit up 28.5 percent in first 9 months
# ==============================
# MarvellÂs News Sends Shares Down 12%
# ==============================
# VF Corp sees 10 percent profit growth in 2008
# ==============================
# Shares in AXA Plummet 10 Percent
# ==============================
# Zimbabwe inflation nears 1,600 percent \
#     (AFP)\
#
# ==============================
# Novartis's 3Q Profit Climbs 21 Percent
# ==============================
# Wyeth Posts 19% Higher Profit; 2 Rivals Fare Less Well
# ==============================
# Nikkei Falls 1 Percent (Reuters)
# ==============================
# A 12% Jump in Profit at American Express
# ==============================
# US Forces Hold 70 Percent of Fallujah
# ==============================
# Oil drops 2 percent on recession fears
# ==============================
# Anheuser-Busch Profit Rises 11%
# ==============================
# US economy increases 3.3 percent in second quarter
# ==============================
# Economy Grows at 3.3 Percent Rate in 2Q (AP)
# ==============================
# Ford Web Traffic Up 70% and Dealer Inventory Searched Grew 100% With New Promotion; Record Web Traffic on Ford, Lincoln and Mercury Dealers Network of Web Sites
# ==============================
# Hockey overnight rating down 12 percent \
#     (AP)\
#
# ==============================
# US economy expands 3.9 percent in third quarter (AFP)
# ==============================
# Omnicom quarterly profit up 10 percent
# ==============================
# German Growth Slowed to 0.1 Percent in Third Quarter as Exports Weakened
# ==============================
# Best Buy Profit Soars 52%
# ==============================
# Study predicts 75 percent overweight in U.S. by 2015 \
#     (Reuters)\
#
# ==============================
# Intel slashes 10% of global jobs
# ==============================
# PC Shipments Rise 12 Percent Worldwide (Reuters)
# ==============================
# Massachusetts Governor: Patrick (D) 57% Healey (R) 24% Mihos (I) 9% \
#     (Rasmussen Reports)\
#
# ==============================
# Consumer Prices Rise 0.8% in November
# ==============================
# 40% of teens want plastic surgery
# ==============================
# Federal Reserve lifts target rate to 2.25%
# ==============================
# Producer prices soar 3.2 percent in November
# ==============================
# Firefox Nears 30 Percent Market Share in Europe
# ==============================
# Export orders for new Harry Potter rose 17%
# ==============================
# May durable goods orders fell 2.8 percent \
#     (Reuters)\
#
# ==============================
#  New-Home Sales Plunge by 9 Percent
# ==============================
# Report claims 16.4% of all Xbox 360 consoles will fail \
#     (Macworld.com)\
#
# ==============================
# Country Music Sales Up 12 Percent in 2004 (AP)
# ==============================
# KfW to sell stake of around 7% in Deutsche Telekom
# ==============================
# Bank of England holds interest rate at 5.00 percent \
#     (AFP)\
#
# ==============================
# Broadband usage jumps 38 percent
# ==============================
# Russian government to control 15% of country&#39;s oil production
# ==============================
# Oracle Q1 net up 16%
# ==============================
# Northrop Q3 profit up 51 percent
# ==============================
# London shares close lower as BoE rate stays at 5.5 percent \
#     (AFP)\
#
# ==============================
# Zimbabwe's inflation tops 1,200%
# ==============================
# Singapore Forecasts Growth of 5 Percent (AP)
# ==============================
# Cingular To Cut 10 Percent of Workforce (NewsFactor)
# ==============================
# Poll: 9 percent of cell phone users want iPhone
# ==============================
# Eurozone industrial production up 0.4 percent in July (AFP)
# ==============================
# National City profit sinks 80 percent on mortgages \
#     (Reuters)\
#
# ==============================
# Nokia profit falls 20 percent on price cuts
# ==============================
# Singapore economy may grow by 8% despite high oil prices
# ==============================
# In 2008, a 100 Percent Chance of Alarm
# ==============================
# N.H.L. Players Propose a 24 Percent Solution
# ==============================
# Paris Club cuts 80 percent of Iraq&#39;s debt
# ==============================
# KMG Chemicals Announces First Quarter Net Income Up 111% Over <b>...</b>
# ==============================
# ANZ Australia Newspaper Job Ads +5.0% In Oct Vs Sep
# ==============================
# Global PC Shipments Up 12 Percent
# ==============================
# British Gas Plans Inflation-Busting Rises Of 15%
# ==============================
# Social Security Gets 2.7 Percent Boost
# ==============================
# Producer prices fell 0.6 percent in January
# ==============================
# Apple's iPhone profit margin greater than 50 percent
# ==============================
# 3M Could Grow Earnings 20%-22% In 2004
# ==============================
# French economy likely to grow close to 2.5 percent in 2006: central bank chief \
#     (AFP)\
#
# ==============================
# Profit at Qwest Increases by 89%
# ==============================
# Airfares Up 5.8% for the Holidays
# ==============================
# Neptune Orient Lines Profit Up 13 Percent
# ==============================
# November layoffs rise by 11 percent: survey
# ==============================
# Delta chief orders 10% pay cuts
# ==============================
# UnitedHealth quarterly profit rises 3 percent
# ==============================
# Report: SP2 Problems Impact 10 Percent of Windows XP PCs (NewsFactor)
# ==============================
# Illinois Governor: Blagojevich (D) 48%; Topinka (R) 36% \
#     (Rasmussen Reports)\
#
# ==============================
# California West Nile virus cases up 46 percent over last week
# ==============================
# Oil down 3.5 percent as OPEC signals stable output
# ==============================
#  Toll Brothers Profit Down 44 Percent
# ==============================
# Indonesian Shares Open +1.5% After Peaceful Elections -2-
# ==============================
# 2008 Democratic Presidential Primary: Clinton 34% Obama 26% Edwards 15% \
#     (Rasmussen Reports)\
#
# ==============================
# Holiday chaos averted as BA unions agree 8.5% deal
# ==============================
# Alaska Airlines slashing 8 percent of work force
# ==============================
# Cost cuts lift 2nd-half profit 12% at Woolworths
# ==============================
# U.S. stocks spike; Nasdaq ends up more than 1 percent
# ==============================
# US Airways to Ask Court to Cut Union Workers' Pay 23%
# ==============================
# Halo 3 Purchased by 52% of all Xbox 360 Owners
# ==============================
# Yuschenko expects to win over 60% of votes on December 26
# ==============================
# US raises interest rates to 2.25%
# ==============================
# August new home sales rose 4.1 percent
# ==============================
# BHP profit rises 78% on Chinese demand
# ==============================
# Fed Raises Interest Rate a 5th Time, to 2.25 Percent
# ==============================
# Oracle Secures Nearly 61% PeopleSoft Shareholder Backing
# ==============================
# Agreement reached to forgive 80 percent of Iraq&#39;s debts
# ==============================
# Searching for 40,000% Returns
# ==============================
# NPD: Early boxed retail sales of Vista down nearly 60% compared to XP
# ==============================
# U.S. Album Sales Fell 9.5% in 2007
# ==============================
# Mosul Forces Secure 75 Percent of Police Stations, US Says
# ==============================
# Honda exec sees 3 percent rise in 2007 U.S. sales
# ==============================
#  China's Trade Surplus Jumps 33 Percent
# ==============================
# Eurozone retail sales rise 0.7 percent in October (AFP)
# ==============================
# Cognizant 3Q Profit Jumps 63 Percent
# ==============================
# Global mobile handset sales up 35% in second quarter
# ==============================
# October U.S. Games Sales Up 35 Percent
# ==============================
# Surging Oil Prices Lift BP&#39;s Quarterly Profit 43%
# ==============================
# German GDP Grows in 2004 by 1.7 Percent (AP)
# ==============================
# University chiefs get 7.9% rises
# ==============================
# Alaska Governor: Palin (R) 52% Knowles (D) 38% \
#     (Rasmussen Reports)\
#
# ==============================
# Unemployment Drops to 5.4 Percent
# ==============================
# Prescription drug sales rise 8.3 percent \
#     (AP)\
#
# ==============================
# Brown-Forman Earnings Jump 67 Percent
# ==============================
# Wal-Mart Says October US Sales Rise Within 2% to 4% Forecast
# ==============================
# New home sales plunge a record 26 percent in '07
# ==============================
# Lehman earnings fall 12 percent
# ==============================
# Flickr Gains 38% Market Share After Yahoo Search Integration
# ==============================
# Libya cuts illiteracy rate to 11.9 percent: census \
#     (Reuters)\
#
# ==============================
# Barclays sees profits up by 35%
# ==============================
# Oil Futures Prices Rise 4.5% on Outsize Drop in Supplies
# ==============================
# U.S. Bancorp Earnings Dropped 21% in 4th Quarter
# ==============================
# Fed Raises Interest Rate to 2.25 Percent
# ==============================
# China January Trade Surplus Up 22.7%
# ==============================
# AT&T Profit Surges 41%, With Help From iPhone
# ==============================
# Sales of new homes up 4.6 percent in May \
#     (AP)\
#
# ==============================
# Kingfisher quarterly profit climbs 10.5 percent \
#     (AFP)\
#
# ==============================
# AIDS Up 6 Percent in S.Africa, Seen Stabilizing
# ==============================
# ADB lowers India&#39;s 2005 growth forecast to 6%
# ==============================
# Scientist: 70 percent chance of small eruption at Mount St. Helens
# ==============================
# German bank to cut IT support costs by 85%
# ==============================
# Glazer stake in Man Utd nears 30%
# ==============================
# HP reports 27% rise in quarterly profits
# ==============================
# Cemex Buys 18.8 Percent Stake in RMC
# ==============================
# Apple iPhone margins 55 percent
# ==============================
# Nikkei Average Fall 1 Percent at Opening
# ==============================
# China says investment up 26.7 percent \
#     (AP)\
#
# ==============================
# Producer prices dip 0.1 percent
# ==============================
# German inflation at 2.2 percent in 2007: Destatis \
#     (AFP)\
#
# ==============================
# Tabcorp Second-Half Profit Rises 28% on Jupiters Acquisition
# ==============================
# With All Votes Counted in Ukraine, Yushchenko Wins 51.99 %
# ==============================
# Health premiums jump 11.2%
# ==============================
# W. Nile reports jump 32 percent in Calif.
# ==============================
# Housing Starts Decline 3.7%
# ==============================
# Wal-Mart Sees 2-4% Sales Increase in September
# ==============================
# Study: 95 percent of all e-mail sent in 2007 was spam
# ==============================
# Cut Trident by 50%, say Lib Dems
# ==============================
# NFL ticket prices rise 5.6 percent \
#     (AP)\
#
# ==============================
# A Taker for 25% of Russia Phone Company
# ==============================
# Bank of America Profit Rises 5 Percent
# ==============================
# JPMorgan Chase Profit Rises 20 Percent
# ==============================
# Rock shares slump 15%
# ==============================
# Estonia mobile operator Elisa rings up 75 percent profit rise (AFP)
# ==============================
# Water Purifying Equipment Firm to Expand Manufacturing By 40 Percent
# ==============================
# China sees growth slow to 11.5%
# ==============================
# Interest rates cut to 5.25%
# ==============================
# Temasek invests in 4th airline, taking 3% stake in Qantas
# ==============================
# Construction spending rises 0.1 percent \
#     (AP)\
#
# ==============================
# US interest rates held at 5.25%
# ==============================
# EA to buy 20% of Ubisoft - report
# ==============================
# Wal-Mart Sees Jan. Sales Up 2.5 Percent (Reuters)
# ==============================
# Dell to Lay Off 10 Percent of Employees
# ==============================
# 'No women bosses' in 38% of firms
# ==============================
#  U.S. to Cut 10 Percent of Diplomatic Posts Next Year
# ==============================
# China&#39;s economy to grow 10.9 percent in 2007 \
#     (AFP)\
#
# ==============================
# Brazilian Inflation 7.6 Percent in 2004 (AP)
# ==============================
# January new home sales fall 16.6 percent \
#     (Reuters)\
#
# ==============================
# Trade Deficit Shrank by 6.2% Last Year
# ==============================
# Freddie Mac Earnings Drop 45%
# ==============================
# Nike Profit Up 25 Percent on US Demand
# ==============================
# Google Shares Jump 18% In NASDAQ Debut
# ==============================
# U.S. projects 19 percent emissions rise \
#     (AP)\
#
# ==============================
# New deal cuts NHS drug prices by 7%
# ==============================
# Oregon Governor: Kulongoski (D) 47%;  Saxton (R) 38% \
#     (Rasmussen Reports)\
#
# ==============================
# 9% of U.S. Kids Have ADHD \
#     (HealthDay)\
#
# ==============================
# How to Achieve 20% Yields
# ==============================
# Deutsche Boerse to buy 5 percent stake in Mumbai stock exchange \
#     (AFP)\
#
# ==============================
# Wal-Mart Earnings Climb 13 Percent
# ==============================
# AIG earnings fall 29 percent \
#     (Reuters)\
#
# ==============================
# Hershey Profit Tumbles 66 Percent
# ==============================
# Sinopec, amid rising demand, posts 51% rise in net
# ==============================

# %%
money_pattern = r"[$€£]\s?\d+(\.\d+)?\w*\b"
titles_by_regex(titles_with_numbers, money_pattern)
# Out:
# Total matches: 1368
# ['Â£800M PLEDGED FOR VIRGIN BOSS&#39;S SPACE TRIPS',
#  'Fattah Got a $100 Gift From Santa Street',
#  'Freescale 1000-worker cull to cost $65m',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Mortgage insurer MGIC to buy Radian for $5 bln \\\n    (Reuters)\\\n',
#  'Jaguar negotiates Â£534m Ford aid',
#  'Update: Motorola to buy Symbol for $3.9 billion',
#  'UN pledges help for Darfur refugees, Sudan wants $300 mln',
#  'Everton reject Â£20m Rooney bid',
#  'Basket Nears $8,800 With 5 Days to Go',
#  'HP to pay $14.5m following probe into boardroom leaks',
#  'PacifiCare buys AMS for $502 million',
#  'General Mills sells Snack Ventures Europe stake for $750 million',
#  'CA to acquire Netegrity for $430M',
#  ' LSI to Buy Agere in $4B Stock Swap ',
#  'Murder manhunt costs reach Â£1.5m',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Drug pipeline brings $80m more to Synta ',
#  'Google boys to pocket Â£650m from share sale',
#  'eBay snaps up Rent.com for $415m',
#  'Spaceflight to cost $40 million in 2009',
#  'Tsunami aid pledges top $3bn',
#  'Team exercises Wagner&#39;s $9 million option',
#  'Blair Presses for $150M in Aid for Darfur',
#  'Energy efficiency firm EnerNoc buys MDEnergy for $7.9 million ',
#  'Deal to Sell Clear Channel for $19 Billion Is Approved',
#  'Update 6: Crude Oil Prices Fall Below $43 a Barrel',
#  'Cornerstone Seeks Capital: The Drug Company Begins Its First Fundraiser, Aims to Raise at Least $15 Million',
#  'GE gets $1 billion in Saudi Arabian orders',
#  'â\x80\x98Piratesâ\x80\x99 Haul So Far Estimated at $401 Million',
#  'Home Depot may accept $1.2 bln less for unit: report',
#  'Bush and Kerry Clash on US&#39;s $1.7 Trillion Health Care Bill',
#  "Kuwait's $3bn plane deal aborted",
#  'Microsoft to fix Xbox 360s, take $1B-plus charge \\\n    (InfoWorld)\\\n',
#  'Â£141m benefits computer shelved',
#  'Merrill seeking $4 bln, Kuwait could invest: FT \\\n    (Reuters)\\\n',
#  'Oil hits new record above $92',
#  'Qwest agrees to pay $250 million to settle fraud case',
#  'NFL Fines S Darius $75K for Ferguson Hit',
#  'Interim Chief at Enron Asks for $25 Million',
#  'NS health system slammed for $15.5M in overdue accounts',
#  ' Oil Futures Rise to $100 a Barrel ',
#  'IRA link to $55m bank raid',
#  'SocGen reels from record $7 billion rogue trader fraud',
#  'Bally agrees to $280 million in credit deals',
#  'Oil holds above $62 as supply glut balances OPEC',
#  "Microsoft's $1 Billion Red Ring Of Death",
#  'Insurers&#39; cost: $7.4-billion',
#  'Russia agrees to US deal that writes off $33bn of Iraq debt',
#  'Nation splurges $126m on Cup',
#  'Roche wins Ventana with raised $3.4 bln bid',
#  'Novar close to Â£800m cash deal with US giant',
#  "Probe says Black 'looted $400m'",
#  'Update 23: Crude Prices Stay Above $50 Per Barrel',
#  'Alcoa, others buying pipeline for $1.3B',
#  'ICI rejects $14.2 bln Akzo Nobel bid approach',
#  'SBC, Microsoft in $400 mn IP-based TV deal',
#  'AMD invests $7.5 million in Transmeta',
#  '$31.5M Online Gambling Settlement',
#  'IBM Sells PC Business for $1.75B',
#  'Amtrak in Another Hole with $1.3 Bln Loss',
#  'Cadbury salmonella bill hits Â£30m',
#  'News Corp., Supersport Pay $323 Mln for Rugby Rights (Update1)',
#  'Sprint near deal to buy Nextel for $35 billion',
#  'Telstra completes $750m buyback',
#  '$10 Vehicle Fee for Highway?',
#  'Northwest to be worth $7b after bankruptcy',
#  '$1b remake of Bayside proposed',
#  'German government approves $1.6B to spur IT innovation',
#  'Apple starts handing out $100 iPhone credits',
#  'MAN AG bids $12.2 bln for truck maker Scania',
#  'A&P in talks to buy Pathmark for about $653 million \\\n    (Reuters)\\\n',
#  'Chavez Predicts $3 B in China Trade',
#  "China snowstorms 'to cost $15bn'",
#  "Reckson shareholders OK SL Green's $4 bln takeover",
#  'ADV: Win a $2400 Scholarship Now',
#  'Man told to hand over Â£18m assets',
#  'Oil majors little moved by $100-per-barrel crude',
#  'States face $2.73 trln bill for retirees: study',
#  'Council foots Â£150,000 flood bill',
#  'Inmates get Â£2.5m payouts',
#  'Acer to grab Gateway for $710m',
#  'Sovereign Bancorp to take $1.58 billion charge \\\n    (Reuters)\\\n',
#  'Oil Holds Near $47',
#  'Fun, Tours and a $3,000 Bill for Hardly Using an iPhone',
#  'House Panel OKs $153M in Pet Projects',
#  'Robbers steal $100m in art from Zurich \\\n    (AP)\\\n',
#  'Cisco to buy Protego for $65m',
#  'Dan Rather sues CBS for $70 million',
#  'Museum to Get $60 Million Exhibit',
#  'BP sees Alaska repairs costing $100 million: source \\\n    (Reuters)\\\n',
#  'Capital One finishes $13.2 bln North Fork purchase \\\n    (Reuters)\\\n',
#  'Gartner: Offshore IT spending to hit $50 billion',
#  'Avaya to be sold for $8.2 billion',
#  'Senate Adds $70 Billion for Wars in Spending Bill',
#  'Yahoo co-founder gives $75 mln to Stanford',
#  'Symantec to Buy Veritas for $13.5 Billion',
#  'Mylan to raise nearly $1 billion in offerings',
#  'Sun posts $174 million loss for the quarter',
#  'P&G buying Gillette for $57 billion',
#  'Chitty film car fetches $505,000',
#  "G8's $60 bln AIDS and Africa pledge criticized",
#  'Oil Hits $47 as Supply Worries Linger',
#  'Oil price to fall to below $53 by 2008: World Bank \\\n    (Reuters)\\\n',
#  'J&amp;J Seals $25.4 Bln Pact to Buy Guidant',
#  'Bush Seeks $245B for Wars\\\n',
#  'WMC rejects Xstrata&#39;s $5.5B bid',
#  "Italy 'paid $1m to free hostages'",
#  'Â£5m hospital bug payout for Ash',
#  'NTL to sell communications masts to Australia&#39;s MCG in Â£1.27bn <b>...</b>',
#  'Toronto Blue Jays to Buy SkyDome for $21 Million',
#  'Monsanto fined $1.5m for bribery',
#  'Navy to Award $6.4 Bln Satellite Contract',
#  'Security alert cost Easyjet Â£4m',
#  'Stocks Fall As Oil Surpasses $51 a Barrel',
#  'BP to pay $373 million to settle charges',
#  '$1m payoff for former Shell boss',
#  'Samsung squirrels $100 million for DRAM cartel case',
#  'Jeanne damage estimated at up to $8B',
#  "Gates' $750m vaccination pledge",
#  "China's LDK plans $300 million Nasdaq listing -paper",
#  'Southwest Offers Ailing ATA $100 Million Deal to Share Flights',
#  "WorldCom directors 'to pay $54m'",
#  'Blockbuster Offers $700 Mln for Hollywood Video',
#  'Mets, Santana agree at $150.75M \\\n    (AP)\\\n',
#  'Crude oil prices push past $50 a barrel',
#  '$136 billion business tax break package gets OK',
#  'Wal-Mart to Offer $4 Generic Prescriptions',
#  "France's CGG to buy Veritas in $3.1 bln deal",
#  'Wanna Pay $7 A Gallon?',
#  'Alltel Buys Western Wireless for $4.4 Bln',
#  'Merrill Lynch to issue $6.6 billion preferred shares',
#  '"$100 laptop" hits $200 \\\n    (Reuters)\\\n',
#  'Sprint buys Nextel for $35 billion',
#  'Update 23: Crude Prices Stay Above $50 Per Barrel',
#  'Oil breaks $100 as U.S. stockpiles drop',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Troubles trauma could top Â£100m ',
#  'Johnny Cash auction closes at $4m',
#  "Immigrants 'cost UK Â£2bn a year'",
#  'London oil drops to $40 a barrel',
#  'Today in blogs: The $500,000 guitar',
#  'Hero&#39; rises to challenge with $17.8 m',
#  'Allianz Renews $7mm Ip VPN Contract With Equant',
#  'Merrill may get $5 bln capital from Temasek: report',
#  "Apple 8GB iPhone components 'cost $220'",
#  'Obama Raises $32.5 Million, Record for a Democrat \\\n    (Bloomberg)\\\n',
#  'Tata Steel wins Corus with $11.3 billion offer',
#  'NaClor Picks Spot for $40 Million Plant',
#  'The Rouse Co. sold for $12.6 billion',
#  'AWB to Supply A$341 Million of Milling Wheat to China (Update1)',
#  'Oracle Raises PeopleSoft Bid by 14% to $8.8 Billion (Update5)',
#  'HSBC to buy 51 pct of Korean bank for $6.3 billion',
#  'A $500 Milestone for Google Believers',
#  'Microsoft bids $44.6 billion to buy Yahoo',
#  'Oil back above $55 as US winter stocks drop',
#  ' Bush Wants $50 Billion More for Iraq War ',
#  'Sweden to donate $3 mln to preserve Bergman works \\\n    (Reuters)\\\n',
#  'Saudi Arabia&#39;s public spending to rise by $2.1 billion',
#  'CBS to pay $31 million in cleanup settlement \\\n    (Reuters)\\\n',
#  'Gas Tops $2/Gallon, 2.9 Cents from Record',
#  'Kidde pours cold water on Â£1.3bn bid',
#  'Citigroup pays CEO Prince $26 mln for 2006',
#  'MCI to Take $3.5 Billion Charge in 3Q',
#  '&quot;Die Hard&quot; chases down $9.1 mil in opening day \\\n    (Reuters)\\\n',
#  'India&#8217;s IT market to reach $24 billion by 2011',
#  'Toshiba to Pay Micron $288 Million to End Litigation Over Flash Memory',
#  'NJ jury awards plaintiff $20 mln in Vioxx case \\\n    (Reuters)\\\n',
#  'Google to build $600M data center in Iowa',
#  'Donors pledge $940m to aid Lebanon relief',
#  '$2m in aid from govt',
#  'Dodgers deal guarantees Saito $1 million',
#  'Update 3: Yahoo Buying Musicmatch for $160 Million',
#  'Stolz&#39;s $990,000 Vegas jackpot',
#  '"Breakfast at Tiffany\'s" dress fetches $800,000 \\\n    (Reuters)\\\n',
#  'Broadcast growth helps News Corp profit rise to $536m',
#  'Deal could mean  $70,000,000,000 more for war',
#  'Bush wants $150 billion plan to lift economy',
#  'Kinder Morgan agrees to $15 billion buyout \\\n    (Reuters)\\\n',
#  'Â£3 cap on hospital parking charge',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Pennsylvaniaâ\x80\x99s $47 Million Lift Bid for New M.L.S. Team',
#  'Oil Clings to $50, Fuel Stocks to Fall',
#  'Update 3: Oil Prices Drop $1 Despite Iraq Sabotage',
#  'SBC Is Near Deal To Acquire AT&T For $16 Billion',
#  'Football: Rangers reject Â£8m bid',
#  'Replicas of Clapton guitar on sale for $24,000 \\\n    (Reuters)\\\n',
#  'Oil falls more than $2 on demand concerns',
#  'Mizuho subprime losses could hit $2.8 billion: reports',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'SpaceShipOne Lifts Off in $10 Million Prize Bid',
#  'J&J sues Boston Scientific, Abbott for $5.5 bln \\\n    (Reuters)\\\n',
#  'Nassau Legislature Expected to Approve a $100M Bond Issue to Protect Environment',
#  'Internet Growth Triggers $100 Million Expansion for VeriSign',
#  'Tenet to Settle Redding Suits With $395 Million Fund (Update2)',
#  'Sabre agrees to be sold for $4.3 bln: paper \\\n    (Reuters)\\\n',
#  'US to forgive Iraq&#39;s $4 billion debt',
#  'Oil Prices Drop $1 Despite Iraq Sabotage',
#  'Asustek, Intel at work on $199 laptop',
#  'Triad Hospitals accepts $4.7 bln bid to go private',
#  'Pledges of relief reach $500 million',
#  'Oil drops below $61 on healthier U.S. supply picture',
#  'Acer to acquire Gateway for $710',
#  'Yahoo to Buy Musicmatch Web Service for $160 Million (Update4)',
#  'Biffa agrees Â£1.2bn takeover bid',
#  'Wal-Mart Stores offer $4 generic drugs in Florida',
#  'Palm strikes deal to sell stake for $325 million',
#  "'$100 laptop' to sell to public",
#  'Promoter buys Elvis estate for $100 million',
#  'Crude Oil Prices Slip Below $43 a Barrel',
#  " Yahoo Board Decides To Reject Microsoft's $44.6 Billion Offer ",
#  '&#39;The Forgotten&#39; scares up $21 million at the box office',
#  'Steel Partners Bids $700 Mln for Gencorp',
#  'Sony cuts price on PlayStation 3 by $100 \\\n    (Reuters)\\\n',
#  'Pottruck: Ousted Schwab CEO Gets $10M Contract',
#  'Monthly Medicare to increase $11.60',
#  'Sprint to Buy Nextel in $36 Billion Deal',
#  '$850m study gives Pill good bill of health',
#  'Pistons Coach Fined $15K for Verbal Abuse',
#  'EU to give $125M for Darfur peacekeeping',
#  'CVC to acquire Samsonite for $1.1 billion',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Netflix offers $1 mln prize for better movie picks',
#  'Secondary offering for Russian bank pulls in $8.8 billion',
#  'Miss Alabama Crowned Miss America, Wins $50,000',
#  'EBay to Buy Rent.com for $415 Mln in Cash and Stock (Update2)',
#  'Calif. Voters Back $3 Billion Stem Cell Measure',
#  'Oil hits record above $92 on weak dollar, Nigeria',
#  'Giuliani Beats Rivals, Raises More Than $17 Million in Quarter \\\n    (Bloomberg)\\\n',
#  "Garden's Â£1.9m debts are cleared",
#  'Siemens Signs $2B Train Deal With Russia',
#  'Airwaves sale raises $13.9 bln, T-Mobile tops',
#  'UN emergency fund raises $420 million \\\n    (AP)\\\n',
#  'Update 12: Crude Oil Climbs Above $50 in Asia',
#  'Harvard endowment swells to nearly $30 billion',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Sen. Specter Proposing $140 Billion Asbestos Fund',
#  'Silverstein: WTC Leaseholder May Collect Up To $4.6B',
#  'Fannie May Have to Restate Earnings By $9 Bln After SEC Ruling',
#  'Libya Agrees to Pay $35 Million to Berlin Bomb Victims',
#  'Callas Jewels Net $1.87 Million at Geneva Auction',
#  'Red Hat to buy Netscape assets for $20.5mn',
#  'Bush pledges $350m; relief efforts crawling',
#  'Google IPO Prices at $85/share - Source',
#  'Toyota, Partner to Invest $461 Mln in China Venture (Update2)',
#  'The $28K Sandwich That Grew No Mold',
#  'Riverside County woman wins $27 million lotto jackpot',
#  'Sen. Specter Backs $140 Bln Asbestos Bill',
#  'Oil Slips Under $55 a Barrel',
#  'Microsoft offers $1.2 billion for Fast',
#  'JP Morgan to buy 50% of Cazenove for Â£100 mn',
#  'Firefighter among $10M arson suspects',
#  'Home Depot settles suit for $5.5M',
#  'Northwest Pilots Ratify $265 Mln Concession Deal',
#  'Cyberthieves steal $449K from city coffers',
#  'Light crude falls below $43',
#  'Bush Helps GOP Senators Raise $2.1 Million',
#  'Attorney General responds to <br>Bandar, Â£1bn and BAE',
#  'Update 2: Gold Fields Rejects $8.1B Harmony Gold Bid',
#  'Creative plans US$100m advertising campaign for its MP3 players',
#  'Chart your space odyssey @ $190k',
#  'Government: Gasoline Rose to $1.884/gal',
#  "France's Areva wins $5 billion nuke deal \\\n    (Reuters)\\\n",
#  'Yahoo buys behavioral ad firm for $300 million \\\n    (Reuters)\\\n',
#  'US Trade Deficit Widens to $54 Billion',
#  'Boeing Probe Widens to $100 Bln Contract',
#  "'Jumper' lands on top with $32.1 million \\\n    (AP)\\\n",
#  'ANZ boosts profit to record $2.81b',
#  'Â£141m benefits computer shelved',
#  'Alcoa selling entire Chalco stake for up to $2 billion',
#  'Steel boss to get Â£140m dividend',
#  'ADV: Win a $2400 Scholarship Now',
#  'Philips in $5.1 Billion Deal for Respironics',
#  'IBM Executes $12.5 Billion Accelerated Share Repurchases',
#  'Bookies fear Â£10m FA Cup payout',
#  'Bush wants another $75 billion to fund wars',
#  'Microsoft facing $1bn Xbox bill',
#  'Carlsbad, Encinitas Pursue Joint $4.2 Million Road Project',
#  'Australia&#39;s Suncorp-Metway FY Net A$618M; Outlook Upbeat',
#  "India's Software, Services Exports Forecast at $40 Billion",
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'VeriSign Pumping $100 Million into Network: CAPACITY FOR DOMAIN NAME QUERIES WILL INCREASE TENFOLD IN THREE YEARS',
#  'Insurance merger results in $126.5 million windfall',
#  'Sony cuts price on PlayStation 3 by $100',
#  'Crude futures dip below $43 a barrel',
#  "Alex's Lemonade Stand Exceeds $1M Goal",
#  'Corruption costs Â£200bn a year',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  "Copy of Poem Sold; 'Twas Worth $280K",
#  "Marineland Plans Big Aquarium Complex ; First Attraction, Part of $144 Million Renovation, to Feature World's Largest Fish and Open in 2008",
#  'Saddam Got $21 Billion from UN Oil Program -U.S. Panel',
#  'Yahoo Buying Facebook for $1 Billion',
#  'Stocks Up Despite Oil Nearing $50 a Barrel',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'BA announces $8.2 bln order with Airbus, Boeing \\\n    (Reuters)\\\n',
#  'Oil price returns to near $50 per barrel mark',
#  "Lidl's Â£25 kilt is a bargain too far",
#  '&#39;Shark&#39; Attacks Boxoffice with $49 Mil',
#  'Nokia Siemens wins $935 million Saudi Arabia deal \\\n    (Reuters)\\\n',
#  'AOL Parent Sets Up $500 Million Reserve',
#  'SBC agrees to buy AT&T for $16bn',
#  ' $3.4 Billion Investment Could Pull Delphi From Bankruptcy ',
#  'Crude futures rise by $1 US on fuel news',
#  'Oil Prices Slide Toward $54',
#  'Ex-Biopure chief agrees to pay $120,000',
#  'The Face of the $100 Laptop',
#  'Research and Markets: Google Recorded Revenues of $10,604.9 Million During the Fiscal Year Ended December 2006',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Microsoft makes $44.6 billion offer for Yahoo',
#  'Hollinger to pay $500m special dividend',
#  'Rinker rejects $12 billion Cemex bid as "far too low" \\\n    (Reuters)\\\n',
#  'Time Warner Prepares for Settlement with $500M Reserve',
#  'U.S. Chips in to Save Farmland: Kane Gets Nearly $1 Million for Efforts',
#  'Dubai&#39;s DAE says funds for $1.8 bln U.S. buy agreed \\\n    (Reuters)\\\n',
#  'Stocks Jump as Crude Falls More Than $1',
#  'KKR completes $26 billion First Data takeover',
#  'Sony cuts price on PlayStation 3 by $100 \\\n    (Reuters)\\\n',
#  'Home abuse victims get Â£2m payout',
#  'Ailing smokers ask Florida justices to restore $145 billion award',
#  'Study: &#39;Phishing&#39; scams net $500 million',
#  "Premiership wages 'to top Â£1bn'",
#  'FA punish Wenger with record Â£15,000 fine',
#  'Wyeth to Pay $3 Million in Cancer Suit',
#  'Oil Holds Above $46 Supply Worries Linger',
#  '"Pirates" grosses $58 million in limited release',
#  'UPDATE 1-PacifiCare to buy American Medical for $502 mln',
#  'Ford Posts Record Loss of $12.7B',
#  'Nortel Wins $5 Million Contract for BT Virtual Call Center',
#  'Oil hits record $100 a barrel',
#  'Investors put Â£1.5bn tag on Kidde',
#  'FBI seizes $87 million worth of illegal software',
#  'Dow Jones to Buy MarketWatch for $463 Mln',
#  'Oil Prices Extend Gains Above $41/barrel',
#  '$20m is set aside to mark end of wars',
#  'Red Cross Raises Record $1.2 Bln in Tsunami Aid',
#  'Avaya faces up to $250 mln break-up fee:  filing',
#  'Volvo to buy Ingersoll-Rand road unit for $1.3 bln',
#  'St. Johns Beach Residents Seek Erosion Study They Pledge to Pay Half of the $280,000 Needed to Determine Action.',
#  'Freeney agrees to $72 million contract with Colts',
#  'DirectRevenue to Pay $1.5M in Adware Settlement',
#  'IBM signs Cigna to 7-year deal worth $723 million \\\n    (Reuters)\\\n',
#  'Murdoch offers $44 million for Manhattan penthouse',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Glazer splashes Â£45M to up Man Utd stake',
#  'Danske pays $1.86B for Irish banks',
#  'Symantec will buy Veritas for $13.5B',
#  'Oil prices rise above $43 per barrel ahead of OPEC meeting',
#  'MoD awards Â£124m for pilot-free plane',
#  'Back up your PC for $2.99 (after rebates)',
#  'Ontario offers C$150 million to woo biotech investment \\\n    (Reuters)\\\n',
#  "Frances' Insured Losses to Near $4.4 Bln",
#  'Oil slips, but still trades above $49',
#  'P&G to Acquire Gillette for $57 Billion',
#  'Courts freeze $12 billion Venezuela assets in Exxon row',
#  'QE2 Liner To Be Sold In Â£50m Deal',
#  'The Dating Coach Is in ($125/Hour)',
#  'Jones to Buy Barneys in $400 Million Deal',
#  "Harrah's accepts $17.1 billion private equity bid \\\n    (Reuters)\\\n",
#  'Deal or no deal: HD-DVD player cracks $200 barrier?',
#  'Vodafone denies planning $160 bln bid for Verizon',
#  'Rayovac to Buy United Ind. for $476 Mln',
#  'Crude futures rise above $43 a barrel as markets look to OPEC <b>...</b>',
#  ' Kraft Bids $7.2B for Danone Unit ',
#  "Ford's new CEO gets $18.5 million to take job",
#  'Bent in Â£16.5m Spurs move',
#  'Sony Pegs PSP Price Under US$200',
#  'BP agrees to pay $373m in fines',
#  'Symantec, Veritas could declare $13B deal this week',
#  'Invesco, AIM Agree to $450 Mln Settlement',
#  'Dye agrees to $10.15 million, two-year deal with White Sox',
#  'Macerich to Buy Wilmorite for $1.45 Bln',
#  'Infineon to build $1bn plant in Malaysia',
#  'Magna Carta sells in NY auction for $21.3 million',
#  'Oil at $70 as cyclone nears Gulf',
#  'Japan Tobacco offers $14.7 billion for the British cigarette maker Gallaher',
#  'Sallie Mae to sell $2.5 billion stock, convertibles \\\n    (Reuters)\\\n',
#  'Energy efficiency firm EnerNoc buys MDEnergy for $7.9 million ',
#  'Carnival on song as quarterly profits break $1bn barrier',
#  'Extra Â£500 on offer to failed asylum seekers',
#  'Intel Capital to Buy $218.5 Million Share of VMware \\\n    (PC World)\\\n',
#  'Countrywide CEO to relinquish $37.5 mln in payments \\\n    (Reuters)\\\n',
#  'SocGen reels from record $7 bln rogue trader fraud',
#  'Merrill to Receive $6.2 Billion Capital Injection',
#  'Oil steady near $70 as US growth worries ebb \\\n    (Reuters)\\\n',
#  'Merrill takes $14.1 billion writedown',
#  'Oil prices hold above $54',
#  'Goldman pays CEO Blankfein $54 mln',
#  'With Oil Near $50 a Barrel, Gas Prices Start to Inch Up',
#  'SBC agrees to buy AT&T for $16bn',
#  'UPDATE 1-Cendant to buy Orbitz for $1.25 billion',
#  'Merck to pay $2.9 billion to settle U.S. tax claims',
#  'US trade gap hits a record $68b in July',
#  'Rolls-Royce eyes $500m China deal',
#  'Â£33m carer-support plan unveiled',
#  'Rio Tinto to invest $1.8 billion in Australian metals plant \\\n    (AFP)\\\n',
#  'Merrill seen suffering $15 billion investment loss: report \\\n    (Reuters)\\\n',
#  'Rogers Wireless to Purchase Microcell for C$1.4 Bln (Update5)',
#  'Casino giant in $4bn Vegas plan',
#  "Brown 'needs Â£11bn tax increase'",
#  'Sprint settles FTC claim for $1.125M',
#  'Piper Jaffray: AT&T paying Apple $18 per iPhone, per month',
#  'U.S. Congress clears the way for $168 billion economic stimulus',
#  'Average GP pay rises to Â£106,000',
#  'Bush Seeks Budget of $3.1 Trillion ',
#  'Crude oil declines by $3',
#  'Credit Suisse jolts market with new $2.9 billion write-down',
#  'NextEngine\'s Next Breakthrough: "Points-to-Parts" Software for $2,495',
#  'Bush to Seek About $80 Billion for Military Operations',
#  'Grid nets bumper Â£5.8bn from sell-off',
#  'Raising $22 million the Diligent way',
#  'Softbank to spend $350 mln on data center: Nikkei \\\n    (Reuters)\\\n',
#  'BA boss who quit over scandal in line for Â£1.6m',
#  "Talks under way to put Intel inside OLPC's $100 laptop",
#  'United unions seek up to $1 billion in skipped pension payments',
#  "Electric town car's launch paved with $60 million more",
#  'Cisco to acquire P-Cube for $200M',
#  'AT&T ordered to pay $156 million in patent case',
#  'YUKOS should be sold for $15bn, official says',
#  'Offering could bring in $850 million; Wasserstein prevails',
#  'Bush, Congress discuss $150 billion lift to economy',
#  'Bear Stearns in $3.2 billion bailout of fund',
#  'Crude Oil Tops $55 per Barrel',
#  '$20bn from Fed to ease credit woe',
#  'IRA denies involvement in $42 million bank heist',
#  'Parent of Washington State Utility Accepts $7.4 Billion Buyout Offer',
#  'Crude Oil Nears $40 a Barrel',
#  "The Â£1,500 'mock' Rembrandt sold for Â£2.2m",
#  'Wachovia to buy A.G. Edwards for $6.8 billion',
#  'Halliburton Work in Iraq Tops More Than $10 Billion',
#  'Â£300m campaign to tackle HIV &#39;epidemic&#39;',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Oil Prices Charge Toward $50 a Barrel',
#  'I Turned $3,000 Into $210,000',
#  'SpaceShipOne rockets to Â£5.6m prize',
#  'Oil Dips Below $46 as Iraq Flow Rises',
#  'Â£4bn to research killer diseases',
#  'EMC Gets Smarts for $260M',
#  'Oil prices surge past $70 in US',
#  'Vonage ordered to pay Sprint $69.5 million in patent case',
#  'Banker wins back $8 mln in Salsa dance case \\\n    (Reuters)\\\n',
#  'China Cos To Invest $19.7B in Argentina Over Next 10 Yrs',
#  'US spends $90m to protect planes',
#  " Pirates' Sanchez Reaches $11M Deal ",
#  'ConocoPhillips Buys $2 Billion Stake in Lukoil',
#  'Asahi Tec to buy Metaldyne in $1.2 bln deal',
#  'PayPal buys Fraud Sciences for $169M \\\n    (InfoWorld)\\\n',
#  'India wins $77m steel investment',
#  'Half of all workers on $2 a day or less',
#  'Archstone deal carries break-up fee of $235 mln \\\n    (Reuters)\\\n',
#  'Nigerian kidnappers demand $78,600 for 3-year-old',
#  'Oil jumps above $60, OPEC cuts feared spreading',
#  'U.S. Mint launches first presidential $1 coin',
#  'Samsung to spend $1 bln to upgrade chip lines',
#  'Russia pays $63m in debts to IMF',
#  'Oil Ends Nearly $2 Down',
#  'Sabeco, Vietnam&#x27;s largest brewer, plans to raise $557 million in an IPO',
#  'Senate Approves Bill Worth $140 Billion in Corporate Tax Breaks',
#  'Californians back hiking cigarette tax by $2: poll',
#  ' Motorola Posts $28M Loss in 2Q ',
#  'Viacom in $1 bln copyright suit vs Google, YouTube \\\n    (Reuters)\\\n',
#  'Middle School Gets $25,000 Technology Grant',
#  'Parmalat sues Grant Thornton, Deloitte for $10 billion',
#  'Rambus settles backdating suit for $18M',
#  'Briefing: Indian farmers to get $1 billion in credit',
#  '&#39;Lemony Snicket&#39; earns box-office fortune with $30.1 million',
#  'House Backs $388 Billion Spending Bill',
#  'Vick Is Atlanta&#39;s New $100 Million Man',
#  'Saudi Arabia to Boost Oil Production as Price Hits $50',
#  'Waste-to-energy firm Ze-Gen gets $4.5 million',
#  'Citigroup rogue metals trader loses $20 million: NYSE',
#  'Oil Finishes Week Below $50 Per Barrel',
#  'Security alert costs Easyjet Â£4m',
#  'Samsung Plans $25B IC Investment',
#  'Microsoft Pays $536 Million in Antitrust Complaints',
#  'Lawmakers Agree on $388 Bln Spending Bill',
#  'Congress close to passing $388 billion spending bill',
#  'beach hut sells for Â£100,000',
#  'LANCOR demands $20 million in patent damages from One Laptop Per Child',
#  'Merrill Lynch to raise $6.2 billion from investors',
#  'Viridian Taken Over In Â£1.6bn Deal',
#  'Oil falls below $89 as stock markets drop',
#  'Report: UBS buying Schwab unit for $265 mln',
#  'Verizon to Buy NextWave Licenses for $3 Billion',
#  'Conrad Black plans $1.1B libel suit over Hollinger board committee <b>...</b>',
#  'Judge cuts Microsoft fees to $100 m',
#  'House passes $696 billion defense bill \\\n    (AP)\\\n',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Brown-Forman to make first move in Â£300m Glenmorangie bid battle',
#  'Oil Prices Drop $1 Despite Iraq Sabotage',
#  'Oil hits record above $79',
#  'Kinross Gold restates Q3, posts $133.6 million',
#  'Reliance Power float raises $3bn',
#  'Crude Settles Above $50 for First Time',
#  'Cisco finishes $3.2B WebEx acquisition',
#  'MySpace could be worth $15 billion \\\n    (Reuters)\\\n',
#  'Oil Slips Below $43 a Barrel',
#  'The fish with a Â£100/kg price on its head set to win protector',
#  'I.B.M. Employees Get $320 Million in Pension Suit',
#  'High-flyer&#39;s Â£7.5m sex discrimination claim against banking giant <b>...</b>',
#  'Exclusivity? Try Lamborghini&#39;s $1.4 million car \\\n    (Reuters)\\\n',
#  'U.S. awards $1.35 billion for cargo screening',
#  'Navy to Award $6.4 Bln Satellite Contract',
#  'Oil Prices Rise Toward Record $54 A Barrel',
#  'Crude oil prices push past $50 a barrel',
#  "Australia's Qantas accepts A$11 billion takeover offer",
#  'Chile Asks Pinochet to Explain $8 Million US Bank Accounts',
#  'Oil tumbles below $53',
#  'China to Shift $20 Billion as Capital for Policy Bank',
#  "WPP wins 'Â£750m' US takeover bid",
#  'Elvis cape goes for $24,000 at Dick Clark auction',
#  "Branston firm's Â£1.2bn Oxo buyout",
#  'Private rocket ship has wild ride in quest for $10 million prize',
#  'Â£40bn criminal networks targeted',
#  'Jury Orders Microsoft to Pay Alcatel-Lucent $1.5 Billion',
#  'SBC Gives Microsoft $400 Mln Internet TV Deal',
#  ' Bush Wants $50 Billion More for Iraq War ',
#  'AOptix Technologies Raises $15 Million in New Venture Funding',
#  'From Near Death to an $8.2 Billion Deal',
#  'Microsoft pledges $235M for IT in developing world',
#  'Crude oil prices surge past $55 a barrel',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'UPDATE 2-Alcan&#39;s new Novelis to have $2.8 billion of debt',
#  'Worth $2b, inventor fighting to keep his job',
#  'Home Depot in $10 bln deal to sell unit: sources \\\n    (Reuters)\\\n',
#  'Continental, others buy Boeing jets worth $4.5 bln',
#  'Update 6: Dutch Steelmaker Buying ISG in $4.5B Deal',
#  'NetSuite IPO prices at $26 per share \\\n    (AP)\\\n',
#  'Fotolog acquired for $90 million',
#  'Cheer Fund Reaches $24,044',
#  'San Diego Church agrees $198 million sex abuse deal',
#  'Singapore Air expands fleet with US$3.7B Boeing order',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Doctors Hail the $100,000 Device, but Critics Question Whether <b>...</b>',
#  'Energizer to acquire Playtex for $1.16 billion',
#  'Walmart.com: $498 Laptop Breaks Price Barrier',
#  'NASA Says $19 Million Toilet System Is Really a Bargain',
#  'Louvre thieves steal diamonds worth Â£8m',
#  'Bank of America to buy Countrywide for $4 billion',
#  " $35 Billion Boost In Works for Kids' Health Care ",
#  'Home Depot is said to cut deal&#x27;s price by $1.8 billion',
#  'Ingram buys Aussie distie for $493m',
#  'MCI says its asset values to be written down $3.5 billion',
#  'Record $4.7bn profit for BHP',
#  'Boeing receives airplane orders worth $3.8 bn from Primaris',
#  'Beatles guitar sells for $294,000',
#  'Â£1,000 bond planned for visits to UK',
#  'Oil Edges Up to $42 Ahead of U.S. Data',
#  'Carillon Beach Finishing $56 Million Revitalization Project: Community Makeover',
#  'XM Satellite in $650 Million Deal with Pro Baseball',
#  'Motorists Could Face $2/gal Gasoline Soon',
#  'Paducah Plant May Get Reprieve As USEC Delays Construction in Ohio: The Estimated Cost of the Centrifuge Plant Has Increased By 30 Percent to More Than $2 Billion.',
#  'Merrill Lynch reports record loss after $16.7 billion in write-downs',
#  'China Development Bank gets $20 billion state funding',
#  'Gold hits 16-month high of $700',
#  'Citigroup sees $15 billion writedown at Merrill \\\n    (Reuters)\\\n',
#  'Linear Retail pays $22m for plaza in Wellesley',
#  'Crude oil prices surpass $53 per barrel',
#  "Harrah's accepts $17.1 billion private equity bid",
#  ' Software Firm to Pay $30 Million in AOL Case ',
#  '$25m offered to blunt global warming',
#  'Record $48M stolen from Belfast bank',
#  'Hutchinson Telecom cuts IPO target to US$1.1bil',
#  'IRA deny Â£22m bank raid link',
#  'China piracy costs film industry $2.7 bln in 2005 \\\n    (Reuters)\\\n',
#  'AK Steel Reports $83.1 Million Profit',
#  'Defence contractor Lockheed takes US$110 million Q4 charge for <b>...</b>',
#  'Oil eases from near $100',
#  'Oil Slips Under $50 as US Supply Swell',
#  'Yukos sues four firms for $20bn',
#  'Deal of the day: JBL Creature II 3-piece desktop speaker system for $34',
#  'A New $3Bln Tax Claim Looms Over Yukos',
#  'GE sells India back office unit stake for $500 mn',
#  'Tsunami Damage Could Exceed $13.6 Bln',
#  'CSC Lands $44 Million NASA Contract',
#  'Stocks Fall As Oil Climbs Past $55 Mark',
#  'League fines Plummer $5K for finger to fans',
#  'Aurora cruise fiasco to cost Â£26m',
#  "Calling Major Tom: This Space Station is a $100bn 'True Historic Stinker' ; THE COLUMNISTS",
#  'Team spends $21.24 million for SkyDome',
#  'Morgan Stanley sees $3.7 billion subprime hit',
#  'Oil Dips Below $46 as Iraq Flow Rises',
#  'HP to Invest $3 Billion in Itanium-Powered Servers',
#  'Oil hits record $100 a barrel',
#  'Bayer sells Starck to Advent, Carlyle for $908 mln',
#  'Bush authorizes $300M for Sudan',
#  'Schwarzenegger Unveils $112 Billion Calif. Budget',
#  'Oil slips, but still trades above $49',
#  'Is Stern Worth $1 Billion?',
#  'Failing CSA paid Â£25m in bonuses',
#  'Cendant Is Close to Acquiring Orbitz for $1.1 Billion',
#  'I Turned $3,000 Into $210,000',
#  'Delta Amends $680 Mln Debt Exchange Offer',
#  'Aon to sell two units for $2.75 bln, boost buyback',
#  'Update 5: Crude Oil Prices Rise Above $46 a Barrel',
#  'Ontario Budget Deficit Is Unchanged at C$2.2 Billion (Update1)',
#  'Promoter buys Elvis estate for $100 million',
#  'Merrill Lynch to raise $6.2 billion from investors',
#  'HP to buy software firm Opsware for $1.6b',
#  'Everex hits the books with $298 open-source desktop ',
#  'Jail-bound Martha nets $2m',
#  'RSS Feed Provider Newsgator Secures $12 Million Fifth Round Funding',
#  'Crude Futures Firm Above $55',
#  'OPEC Approves of $50 Oil, Holds Output',
#  'Wizards Raise $30,000',
#  'Dockyard signs Â£30m MoD contract',
#  'Oil Slips Below $46, Supply Woes Persist',
#  'Global crude oil price near $49 on mounting Iraq violence',
#  'UK launches Â£10m recycling effort',
#  'U.S. Mint launches first presidential $1 coin',
#  'HP approves $3.7M severance package for top lawyer',
#  'Alchemy eyes $5.9bln Jaguar, Land Rover bid: report \\\n    (Reuters)\\\n',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Oil Prices Climb Above $42 a Barrel',
#  'Critical Letter to Limbaugh Fetches $2 Million',
#  'Oil eases as investors cash in on $100 rally',
#  'Â£500m plan to boost school sport',
#  'Update 4: Time Warner Profit Dips on $500M Reserve',
#  'World airlines&#39; loss estimate: $4 billion',
#  'Crude settles above $50 US for first time',
#  'BT to spend $27 million on new data center',
#  'Raids target Â£100m drug operation',
#  ' Moreanu, Twins Agree at $7.4M ',
#  'Crude Oil Prices Fall Below $44 a Barrel',
#  'Cuddyer gets $24M deal with Twins \\\n    (AP)\\\n',
#  'Manhattan housing in $5bn sale',
#  'ANZ pays $88 million for stake in Vietnam broker',
#  'Woman Wins $29,000 for Topless Stroll',
#  'CanWest Global earns $62M for Q4, compared with $45M loss last <b>...</b>',
#  'Woman Sues Best Buy for $54M for Lost Laptop',
#  'IRA link to $55m bank raid',
#  'CORRECTED: XM Satellite in $650 Mln Deal with Pro Baseball',
#  'Citgo to Spend $320 Mln on Refinery Pollution Curbs',
#  'India Tata Steel wins Corus with $12 bln offer',
#  'Thieves take $91 mln masterworks in Swiss art heist',
#  'UBS Takes a $14 Billion Hit',
#  'Danone in talks on $7.2 bln biscuit sale to Kraft',
#  "MPs' Â£87.6m expenses claim bill",
#  ' Family of Slain Miami Player to Get $2 Million Settlement ',
#  'Medco to buy PolyMedica for $1.5 billion',
#  'McAfee pays $51m for Hacker Safe',
#  'Apollo raises bid for Huntsman to $6.5 billion \\\n    (Reuters)\\\n',
#  'Intel appeals potential tax bill of $2.4 billion',
#  'Jenkins to get monthly salary of $3,200',
#  '"Pirates" races past $400 million overseas',
#  'Foundation Gives $20 Million to 3 Miami Institutions',
#  'ADV: STOPzilla Anti-Spyware - Only $19.95',
#  'BA &#39;robust&#39; after declaring Â£335m profit',
#  "'Treasure' finds $45M in box office gold \\\n    (AP)\\\n",
#  'Â£11M for Hirst fittings',
#  'Findings : A Cool $25 Million for a Climate Backup Plan',
#  'Rexam to buy Owens-Illinois Plastics for $1.8 bln',
#  'BT buys Infonet for $965 million',
#  'Anadarko to Sell Gulf Assets for $1.3 Bln',
#  'PeopleSoft Board Rejects Oracle $24/Share Tender',
#  'Home Depot to sell $5 bln in 3-part debt sale',
#  'UPDATE 2-Delta in $500 mln financing deal with GE unit',
#  'U.S. Crude Sets New Record: $47.52/Barrel',
#  'IBM to buy Israeli startup for $300 million: report \\\n    (Reuters)\\\n',
#  'ADV: Win a $2400 Scholarship Now',
#  'Gold soars to record high above key $850/oz level',
#  'Warning on $15bn Boeing contract',
#  'Lannon Could Seek Vote on Water System: Referendum Would Ask to Borrow $3 Million for Municipal Project',
#  'Waste may cost UK Â£180m a year',
#  'Nuveen agrees to $5.75 billion buyout',
#  'League earmarks extra $10 million for medical fund',
#  'Airlines expected to lose $4 billion',
#  'Santana gets four years, $40 million',
#  'Guru pledges $23m tsunami relief',
#  'Set-Top Box Delivers Unlimited Porn for $10 a Month',
#  'Stewart to keep $900,000 salary',
#  'London Olympics could cost Â£9bn',
#  'GoogleÂ\x92s Shares Climb Above $500',
#  'NetSuite Prices I.P.O. at $26 Per Share',
#  'Microsoft makes $42B bid for Yahoo \\\n    (AP)\\\n',
#  'Parent of Washington State Utility Accepts $7.4 Billion Buyout Offer',
#  'SBC Finishes $16 Billion Deal for AT&T',
#  'Crude oil pushes past $50 a barrel',
#  '$2.5 Trillion Budget Plan Cuts Many Programs',
#  'HBOS profit climbs 19% to Â£5.7bn',
#  'U.S. hurricane aid fraud likely tops $1 bln: report',
#  'Oil hits record $100 a barrel',
#  'Microsoft expects Xbox repair costs of up to $1.15b',
#  'BitTorrent bags $20m, galvanises CEO',
#  'Robert Tchenguiz may have lost Â£560m, but the yacht is safe',
#  'Ex-Brocade CEO ordered to pay $15M fine \\\n    (AP)\\\n',
#  'Respectable Portable PC for About $500',
#  'Bank of America to buy Countrywide for $4 billion',
#  'Seabright Insur Files IPO For Up To $86.25 Million Of Cmn Stock',
#  'IRS says Fedex owes $319 mln in back taxes: filing',
#  'Private equity firm buys CDW for $7.3 billion',
#  'Oregon Town Goes on Sale for $3 Million',
#  '$1 Billion Donated to Vaccinate Poor Children',
#  'Digital Cameras Sales to Hit $24 Billion in 2004',
#  'Spain\'s "El Gordo" lottery awards $3.2 billion',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'ELS CHASING Â£1MILLION BIRTHDAY PRESENT',
#  'U.S. Steel to pay $1.1b for Stelco',
#  'U.S Did Not Safeguard $8.8 Bln of Iraq Money -Audit',
#  "Google's Stock Price Rises Above $500 for First Time",
#  'Sprint to Buy Nextel in $35 Bln Deal',
#  'Gov&#39;t buys $877M worth of anthrax vaccine',
#  'Thieves grab Â£1m gems in raid on Osbourne mansion',
#  'Oil eases to $59, Nigeria checks fall',
#  'Air China Signs USD$1.3 Billion Airbus Deal',
#  'Ottawa surplus swells to $9.1 billion',
#  'NI firms waste Â£11m on IT finance',
#  'Microsoft offers to buy Yahoo for $44.6 bln \\\n    (AFP)\\\n',
#  "Buffett's one-day $645 million profit on Gillette",
#  'BP to pay $373 million to settle charges',
#  'Intel to start production at new $3 bln plant',
#  'Team spends $21.24 million for SkyDome',
#  'The Lede: The $94 Billion Immigration Question',
#  'Aberdeen raises $330 mln for US bond fund',
#  'Yukos may cut after $2.6B funds seized',
#  'Chechen Rebels Offer $20 Million Reward for Putin',
#  'AT&T to invest $750 mln in Internet business \\\n    (Reuters)\\\n',
#  'Flood areas get Â£8m and new rain warning',
#  'Power company NRG rejects $8 bln offer from Mirant \\\n    (Reuters)\\\n',
#  'Despite Â£1.8bn loss, MCI says it is back on track',
#  'LifePoint to Buy Rival for $1.1 Billion',
#  'Symantec faces $1 billion tax demand \\\n    (Reuters)\\\n',
#  "Energy magnate's ex wins $184M divorce verdict",
#  'Bear Stearns Told to Pay $160 Million to Investors',
#  'Hollywood Says Loses $718 Mln Due to Piracy in Asia',
#  'Nokia battery recall to cost Matsushita up to $172m',
#  'Clorox Swaps $2.1 Bln, Two Brands to Get Henkel Stake (Update3)',
#  'Crude prices rise above US$54 on supply fears',
#  'Kmart snaps up Sears for $11bn',
#  'Deal of the day: Logitech R-10 desktop speakers, $15 shipped',
#  'Oil fades to $47, awaits US stock data',
#  'Intuit iPhone-friendly Quicken priced at $3/month \\\n    (Reuters)\\\n',
#  'China online game market to hit $1.3 bln in 2007: CS \\\n    (Reuters)\\\n',
#  'Gangmaster guilty of Â£5m racket',
#  '* SCH appears to be in the clear with Â£8.55bn bid',
#  'Google&#39;s share price set at US$85',
#  'GE OKs $15 Bln Buybacks, Hikes Dividend',
#  '$2 million to save Army marriages',
#  'Cendant to acquire Orbitz for $1.25b',
#  ' NIH Scientist Pleads Guilty in Accepting $285,000 from Pfizer ',
#  'Lockheed beats Northrop to $3.9 billion NASA contract',
#  "Employee's silent rampage wipes out $2.5m worth of data",
#  "Sallie Mae's stock, preferred sales raise $3 bln",
#  'BHP Billiton to pay out $10 bln, CEO to step down \\\n    (Reuters)\\\n',
#  "TDC Asks Why City Won't Pay $600,000",
#  'French bank finds $7.14 billion fraud \\\n    (AP)\\\n',
#  'Ariad, Merck forge $75m drug-development deal',
#  'Jobs Apologizes for Iphone Price Cut, Offers $100 Credit to Early Adopters',
#  'Lead Paint Suit Fails; City Was Seeking $52.6 Million From Company for Cleanup',
#  'Price of Next Big Thing in Physics: $6.7 Billion',
#  'ConocoPhillips eyes $2B stake in LUKOIL',
#  'Rolls-Royce wins $1.3 billion contract with aircraft leasing group \\\n    (AFP)\\\n',
#  'Cisco plans to invest $12m in Japanese R&amp;D centre',
#  'FirstGroup to buy Greyhound bus firm for $2.8 bln',
#  'HP to acquire Opsware for $1.6 billion \\\n    (InfoWorld)\\\n',
#  '$591 million restored to health care for needy',
#  'Exxon can appeal $2.5bn oil fine',
#  'Classmates Online sells for $100 million',
#  'Oil Near $49 as Iraq Violence Escalates',
#  'Â£800 million takeover battle for Man Utd',
#  'Toshiba says to sell Ginza bldg for $1.4 bln',
#  'J&J agrees $25.4bn Guidant deal',
#  'Crude oil closes above $100',
#  'Boeing: $3.8 Billion Primaris Deal to Include 7E7',
#  'XM Satellite in $650 Million Deal with Pro Baseball',
#  '$100 Million and Five Tools: Mets and Beltran Discuss',
#  '2nd UPDATE: Temasek Cuts SingTel Stake; Raises S$800M',
#  '$10m more sought for Columbus Center',
#  'Tribune to pay $15 mln for inflating circulation',
#  'Singh vows $5bn loans for Kashmir',
#  'Lockheed gets $144 million deal for Pakistan F-16s \\\n    (Reuters)\\\n',
#  'First Backdating Conviction Brings Prison Term and $15 Million Fine',
#  'Modern art auction fetches $195m',
#  'Snecma and Sagem plan $6 bn merger',
#  'Spectrum Auction: The C-Block Bidding Is Over at $4.7 Billion',
#  'Get up to $500 in',
#  'BA Profits Up 35% At Â£788m',
#  'News.com Extra: Rules set for $50 million space prize',
#  'Sun trims fourth-quarter earnings by $12 million',
#  '$1,000 Sewer Hook-Up Hike',
#  'Crude retreats back below $50 mark',
#  "IHOP to Buy Applebee's for $1.9B",
#  'Kerry Says Bush Miscalculations in Iraq Cost $200 Bln (Update3)',
#  'Gates: Foundation Donates $42.6 Million To Combat Malaria',
#  'Â£15k model Vickers Valiant crashes and burns',
#  'Sony&#39;s `Resident Evil&#39; Opens at No. 1 With $23.7 Mln (Update1)',
#  'Court orders Yukos to pay $1.7 billion tax bill',
#  '$210m settlement in AOL fraud inquiry',
#  'U.S. Steel to buy Stelco for about $1.1 billion',
#  'Court Orders Vonage to Pay $58 Million in Patent Case',
#  'Brazil police hunt Â£28m art thief',
#  'Samsung in $1.1bn Thailand deal',
#  'US Airways pilots vote for pay cuts of $300m',
#  'Boeing gets $2 bln U.S. Air Force contract',
#  'Delta Amends $680 Mln Debt Exchange Offer',
#  'ITV faces Â£70m fine over phone-ins',
#  'Johnson &amp; Johnson buys Guidant for $24 billion',
#  'Bush wants another $75 billion to fund wars',
#  'Yugansk Could Be Sold for $3.75 Bln',
#  'Turner, contractor to pay $2 million in bomb scare',
#  'Sprint Has 3rd-Qtr Loss of $1.91 Billion on Network Write-Down',
#  'Verizon Wireless Will Pay $3 Billion for Additional Capacity',
#  'Oil price may top US$53 a barrel',
#  '$300 to Learn Risk of Prostate Cancer',
#  'Vodafone wins Hutch Essar, valuing it at $19 bln \\\n    (Reuters)\\\n',
#  'Factory blast firm fined Â£400,000',
#  'BCE Inc. expects $578 million from selling most of stake in <b>...</b>',
#  'Oil falls after striking record $90 a barrel',
#  'Merrill Lynch write-downs total $7.9 billion',
#  'Boston Capital hopes to raise $1b in IPO',
#  'Penn National Pays Over $2B for Argosy Gaming',
#  'Open source to hit $22 billion by 2010.  What this means for Red Hat and Novell',
#  'MBIA cuts dividend and says it will raise $1 billion',
#  'Update 4: DaimlerChrysler Posts $1.27B Net Profit',
#  'Software AG Pays $26M for Mainframe UI Tools',
#  'St George roars with $717m net',
#  'China insurers pay $165M for snow damage \\\n    (AP)\\\n',
#  "Raiders' Sapp fined $75,000",
#  'Icahn Seeks Up to $1B Temple-Inland Stock',
#  'Oil Jumps $1; IEA Warns of Supply Strains',
#  'Casino giant accepts $17bn bid',
#  'Stocks Fall As Oil Climbs Past $55 Mark',
#  'CME eyes Nymex for $11 billion',
#  '&#39;Stingy&#39; remark hits US, which adds $20m to aid',
#  'Basell to buy Lyondell for about $12.14 billion',
#  'Smithsonian head spent $250K on  jaunts',
#  'ADV: Win a $2400 Scholarship Now',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Cisco Opens S$3 Million Customer Briefing Center in Singapore',
#  'Oil Falls from Highs After Missing $50',
#  'Valassis sues to rescind $1.3 billion ADVO merger',
#  'Hyundai to build $270 mln U.S. engine plant \\\n    (Reuters)\\\n',
#  'SpaceShipOne Will Try To Claim $10M Monday',
#  'Asahi Tec to buy Metaldyne for about $1.3 billion',
#  'Samsung sets aside $100m in antitrust case',
#  'Mass. jury awards $2 million in Wal-Mart bias suit',
#  'Online sales pass the $15bn mark in the US',
#  'Carlyle lines up $8bln bid for Virgin Media: report',
#  'Microsoft bids $1.2B for Fast Search and Transfer for \\\n    (InfoWorld)\\\n',
#  'Sweden to donate $3 mln to preserve Bergman works \\\n    (Reuters)\\\n',
#  'Diageo in $900m Dutch vodka deal',
#  'Sun settles Kodak&#39;s Java suit for US$92 million',
#  'Chinese Bank Has $9 Billion in Subprime-Backed Securities',
#  'School offers Â£110,000 for a head',
#  'Obama raises $32 million in January \\\n    (AP)\\\n',
#  'Oil prices hold above $54',
#  'BEA counters Oracle offer: $21 a share sounds better',
#  ' Gunmen Grab $163m in Art at Swiss Museum ',
#  'Just Another Day in the Pit as Oil Tops $52',
#  'Wal-Mart Lowers Laptop Computer Price to Below $500',
#  "McDonald's Generated $3.9 Bln in Cash",
#  'Waste-to-energy company EnerTech raises $42 million ',
#  'PIMCO-SEC Settle Fraud Case for $50 Mln',
#  'Station Casinos agrees to be acquired by Fertitta for $90/share',
#  'Sportingbet reports a Â£241m loss',
#  'Ottawa rejects premiers&#39; demand for $36.5 billion in new health <b>...</b>',
#  'Countrywide to modify up to $16 billion of mortgages',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Intel breaks ground on $2.5 billion chip plant in China',
#  'Pakistan agrees $43bn development',
#  'Murder manhunt costs reach Â£1.5m',
#  'Crude prices top US$43 a barrel on nagging concern about heating <b>...</b>',
#  'Indian minister says IT outsourcing raked in $12.5 billion',
#  'Ford to offer up to $140,000 as buyout: UAW \\\n    (Reuters)\\\n',
#  'Ottawa provides $1.5B in loan guarantees for Bombardier',
#  'Bruins sign Alberts for 2 years, $2.5m',
#  'Family of Woman Killed in Big Dig Collapse to Get $6 Million Settlement',
#  "The Bush budget: What's in $2.9 trillion? ",
#  'Dura Automotive to sell Atwood unit for $160 mln',
#  'Lockheed gets $1 billion US deal for F-22 fighters',
#  ' Bank of America buys US Trust for $3.3bln ',
#  'House approves $447b defense bill',
#  'Shuttle Blasts Off With $2B Lab',
#  'Principles Sold For Â£140m',
#  'Go-ahead for $102bn debt swap',
#  'Australia&#39;s Challenger Reports Loss Of A$235.4M -2-',
#  'Focus DIY Is Bought Up - For Just Â£1',
#  '$1.8B Tax Cut Passed By House',
#  'Polanco, Phillies Agree to $4.6M Deal',
#  'Clear Channel delays vote on $19 bln buyout deal',
#  'Bush wants $150 billion economic package',
#  'Citi says UBS may need up to $18 billion in writedowns',
#  'Royal Bank of Scotland profit climbs to Ã\x82Â£6.2 billion \\\n    (AFP)\\\n',
#  'Women may get Â£1,000 for donating their eggs',
#  'Chavez Predicts $3B in China Trade',
#  'Oil Finishes Week Below $50 Per Barrel',
#  "Nazi victims' fund pays out Â£21m",
#  'ARI sells $115m stake in Colorado',
#  'Rod Stewart ordered to repay $780,000',
#  'Gasoline prices rise to $2.22/gallon: survey',
#  'Travel Agency Claims Courtney Love Left Them In $50,000 Hole',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Nigerian kidnappers demand $78,600 for 3-year-old',
#  'Alcan Endorses $38.1 Billion Bid From Rio Tinto',
#  'US network faces $1m nudity fine',
#  'Credit Suisse says writing down $2.85 billion \\\n    (Reuters)\\\n',
#  'Oracle to buy Hyperion for about $3 bln: NY Times \\\n    (Reuters)\\\n',
#  "Hirst's diamond skull raises Â£50m",
#  'Bulgarian Arrested in $300 Mln Drug Seizure',
#  'Mexican firm buys RMC for Â£2.3bn',
#  'Apple posts $904 million profit \\\n    (Macworld.com)\\\n',
#  'China cars start at $7,000',
#  'IRA denies $42m Belfast heist',
#  'Man Charged With Threat Over $6 Sandwich',
#  'Calif. Jury Awards $15.6M to Nestle Model',
#  'IBM saved about $1.6 billion in tax maneuver: WSJ',
#  'The $75 Billion (and Growing) Opportunity',
#  'Cracker Barrel Announces $8.7M Settlement',
#  'Teachers suspended in Â£1m probe',
#  'Ohio settles suit against Time Warner for $144 mln',
#  'MP3 Player Sales To Hit $58 billion By 2008',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Rod Stewart ordered to repay $780,000',
#  'Update 4: Crude Oil Prices Trade Below $49 a Barrel',
#  'Morgan Stanley raises $8 bln as property funds go big',
#  'AT&T Cuts 7,400 Jobs, Asset Value by $11B',
#  'Cendant near $1.2B deal to buy Orbitz',
#  'The $5m royal wedding',
#  'Marsh & McLennan to sell Putnam for $3.9 billion',
#  'Texas Democratic Senate Candidate Offers Up $10 Million \\\n    (CQPolitics.com)\\\n',
#  'United Way Giving $50,000 in Grants',
#  'Fed Auctions $30 Billion',
#  'Citigroup to raise $14.5 billion after historic loss',
#  'The fish with a Â£100/kg price on its head set to win protector',
#  'Swiss to Return to Nigeria $500 Million Linked to Abacha Regime',
#  'Intel appeals potential tax bill of $2.4 billion',
#  'City Eyes $1.3M Site for Sewer',
#  'Edwards Proposes $120B Health Deal',
#  "McDonald's to Pay $8.5 Million in Trans Fat Lawsuit",
#  '5 Stocks Under $10 for 2008',
#  'National Foods Valuation A$6.11-A$6.65/Share -2-',
#  'FDA fines Red Cross another $4.6 million \\\n    (AP)\\\n',
#  "Vodafone wins India's Hutch Essar with $11 bln bid",
#  'Wachovia to buy A.G. Edwards for $6.8 billion',
#  'Bare rear could cost ABC $1.4 million \\\n    (AP)\\\n',
#  'Mass. tech developer to be sold for $163m',
#  'ICBC to buy $5.6 billion stake in South African bank',
#  'Prisoners paid Â£2.5m compensation',
#  'AFC to Sell Cinnabon for $30.25 Million',
#  "Fannie Mae's Ex-CEO May Get $1.37 Mln-A-Yr Pension",
#  "Kenexa for pay $115m for Waltham's BrassRing",
#  'Covad sells to private equity firm for $304 million',
#  'Molson, Coors to Pay C$381 Million to Sweeten Merger (Update3)',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'Update 2: Gambro to Pay $350M to Settle Fraud Case',
#  'Oil Prices Hold Firm Near $47',
#  'Pfizer, Alcoa, Verizon, Intel are cut; oil back near $43',
#  'Credit Suisse Writes Off $2.85 Billion',
#  'Sony Agrees to Buy MGM for Nearly $5 Bln',
#  'Unlimited mobile music for Â£1.99 a week',
#  'Anna hit by Â£46m ruling',
#  'Oil prices fall below $43 in fourth day of selling',
#  'PS3 Nike shoes for $5,000',
#  'ADV: $175,000 Mortgage for Under $730/Month',
#  'Rio Tinto says gets OK for $38 billion Alcan offer \\\n    (Reuters)\\\n',
#  'Scrushy to Pay HealthSouth $31 Million',
#  'Nasdaq bids $3.7 bln for Nordic bourse group OMX \\\n    (Reuters)\\\n',
#  'AT&T to spend $750 mln on global network in 2007',
#  'Kraft Offers $7.2 Billion for Groupe Danoneâ\x80\x99s Biscuit Business',
#  'Oil Holds Near $47',
#  '$10m prize for super genetic test',
#  'Chinese tax change could raise bill for foreign firms by $5.5 billion',
#  'Record $48M stolen from Belfast bank',
#  'Play FarCry, Earn $300K',
#  'Palestinians Seek $5.6 Billion in Aid',
#  "'$100 laptop' production begins",
#  'AIG to Pay $126 Mln to Settle SEC Charges',
#  'Oil barrels toward $50',
#  '^ $3.0 million team option',
#  'UPDATE: Singapore&#39;s StarHub Prices IPO At S$0.95 A Share',
#  'Group offers $50,000 for proof of Bush service',
#  'Lankan reconstruction would cost $1 billion',
#  'US Trade Deficit Surges to $54B',
#  'Update 23: Crude Prices Stay Above $50 Per Barrel',
#  'Oil steady under $70, trade muted on U.S. holiday',
#  'US RESPONSE: $35 million just a start, Powell tells critics',
#  "'$100 laptop' production begins",
#  "Â£800m 'has not cut drop-out rate'",
#  'Basell to buy Lyondell for almost $13 billion',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  'ICL fined Â£400,000 over factory explosion',
#  'FBR Agrees to Buy Lender for $88 Million',
#  'Hot deal: Razer DeathAdder gaming mouse, $46',
#  'Goldman Sachs chairman gets a bonus of $53.4 million',
#  'Update 7: Oil Prices Sink Below $50 a Barrel',
#  'Target to pay $1m in item price suit',
#  'UPDATE 1-Hicks Muse pays $194 mln for ConAgra&#39;s Swift stake',
#  'Microsoft quarterly revenue hits $9.1 billion',
#  'Eurocopter Cougars to Cost $150 Mln to Bulgaria - Report',
#  'Gold Fields plans $3.5 bn asset sale',
#  'NFL ROUNDUP: Arbitrator: Retired Williams owes Dolphins $8.6 <b>...</b>',
#  'Â£500m plan to boost school sport',
#  'How to Turn $1,000 Into $1 Million',
#  'Xstrata makes $5.8B bid for WMC',
#  'With Oil Near $50 a Barrel, Gas Prices Start to Inch Up',
#  'Russia Offers $10 Million for Chechen Rebels -Agencies',
#  'Danone in talks on $7.2 bln biscuit sale to Kraft',
#  'iMac for $499',
#  'Oil down $2 after foiled aircraft plot \\\n    (Reuters)\\\n',
#  'Toshiba to buy 77 pct of Westinghouse for $4.2 bln',
#  'ADV: $150,000 Mortgage for Under $690/Month',
#  ...]

# %%
score_pattern = r"\b\d+\s?[-–]\s?\d+\b"
titles_by_regex(titles_with_numbers, score_pattern)
# Out:
# Total matches: 501
# ['Wells Leads Grizzlies Past Spurs 93-90 (AP)',
#  'Thai 2004 growth forecast cut to 6.0-6.5 percent as Q2 growth slows (AFP)',
#  "Beltran's blast in 16th lifts Mets 9-8 \\\n    (AP)\\\n",
#  'Bills Overpower Browns, 37-7 (AP)',
#  'Colorado (3-0) At Missouri (2-1)',
#  'Webber Leads Kings Past Clippers, 89-83 (AP)',
#  'Knuble nets 2 as Flyers beat Caps 6-4 \\\n    (AP)\\\n',
#  'VfB Stuttgart 3-0 Benfica: FT Report',
#  "Packers lead Eagles 3-0 on Rayner's FG \\\n    (AP)\\\n",
#  'Juventus stretches Serie A lead while Roma and Inter play to 3-3 <b>...</b>',
#  'US, Brazil tied 0-0 in gold medal match',
#  'Patriots, Now a Perfect 16-0, Go For 19',
#  'Redskins Tied, 3-3',
#  'Dodgers Lead Cardinals 1-0 After One',
#  'Miami Upsets No. 22 Maryland, 75-73 (OT) (AP)',
#  'Man Utd 2-0 Arsenal: FT Report',
#  'Erat lifts Predators past Flyers 3-2 \\\n    (AP)\\\n',
#  'Washington St. tops No. 18 Gonzaga 77-67 \\\n    (AP)\\\n',
#  'Rick Majerus Named USC Men&#39;s Basketball Coach For 2005-06 Season',
#  'Pena Homers Give Reds 6-5 Edge Over Cubs (AP)',
#  'Clippers Edge Heat, 114-112 (2OT) (AP)',
#  'Arsenal held to 1-1 tie by West Brom',
#  'Bills Beat Dolphins, 42-32 (AP)',
#  'Arrington out 2-4 weeks',
#  'Ching Scores Late Goal To Give National Team 1-1 Tie',
#  'Royals rip Yankees for 17-8 win',
#  'Stanford rolls to 43-3 football win',
#  'Brazil beats U.S. 4-2 in exhibition \\\n    (AP)\\\n',
#  'France rallies to beat Spain 3-1 \\\n    (AP)\\\n',
#  'Hansbrough powers top-ranked UNC to 14-0 \\\n    (AP)\\\n',
#  'Pinegar TD Pass Drives Fresno to 37-34 Win Vs. Virginia',
#  'Cubs Walk Past Pirates 1-0 (AP)',
#  'Tampa Bay beats Flyers 5-2 \\\n    (AP)\\\n',
#  "Viewer's Guide: Perseid Meteor Shower Peaks Aug. 11-12 (SPACE.com)",
#  'Celtics Beat Magic 117-101 to End Skid (AP)',
#  'No. 1 Illini Wear Down Georgetown 74-59 (AP)',
#  'Hawaii Defeats Alabama-Birmingham 59-40 (AP)',
#  'UPDATE 1-Chaotic Real Madrid lose 1-0 at Espanyol',
#  'French insurer AGF plans 1,500-2,000 layoffs: report',
#  'Andrei Kastsitsyn gets three points as Belarus upsets the US 5-3',
#  'Magic Beats SuperSonics 105-87 to End Skid (AP)',
#  'Czech Republic Crushes Sweden 6-1 (AP)',
#  'Rangers Defeat Athletics 5-3 (AP)',
#  'Aston Villa Beats Tottenham 1-0, Moves to Fifth in Premiership',
#  'Live - France 9-17 Argentina',
#  'Russia Beats U.S. 3-1 in Worlds (AP)',
#  'United States beats England 3-0 \\\n    (AP)\\\n',
#  'Patriots buzz bumbling Bills 29-6',
#  'Knicks Get Rare 94-93 Home Win Over Jazz (AP)',
#  'Celtics Take Down Hawks 106-94',
#  'Spurs Pummel Trail Blazers, 114-80',
#  'Japan says PM Abe to visit China, S.Korea Oct 8-9 \\\n    (Reuters)\\\n',
#  'Jets: Injured shoulder KO&#39;s Pennington 2-4 weeks',
#  'Red Sox Feeling Heat of 0-2 Start in ALCS',
#  'Braves Beat Astros 4-2 to Even NL Playoff Series (Update1)',
#  'Colts need late magic to beat Jets 31-28 \\\n    (AP)\\\n',
#  'Bank of England voted 9-0 for steady rates',
#  'U.S. Beats Australia, 5-0',
#  'Newcastle United Extends Unbeaten Run With 1-1 Draw at Charlton',
#  "Blue Jays Ruffle Yankees' Feathers, 6-4 (AP)",
#  'No. 23 Bruins win city battle, 62-61',
#  'Political Islam takes center stage since 9-11',
#  'Pavano Homers As Marlins Beat Padres 8-3 (AP)',
#  'Man United Beats Birmingham 2-0 (AP)',
#  'Los Angeles Galaxy routs Chivas USA 3-0 \\\n    (AP)\\\n',
#  'Official: Iran 3-8 Years from Nukes',
#  'UPDATE 1-Manchester United held 0-0 by Everton',
#  'Braves Beat Astros 4-2 to Even Series',
#  'Packers take 7-0 lead after one quarter',
#  'BoSox Lead Yankees 2-1 After Two Innings',
#  'Encarnacion Leads Marlins Over Rockies 4-3 (AP)',
#  'Yanks Beat Twins 8-4 to Take Playoff Lead',
#  'No. 6 Okla. St. Routs Wash. St., 81-29 (AP)',
#  'Nebraska Tries to Forget 70-10 Flogging (AP)',
#  'Czech Republic beats Germany 7-2 for first win in World Cup <b>...</b>',
#  'Durant lead Sonics past Toronto 123-115 \\\n    (AP)\\\n',
#  'Arizona St. defeats Washington St. 67-39',
#  'Roddick Rocks Voltchkov as US Leads Belarus 2-0',
#  'North Carolina Whips Hokies 85-51',
#  "Rockies edge D'backs 3-2; lead NLCS 2-0 \\\n    (AP)\\\n",
#  "Cubs' Zambrano flirts with no-hitter but loses 1-0",
#  'Axelsson out 6-10 weeks with broken wrist',
#  'Surging Canadiens beat Sabres 5-2 \\\n    (AP)\\\n',
#  'Suns Burn SuperSonics 112-110 (AP)',
#  'No. 8 Kentucky Breezes Past LSU 89-58 (AP)',
#  'Casey and Pirates pound Brewers 14-3 \\\n    (AP)\\\n',
#  'Pistons Stop Raptors 90-86 in Overtime (AP)',
#  'Celtic defeats Dundee 3-0 to keep Scottish league record perfect',
#  'Astros Rally in Ninth to Beat Expos 5-4 (AP)',
#  'WSU beats Oregon 69-60 \\\n    (AP)\\\n',
#  'Kobe scores 42, but Shaq&#39;s Heat melts Lakers, 104-102, in OT',
#  "Suns win 92-83 to snap Hornets' streak \\\n    (AP)\\\n",
#  'Vick runs, guns, Falcons blast Bucs 14-3 \\\n    (AP)\\\n',
#  'Lakers Clobber SuperSonics 117-91 (AP)',
#  '50-50 ruling in Ryanair wheelchair case',
#  'No. 13 Michigan State Nudges Utah 56-54',
#  'Yanks Tattoo Martinez, Sox In 11-1 Rout',
#  'UPDATE 1-Bolton end Newcastle run with 2-1 win',
#  'Bears rally past tough Vikings 19-16 \\\n    (AP)\\\n',
#  'Chelsea Beats Blackburn 4-0 in Soccer&#39;s Premiership (Update1)',
#  'SuperSonics Beat Clippers, 104-99 (AP)',
#  'No. 1 LSU Beats No. 13 Minnesota, 75-67 (AP)',
#  'Pistons Hold Off Knicks 94-93 (AP)',
#  'Getzlaf lifts Ducks over Canucks 2-1 \\\n    (AP)\\\n',
#  'Brazil labors to 2-0 win over Australia \\\n    (AP)\\\n',
#  'Giants Beat Slumping Rockies 9-5 (AP)',
#  'Warriors Defeat Trail Blazers 87-84 (AP)',
#  'Live - Australia 7-0 Fiji',
#  'D-backs edge Rockies 2-1 in 18 innings \\\n    (AP)\\\n',
#  "Cowboys spoil Vince Young's debut 45-14 \\\n    (AP)\\\n",
#  'Hawks lose seesaw battle with Cowboys, 43-39',
#  'Royals Drop Devil Rays 7-6 in 10 Innings',
#  'Flames defeat Ducks 5-3 \\\n    (AP)\\\n',
#  " Howard's Petty Let Go After 5-6 Season ",
#  'Leafs roll on the road, beat Rangers 2-1',
#  'Pirates Edge Cardinals 3-2 in 10 Innings',
#  'Phillies Beat Pirates 8-4 in First of Two (AP)',
#  "Blue Jays beat A's 6-2 in 12 innings \\\n    (AP)\\\n",
#  'England 70 - 0 Canada',
#  'Rams Roll Past Redskins 28-3 (AP)',
#  'Football: Charlton 4-0 West Ham',
#  'No. 7 North Carolina Routs Lipscomb 91-45',
#  'Duke Collects 89-63 Win Over Rhode Island in Auburn Holiday <b>...</b>',
#  'Flyers top Penguins 4-3 in testy match \\\n    (AP)\\\n',
#  '(10) Wisconsin (6-0) At (5) Purdue (5-0)',
#  'N.C. State Tops Louisiana-Lafayette 78-72 (AP)',
#  'US leads 2-0 in Davis Cup',
#  'Flames defeat Hurricanes 3-0 \\\n    (AP)\\\n',
#  'Iran probably 3-8 years off nuclear bomb: IAEA',
#  'Hires, Fires And Retires: Nov. 1-5, 2004',
#  'Pistons Race Past Rockets 93-72 (AP)',
#  'No. 6 Wake Forest Beats Temple 67-64 (AP)',
#  'Oilers beat Coyotes 4-2 \\\n    (AP)\\\n',
#  'Russia ties France 1-1 in Fed Cup final',
#  'Giants Clobber Astros 5-1 (AP)',
#  'Will 7-7-07 be your lucky day? \\\n    (AP)\\\n',
#  'Manchester United 2 - 1 Olympique Lyon',
#  'UPDATE 1-Owen earns Real 1-0 win over champions Valencia',
#  'Edmonton stops Oilers, 5-0 \\\n    (AP)\\\n',
#  'Almost! Inspired Beavers throw scare in USC before falling 28-20',
#  'Australia Reaches 316-5 vs India; Kumble Gets 400th Test Wicket',
#  'Patriots finish off 19th straight team with 24-10 victory',
#  'Rams Lead Seahawks 14-10 at Halftime (AP)',
#  'Boston College Tops New Hampshire, 78-49 (AP)',
#  'Dollar slides to 1-1/2-year low vs euro',
#  'Mets Beat Braves 2-1 to Open Twinbill (AP)',
#  'SuperSonics Defeat Nuggets, 98-83 (AP)',
#  'UPDATE 2-Zoysa takes 5-26 to set up Sri Lanka win',
#  'Carter, Raptors perfect 3-0',
#  'Rangers Down D-Rays 6-2 to Sweep Series (AP)',
#  "No home base for NY City Opera in '08-09 \\\n    (AP)\\\n",
#  'No. 3 Baylor Edges No. 7 Texas 63-60 (AP)',
#  'Adriano and Vieri lead Inter to 3-1 win',
#  'Angels Hold on to Defeat Devil Rays 6-4 (AP)',
#  'W.Va. Edges No. 16 Pittsburgh, 83-78 (OT) (AP)',
#  'SEEKING ANSWERS: Japan plans Sept. 29-30 abduction talks',
#  'Royals batter Mussina, Yankees 5-0 \\\n    (AP)\\\n',
#  'Garnett leads T-Wolves over Heat 108-97',
#  'Rockets Defeat Winless Grizzlies 90-87 (AP)',
#  'NFL: Eagles Soar to 27-14 Win Over Vikings',
#  'Reds top slumping Cardinals 5-1 \\\n    (AP)\\\n',
#  '15-4 run puts New Orleans ahead to stay',
#  'Clippers Nudge Nuggets 102-98 (AP)',
#  'Pistons Prevail Over Pacers 98-93 in Peace (AP)',
#  'Warriors defeat Kings 126-113 \\\n    (AP)\\\n',
#  'Stellar Putting Gives Europe a 2 - 0 Ryder Cup Lead',
#  'Lakers Beat Rockets, 111-104 (AP)',
#  'Ford Scores 21 As Shock Tops Liberty 76-66',
#  'Nets Nip Raptors 88-86 As Kidd Returns (AP)',
#  'No. 25 Wisc. Upsets No. 12 Maryland 69-64 (AP)',
#  'Political Trivia for June 9-11 \\\n    (CQPolitics.com)\\\n',
#  'Dolphins Top Browns, 10-7',
#  'No. 16 Pittsburgh Tops Loyola, Md., 93-57',
#  'EMI slashes 1,500-2,000 jobs \\\n    (AFP)\\\n',
#  'France 25-3 Ireland',
#  'Twins wild card hopes dealt double blow in 1-0 loss',
#  ' Devils Beat Penguins, 5-4, on Asham Goal ',
#  'Finland Defeats U.S. 2-1 in World Semis (AP)',
#  'Miller, Rahlves give US Ski Team 1-2 punch in quest for overall <b>...</b>',
#  'No. 14 LSU Routs Arkansas 43-14 (AP)',
#  'ODDS STACKED AGAINST CARDS Facing a 2-0 deficit along with Pedro',
#  'Spain takes 1-0 lead in Davis Cup',
#  'No. 15 Texas Crushes Chaminade 84-62',
#  'BoSox Lead Yankees 2-1 After Three Innings',
#  'Astros Defeat Reds 9-3 (AP)',
#  'Man U 1-0 Arsenal: We&#39;re out but the kids have done us proud',
#  'Marlins Beat Brewers 5-3 in 10 Innings (AP)',
#  'Sosa Homers As Cubs Club Pirates 7-2 (AP)',
#  'Celtics Beat Wizards 108-103 (AP)',
#  'Student Spotlight, 01-20-05',
#  'Revolution play Chivas USA to 1-1 tie \\\n    (AP)\\\n',
#  'UEFA Cup champ takes Super Cup with 2-1 victory over Porto',
#  'Japan PM to visit China Dec 27-30 as support drops',
#  'Cardinals Beat Astros 6-4 to Take 2-0 Lead in NL Title Series',
#  'Arsenal Beats Manchester City 1-0 to Top Premiership (Update1)',
#  'No. 15 Va. Tech Drubs Maryland 55-6',
#  ' Bulls Fire Scott Skiles After 9-16 Start ',
#  'Padres Clobber Cardinals 7-3 (AP)',
#  'Orlovsky Leads Conn. to Trounce Toledo 39-10',
#  'Fire Beat Wizards 3-1 in MLS (AP)',
#  'Nuggets edge Rockets, 112-111 \\\n    (AP)\\\n',
#  'Newcastle Wins 4-0 at Sochaux to Advance in Soccer&#39;s UEFA Cup',
#  'Rowand Powers White Sox Past Tigers 9-2 (AP)',
#  'Football: Chelsea 1-1 Arsenal',
#  'Carroll gives Rockies 10-5 win over Nats \\\n    (AP)\\\n',
#  'Big Ben Outguns Eli As Steelers Win 33-30 (AP)',
#  'No. 2 Kansas Dodges South Carolina 64-60',
#  'Cards rout LA 8-3 in opener',
#  'Columbus Crew Ties MetroStars 1-1 (AP)',
#  'Dodgers Beat Rockies 8-6 in 10 Innings (AP)',
#  'Roma 0-1 Dynamo Kiev: FT Report',
#  '[ * 22nd Street Landing, San Pedro: 832-8304... ]',
#  'No. 4 LSU Edges Oregon State 22-21 in OT',
#  ' Athletics Embarrass Punchless Yanks 7-0 ',
#  'USA 0 - 1 Europe',
#  'Survey: 9-11 kin don&#39;t want RNC in NY',
#  'Maple Leafs hold on to top Oilers 4-3 \\\n    (AP)\\\n',
#  "NFL caves, will air Pats' 16-0 try on all TVs",
#  'Roethlisberger 7-0 As Steelers Top Browns (AP)',
#  'Wal-Mart Sees Same-Store Sales Up 1-3 Pct',
#  'U.S. Stages Fight-Back But Still Trails 8-4 at Ryder Cup',
#  'Lakers Clobber Raptors 117-99 (AP)',
#  'No. 10 Okla. State Defeats Baylor, 81-63 (AP)',
#  'Senate Panel Votes 16-2 to Recommend Rice (AP)',
#  'St. Helens Crater Floor Bulges Another 10-30 Feet Friday',
#  'Monarchs beat Sparks 72-52 in Game 1',
#  'Co. Pulls Toys Depicting 9-11 Attack (AP)',
#  'Canadiens top Panthers in 2-1 OT \\\n    (AP)\\\n',
#  "LeBron's 23 leads U.S. over China 119-73 \\\n    (AP)\\\n",
#  "U.S. Crashes 94-90 to Lithuania in Men's Basketball",
#  'UPDATE 2-Zoysa takes 5-26 to set up Sri Lanka win',
#  'Highlights from the SEW Blog: October 15-19, 2007',
#  'SuperSonics Leave Jazz Behind, 122-105 (AP)',
#  'Highlights from the SEW Blog: December 17-21, 2007',
#  'Rockets Blast Hawks 92-69 (AP)',
#  'Browns Beat Ravens 20-3 Behind Garcia: NFL Week 1 (Update1)',
#  'No. 19 N.C. State Rips New Orleans 92-58 (AP)',
#  'Phillips&#39; streak in long jump continues as US finishes 1-2',
#  'No. 9 Kentucky Edges Louisville 60-58 (AP)',
#  'Suns Power Past Lakers 107-102 (AP)',
#  'Australia Beats NZ in One-Day Cricket Match to Tie Series 1-1',
#  '49ers Alone in Last Place With 1-10 Record (AP)',
#  'Beckham scores beauty as England beats Wales 2-0 in World Cup <b>...</b>',
#  'No. 3 Auburn Dominates Georgia 24-6',
#  '2-Run Homers Lift Angels Over Twins 9-6 (AP)',
#  'Braves Beat Astros 6-5 to Force Fifth Game',
#  'Wal-Mart Still Sees Sales Up 1-3 Pct.',
#  '5-2 Irish get ready for BC',
#  ' CDC Recommends HIV Tests for All Americans 13-64 ',
#  'Viduka Goals Help Middlesbrough Beat Man. City 3-2 (Update1)',
#  'Navarro, Calderon lead Spain 92-71 \\\n    (AP)\\\n',
#  'Barron leads Rhode Island to 14-1 start \\\n    (AP)\\\n',
#  'Football: Beckham guides Eng to 2-0 win over Wales',
#  'Britain to host conference on Palestinian reform on March 1-2 (AFP)',
#  'Salt Lake draws with Revolution 0-0 \\\n    (AP)\\\n',
#  'Pepperdine Upsets No. 20 Wisconsin 75-61 (AP)',
#  'No. 16 UConn Holds Off Seton Hall 77-68 (AP)',
#  'Luciano Pavarotti 1935-2007',
#  'Bears Best Rival Packers, 21-10 (AP)',
#  'Spurs Defeat Lakers 100-83 (AP)',
#  'Kaizer Chiefs 1 - 2 Tottenham',
#  'No. 5 Duke overpowers Michigan 92-47 \\\n    (AP)\\\n',
#  'Pistons end skid, defeat Heat, 78-77',
#  'Grizzlies Rally to Stop Celtics 117-109 (AP)',
#  'Wizards Rally to Defeat Cavaliers 106-97 (AP)',
#  'Liverpool hit bottom with 2-1 defeat at Besiktas \\\n    (AFP)\\\n',
#  'Chacon leads Pirates over Braves 3-2 \\\n    (AP)\\\n',
#  'England 32 - 16 South Africa',
#  'No. 11 Florida State Holds Off N.C. State, 17-10',
#  'Lieber, Yankees Shut Down Red Sox 14-4 (AP)',
#  'Mets Thump Dodgers 9-2 (AP)',
#  'Cassell leads Clippers past Suns 97-90 \\\n    (AP)\\\n',
#  'Roddick, Blake give US 2-0 lead over Austria',
#  'United Edge Revolution 4-3 in Overtime (AP)',
#  'Lilly Leads Blue Jays Past Red Sox 3-0 (AP)',
#  'Angels Rattle Loaiza, Blast Yankees 6-1 (AP)',
#  'Nuggets Beat Pistons 117-109 to End Skid (AP)',
#  'Melrose uses a 1-2 punch to knock out Winchester',
#  'No. 2 LSU runs past Gamecocks, 28-16 \\\n    (AP)\\\n',
#  "No. 11 UConn Women Beat St. John's 60-32 (AP)",
#  "Italian government's public offer of ENEL shares to run October 18-22 (AFP)",
#  'No. 3 Kansas Steamrolls Colorado 89-60 (AP)',
#  'Steelers lead Dolphins 14-10 at half \\\n    (AP)\\\n',
#  'Heath Ledger autopsy results due in 10-14 days',
#  'Red Sox Cruise Into 2-0 Lead Over Angels',
#  '11-07: East Texans sue maker of painkiller',
#  "Cheechoo has 3 goals in Sharks' 4-3 win \\\n    (AP)\\\n",
#  ' Sky Send Lynx to 1st Ever 0-4 Start ',
#  'Yanks edge Bosox 7-5, split doubleheader \\\n    (AP)\\\n',
#  'Dodgers Beat Giants 7-3, Win NL West',
#  'Milan bloccato dalla Roma: 1-1',
#  'Australia 55-12 Fiji',
#  'No gold for US after 89-81 loss to Argentina',
#  'Fading Padres lose 9-4 to Giants \\\n    (AP)\\\n',
#  'Angels beat slumping Diamondbacks 8-2 \\\n    (AP)\\\n',
#  'Pujols rips 3-run HR, Cards top Astros 3-1 \\\n    (AP)\\\n',
#  'Kevin Davies scores as Bolton upsets Liverpool 1-0 in English <b>...</b>',
#  'UEFA Cup: Newcastle crush Sochaux 4-0',
#  'Cardinals Clip Brewers 3-2 (AP)',
#  'Czech Republic Beats Switzerland 5-2',
#  'No. 10 Ohio St. Defeats Oregon 73-58',
#  'Cards Score in Ninth to Top Reds 6-5 (AP)',
#  'Astros Defeat Braves 9-3 in Game 1 of Baseball Playoff Series',
#  'Bobcats Defeat Knicks, 107-101 (AP)',
#  'No. 1 Illinois Defeats Ohio State, 84-65 (AP)',
#  'American Who Lost Mom in 9-11 Presses FBI (AP)',
#  'The Irish fall to the Eagles, 24-23',
#  'Chelsea goes six clear with 4-0 win',
#  'Barbarians 19 - 47 New Zealand',
#  'Arsenal 2-0 West Ham',
#  'UM knocks down fumbling Purdue, 16-14',
#  'Bears lead Cowboys 3-0 in 2nd quarter \\\n    (AP)\\\n',
#  'Bengals, Colts tied 3-3 after first \\\n    (AP)\\\n',
#  'Rams Clobber Eagles 20-7',
#  'Wal-Mart Sees January Sales Up 2-4 Pct',
#  'Spurs Hold Off Mavericks 98-95 (AP)',
#  'Yankees storm back, beat Red Sox 8-7 \\\n    (AP)\\\n',
#  'England 6 - 15 South Africa',
#  'Americans Settle for 1-1 Tie With Aussies',
#  'Brunell, Redskins Shellac Dolphins 17-0 (AP)',
#  'Wolverines deny Gophers again, 27-24',
#  'Dayton defeats No. 6 Pittsburgh 80-55 \\\n    (AP)\\\n',
#  "Manning's 6 TD Passes Give Colts 41-9 Lead (AP)",
#  'Football: Fenerbahce 3-0 Man U',
#  'No. 16 Iowa rallies past Iowa St. 27-17 \\\n    (AP)\\\n',
#  'Cougars may be 1-3, but they aren&#39;t hurting from lack of exposure',
#  'Braves rally to stun Phillies 9-8 \\\n    (Reuters)\\\n',
#  'No. 16 Vanderbilt Beats BYU 86-47 (AP)',
#  'Harris, Miami Upend No. 19 Florida 72-65 (AP)',
#  'Yankees Blow Lead but Beat Twins 13-10',
#  'Marlins Stop Reeling Mets 3-0 (AP)',
#  'U.S. Women Defeat Iceland 3-0 (AP)',
#  'Romo lifts Cowboys over Bucs 38-10 \\\n    (AP)\\\n',
#  'Ghana 4-2 Ivory Coast',
#  'No. 1 UNC routs Rutgers to move to 9-0 \\\n    (AP)\\\n',
#  'Peterson, White finish 2-3 in Heisman race',
#  'Magic Edge Sixers in 115-111 Shootout (AP)',
#  'Charlotte Edges No. 18 Cincinnati, 91-90 (AP)',
#  "Ljungberg's header gives Sweden 1-0 win \\\n    (AP)\\\n",
#  'Argentina downs Mexico in extra time, 2-1 \\\n    (AP)\\\n',
#  'BoSox Lead Yankees 4-2 After Eight Innings',
#  'Pujols powers Cardinals to 5-1 win over Padres',
#  'Notre Dame Upsets No. 8 Michigan 28-20',
#  'Spain lead United State 2-0 in Davis Cup final',
#  'Young Suns Outhustle 76ers 108-98 (AP)',
#  'Colts Lead Vikings 14-6 at Halftime (AP)',
#  'A 1-2 combination',
#  'Tapit is 2-1 favorite in Pennsylvania Derby',
#  'Wake, Sox lose way: Stumble to 7-1 setback in Seattle',
#  'Manning Leads Colts Past Jaguars, 24-17 (AP)',
#  'Arsenal held 2-2 by Bolton',
#  'UPDATE 1-Werder come from behind for 2-1 away win',
#  'Yanks, BoSox Tied 4-4 After 11 Innings',
#  'Torres, Oilers beat Blue Jackets 5-2 \\\n    (AP)\\\n',
#  'UPDATE 1-Ronaldo strikes to give Real 1-1 draw at Betis',
#  'Notebook: Mashburn is out for &#39;04-05 season',
#  'Francis Pushes Magic Past Hornets 90-89 (AP)',
#  'TV Lookout: highlights for Jan. 6-12 \\\n    (AP)\\\n',
#  'Sol Campbell scores to give Arsenal 1-0 victory at Portsmouth on <b>...</b>',
#  'Favre Leads Packers Past Vikings, 34-31 (AP)',
#  'Roethlisberger moves to 4-0',
#  'Carter leads Kiwi 1-2 punch in Athens',
#  'Lidle Leads Phillies Past Marlins 4-2 (AP)',
#  'Anna Nicole Smith, 1967-2007',
#  'Guerin leads Islanders to 5-2 win over Capitals',
#  'Bhajji scripts 1-0 Test series win against Proteas:',
#  'Donyell Marshall scores 22 points as Raptors beat Jazz 98-86',
#  'Smith gets United out of jail for late 1-1 draw',
#  'Cardinals Beat Padres 4-2 (AP)',
#  'Nuggets Knock Off Hornets 76-67 (AP)',
#  'Mavs win 12th straight after 0-4 start \\\n    (AP)\\\n',
#  '34th Annual Hooters/IHRA Championship Awards Banquet Returns To Northern Kentucky, Jan., 14-15, 2005',
#  'Dream Team Breezes Past Angola 89-53',
#  "Battier's clutch 3s lift Rockets 82-75 \\\n    (AP)\\\n",
#  'Everton 1-0 Liverpool',
#  'Real Madrid held to 1-1 draw by Betis in Spanish league',
#  'Red Sox edge Rockies for 2-0 World Series lead',
#  'UPDATE 5-Kiev given 3-0 win at Roma after referee injury',
#  'Blackburn out of League Cup after 7-6 loss to Bournemouth on <b>...</b>',
#  'NATO says kills 70-80 Taliban in fierce battle',
#  'Streaky Orioles Stop Yankees 3-1 (AP)',
#  'No. 1 UCLA survives Texas A&M 65-62 \\\n    (AP)\\\n',
#  'Raptors hang on to beat Pacers 92-83 \\\n    (AP)\\\n',
#  'ID thieves have a 50-50 chance of going to prison',
#  'Houston Astros Hold on Wild Card Lead with 4-2 Win',
#  'Russians Beat NHL World Stars 5-4',
#  'Suns Defeat Trail Blazers, 117-98 (AP)',
#  'No. 7 Stanford Shuts Down Pacific 82-26 (AP)',
#  'Yanks Beat Twins 5-3 to Start Doubleheader (AP)',
#  'Streaking Rockets Defeat Clippers 96-79',
#  'At 3-0, Mora&#39;s Falcons Get Tested Sunday',
#  'Ryder Cup live - Europe 10-6 USA',
#  'Marlins Beat Cubs 7-0 in Twinbill Opener (AP)',
#  'Public Sale / Auction  5-30-2007',
#  'Redskins Trail, 17-14',
#  'Duncan Leads Spurs Past 76ers 105-72',
#  'Ponson fills in blanks in O&#39;s 7-0 win',
#  'Allen helps Celtics beat Blazers 100-90 \\\n    (AP)\\\n',
#  'Kansas Fight for 64-60 Victory Vs. South Carolina',
#  "DePaul's rally stuns No. 5 Kansas 64-57 \\\n    (AP)\\\n",
#  'Wizards Defeat Bulls, 95-88 (AP)',
#  'Heath Ledger autopsy results due in 10-14 days',
#  'Eagles Clobber Vikings 27-16',
#  'No. 17 Gonzaga Beats Santa Clara, 92-75 (AP)',
#  'Eagles Beat Ravens 26-17 but Lose Runner (AP)',
#  'Sparta Prague 1-2 Lyon: FT Report',
#  'Lady Bird Johnson, 1912-2007',
#  'USA takes 2-0 lead in Davis Cup semifinals',
#  'Ducks lead Senators 4-2 in Game 5 \\\n    (AP)\\\n',
#  ' Michigan State Makes History at 19-2 ',
#  'Greinke fans 10 as Royals top ChiSox 3-0 \\\n    (AP)\\\n',
#  'U.S. Soccer Team Fights Past Japan 2-1',
#  'Grizzlies Run Over Bobcats 109-89',
#  'My Garden Year June 16-22',
#  'Photos: Remembering Lady Bird Johnson, 1912 - 2007',
#  'Mobley, Clippers defeat Grizzlies 105-90 \\\n    (AP)\\\n',
#  'Liverpool Beats Arsenal 2-1; Spurs End Losing Run (Update3)',
#  'Wizards guard Blake out 10-12 weeks with ankle injury',
#  "Sabres' Ales Kotalik will miss 4-6 weeks \\\n    (AP)\\\n",
#  'Ireland 17-20 France',
#  'No. 17 Louisville Routs Lafayette 98-57 (AP)',
#  'Sooners upset No. 18 Gonzaga 72-68 \\\n    (AP)\\\n',
#  'Suns Burn Jazz 108-86 (AP)',
#  'Suns Top Skidding Timberwolves 122-115 (AP)',
#  'Apple releases Security Update 2004-09-30 (MacCentral)',
#  'Wallace-led Pistons stunt Dallas 90-67 \\\n    (AP)\\\n',
#  'COACHES: Bengals, Marvin Lewis (2nd season, 9-12); Broncos, Mike <b>...</b>',
#  'Clippers Defeat Cavaliers 94-82 (AP)',
#  'Texans Defeat KC 24-21 Fall to 0-3',
#  'Canadiens power past Hurricanes 7-4',
#  'Miami dominates Dallas to level NBA finals at 2-2 \\\n    (AFP)\\\n',
#  'Twins win 5-3 to sweep Tigers',
#  'Well-traveled Lions are 3-0 on the road',
#  "No. 2 Kansas Defeats St. Joseph's 91-51 (AP)",
#  "Blue Jays end Yankees' winning streak with 3-2 victory",
#  'Simon suspended 30 games; Isles lose 2-1 \\\n    (AP)\\\n',
#  'Braves Beat Astros 4-2 to Even National League Playoff Series',
#  'Soccer World Cup: US Beats Panama 6-0',
#  'Ducks stun Red Wings to seize 3-2 lead \\\n    (AP)\\\n',
#  'Yankees make 8-0 meal out of Twins \\\n    (AP)\\\n',
#  'Penny outpitches Sosa, slumping Mets 9-1 \\\n    (AP)\\\n',
#  'Rams fault QB Chandler in abysmal 31-7 loss',
#  '10-12: Hospital says flu shots expected to run out today',
#  'Heat Defeat Trail Blazers, 103-92 (AP)',
#  'Celtics Crush the Bulls 104-74',
#  'Astros Beat Braves 8-5 for NL Series Lead (AP)',
#  'Wal-Mart Sees 2-4% Sales Increase in September',
#  'Yanks Beat Twins 8-4 to Take Playoff Lead',
#  'No. 21 Purdue Defeats No. 15 DePaul 69-61 (AP)',
#  'Tynes Field Goal Sinks Raiders 31-30',
#  'Devils drub Hurricanes 4-1 \\\n    (AP)\\\n',
#  "A's finish sweep of Twins with 8-3 win \\\n    (AP)\\\n",
#  "Bonds' double enough to lift Giants 3-2 \\\n    (AP)\\\n",
#  'SuperSonics beat Clippers, 95-85 \\\n    (AP)\\\n',
#  'Wal-Mart Still Sees Nov. Sales Up 2-4 Pct',
#  'Appleby, Huskies upset No. 23 USC 85-70 \\\n    (AP)\\\n',
#  'Beckham scores beauty as England beats Wales 2-0 in World Cup <b>...</b>',
#  'Teva sees 15 drug applications from 2009-2015',
#  'Red Sox lead Indians 5-2 after 7 innings \\\n    (AP)\\\n',
#  'Seeking common ground amid 7-10 split of politics',
#  'Grizzlies Rout Clippers 96-76 (AP)',
#  'Warriors rally to defeat Rockets 112-95 \\\n    (AP)\\\n',
#  'WHO: 6,000-10,000 Die Monthly in Darfur (AP)',
#  'Red Sox homer 5 times; rout Braves 11-0 \\\n    (AP)\\\n',
#  'No. 6 Duke Rallies Past Clemson, 62-54 (AP)',
#  'Cardinals Slam Reds 7-2 (AP)',
#  "O'Neal Leads Pacers Past Nets 96-83 (AP)",
#  'Nets Nip Blazers 64-60 in Offensive Dud (AP)',
#  'Bears Defeat Giants, 28-21',
#  'Rangers Watch as 5-0 Lead Turns Into Defeat',
#  'U.S. tunes up with 4-1 win over China \\\n    (AP)\\\n',
#  'FC Dallas drops Chivas USA 2-0 \\\n    (AP)\\\n',
#  'Chelsea and Villa in 4-4 thriller',
#  'Angels Complete Sweep of Yankees, 4-3 (AP)',
#  'Hot Suns Defeat Reeling Hornets 107-96',
#  'US defeats Spain 102-94 in Olympic men&#39;s basketball quarter-final',
#  'Leap year again as Americans go 1-2 in long jump',
#  'Daniels hits late shot to left Sonics over Raptors, 88-87',
#  'Bombs in Karbala, Najaf kill 67 - 10 Iraqi employees of US company <b>...</b>',
#  'NFL: Eagles Soar to 27-14 Win Over Vikings',
#  'Paul sparks Hornets past Suns 118-113 \\\n    (AP)\\\n',
#  'Red Sox win World Series with 3-0 win Weds. to sweep St. Louis',
#  'Browns (1-0) at Cowboys (0-1)',
#  'President Ilham Aliyev is expected to visit Romania on October 11-12. ...',
#  'Bulls Hold Off Lakers 92-84',
#  'No. 15 Vanderbilt Pounds New Orleans 91-37',
#  'Football: Burnley 1-0 Liverpool',
#  'Tigers Race by Indians 11-3 (AP)',
#  'No. 10 California Routs Oregon St., 49-7 (AP)',
#  'Red Sox Lead Cards 1-0 After One Inning',
#  'Sharks slip Capitals 3-2 in shootout \\\n    (AP)\\\n',
#  'Bills get 7 sacks, thump Dolphins 16-6 \\\n    (AP)\\\n',
#  'Federal inmate 55170-054 Martha Stewart checks in',
#  'Uefa Cup: Newcastle 2 - 1 Celta Vigo  ',
#  'Henry scores two as Arsenal crushes Charlton 4-0',
#  'Beckham unable to lift Galaxy in 3-0 defeat',
#  'NFL: Tennessee Titans Crush Green Bay 48-27',
#  'No. 21 Oklahoma Drubs Akron 88-40 (AP)',
#  'UEFA Cup: Sporting gains 1-1 tie to join Newcastle in next round',
#  'Canada, US skate to 1-1 draw at Four Nations Cup',
#  'Dodgers edge Reds 6-5 in 16 innings \\\n    (AP)\\\n']

# %%
year_pattern = r"\b(19|20)\d{2}s?\b"
pct_pattern = (r"(\b\d+(\.\d+)?\s?%)"
               r"|(%\s?\d+(\.\d+)?\b)"
               r"|\b\d+(?:\.\d+)?\s?percent(?:age)?s?\b"
                r"\b\d+(?:\.\d+)?\s*[-–]\s*\d+(?:\.\d+)?\s*(?:%|percent(?:age)?s?)\b"
                r"|\b\d+(?:\.\d+)?\s*%\b"
                r"|%\s*\d+(?:\.\d+)?\b"
                r"|\b\d+(?:\.\d+)?\s*percent(?:age)?s?\b"               
)
unit_pattern = r"\b\d+(?:\.\d+)?\s?(?:GB|MB|TB|MP|kg|g|km|m|cm|mm)\b"
money_pattern = r"((\d+((\.|,)\d*)?[$€£]+)|([$€£]+\d+((\.|,)\d*)?))(M|B)*"
score_pattern = r"\b\d+\s?[-–]\s?\d+\b"
quarter_pattern = r"\b(?:[1-4]Q|Q[1-4])\b"
ord_pattern = r"\b\d+(?:st|nd|rd|th)\b"
num_pattern = r"(?<![A-Za-z])\b\d{1,3}(?:,\d{3})*(?:\.\d+)?\b(?![A-Za-z])"
iso_pattern = r"\b\d{4,5}:\d{4}\b"


replacements = [
    (iso_pattern,     "ISOTOKEN"),       # 13485:2003
    (quarter_pattern, "QUARTERTOKEN"),   # 3Q, Q4
    (score_pattern,   "SCORETOKEN"),     # 3-1
    (pct_pattern,     "PCTTOKEN"),       # 6%, %6, 6 percent, 6.0-6.5 percent
    (money_pattern,   "MONEYTOKEN"),     # €100, $100.5, 100€ (vedi nota sotto)
    (unit_pattern,    "UNITTOKEN"),      # 8GB, 80kg, 100m
    (year_pattern,    "YEARTOKEN"),      # 1990, 1990s
    (ord_pattern,     "ORDTOKEN"),       # 3rd, 10th
    (num_pattern,     "NUMTOKEN"),       # numeri standalone rimanenti
]

import unicodedata
import html

news_df["title"] = news_df["title"].astype(str).apply(html.unescape)

s = news_df['title'].astype(str)
s = s.apply(lambda x: unicodedata.normalize("NFKC", x))

for pattern, token in replacements:
    s = s.str.replace(
    pattern,
    token,
    regex=True,
    flags=re.IGNORECASE
    )
news_df['title'] = s

# %%
titles_with_numbers = news_df[news_df["title"].str.contains(r"\d", regex=True, na=False)]["title"]

len(titles_with_numbers)
# Out:
# 890

# %%
for title in titles_with_numbers[100:200]:
    print(title)
    print('='*30)
# Out:
# Cardinals Beat Astros to Force Game NUMTOKEN of NL Series (Update1)
# ==============================
# SABMiller Venture to Buy Lion Nathan's China Brewers (Update1)
# ==============================
# Seven US Soldiers Killed in Texas Helicopter Crash (Update1)
# ==============================
# G7 fails to reach debt deal
# ==============================
# Airbus sees A350 orders ahead
# ==============================
# A âPG-13â Rating, Despite the Haze
# ==============================
# Ferrari's Raikkonen storms to F1 title
# ==============================
# Bono urges G8 nations to open purses in fight against AIDS \
#     (AFP)\
#
# ==============================
# Mayer Goes Nashville for VH1 Special (AP)
# ==============================
# G7 warns markets against yen-depressing trades
# ==============================
# F1 power struggle now in session.
# ==============================
# UB40 singer Campbell quits group
# ==============================
# Samsung Forecasts Global Chip Sales to Slow Next Year (Update2)
# ==============================
# AWB to Supply AMONEYTOKEN Million of Milling Wheat to China (Update1)
# ==============================
# Eight injured in M1 coach crash
# ==============================
# Oracle Raises PeopleSoft Bid by PCTTOKEN to MONEYTOKEN Billion (Update5)
# ==============================
# Bush Is Leading Kerry in Surveys by Newsweek, Time (Update2)
# ==============================
# GSPDA M28 Palm OS Smartphone Hits Asia
# ==============================
# Siemens SF65 Mobile Phone Digital Camera
# ==============================
# UPS says to cancel order for NUMTOKEN Airbus A380s
# ==============================
# Input inflation at nearly 10yr high
# ==============================
# Myanmar releases nearly 4âNUMTOKEN prisoners
# ==============================
# UPS, last Airbus A380 freighter buyer, may cancel \
#     (Reuters)\
#
# ==============================
# Microsoft releases new XP SP3 test version
# ==============================
# Thatcher mansion on sale for R24 million
# ==============================
# FastT100 offers cost-effective, reliable storage for consolidation <b>...</b>
# ==============================
# Pick of the Day Nick Baker's Weird Creatures, Five, 8pm
# ==============================
# MP fingers O2 in overcharging rumpus
# ==============================
# Dollar Stuck Near Lows Ahead of G20 Meet (Reuters)
# ==============================
# Bush should be open for G8 climate talks: Pelosi
# ==============================
# Food, water run low at camp on 3d day of W. Bank raid
# ==============================
# E3: Few Surprises at Microsoft's Press Conference
# ==============================
# 49ers sign Ravens DT Aubrayo Franklin \
#     (AP)\
#
# ==============================
# Tenet to Settle Redding Suits With MONEYTOKEN Million Fund (Update2)
# ==============================
# F5's Integrated Approach To Web Traffic Management
# ==============================
# Dell Inspiron 6400 Core NUMTOKEN Duo laptop
# ==============================
# Russia blocking Paris Club debt relief for Iraq: G20 source
# ==============================
# Yahoo to Buy Musicmatch Web Service for MONEYTOKEN Million (Update4)
# ==============================
# Air Europa Orders Extra Boeing B737-NUMTOKEN Aircraft
# ==============================
# PS3 price cut isn't going to last?
# ==============================
# Calpers Tenders MONEYTOKEN Mln PeopleSoft Shares to Oracle (Update2)
# ==============================
# G8:  Despite Differences, Mexico Comfortable as G5 Emerging Power
# ==============================
# China defends its role in Africa ahead of G8
# ==============================
# Top Linux programmers pan GPLv3
# ==============================
# IBM Releasing New Power5-Based Servers
# ==============================
# 76ers thumbnails
# ==============================
# G7 warns markets against yen-depressing trades
# ==============================
# U2 manager takes Internet providers to task \
#     (Reuters)\
#
# ==============================
# EBay to Buy Rent.com for MONEYTOKEN Mln in Cash and Stock (Update2)
# ==============================
# QE2 set to become floating hotel
# ==============================
# New U2 Album Melodious, Without Surprises (AP)
# ==============================
# Real Madrid Hires Luxemburgo, ORDTOKEN Coach in NUMTOKEN Months (Update2)
# ==============================
# G7 warns markets against yen-depressing trades
# ==============================
# "Milk" biopic brings '70s vibe to San Francisco
# ==============================
# U2's new album will be Atomic Bomb
# ==============================
# The Nokia N81 will rock you (and your wallet)
# ==============================
# Chelsea Beats Blackburn SCORETOKEN in Soccer's Premiership (Update1)
# ==============================
# Home Users Most Vulnerable to SP2 Flaw (NewsFactor)
# ==============================
# PS3 Games: Picks and Pans
# ==============================
# Airbus gives EADS new flight plan for A380 superjumbo \
#     (AFP)\
#
# ==============================
# NHL Players Offer PCTTOKEN Pay Cut to End Lockout (Update1)
# ==============================
# AMD ships 90nm Opterons
# ==============================
# Nokia's New and Novel N800
# ==============================
# QE2 heads to luxury retirement home in Dubai
# ==============================
# Apple update boosts support for Canon 1D Mark III
# ==============================
# Sony Computer to launch worldwide sales of new PS2 console in Nov
# ==============================
# CARE Halts Iraq Operations After Director Kidnapped (Update5)
# ==============================
# H5N1 bird flu virus confirmed in England \
#     (AP)\
#
# ==============================
# mmO2 to launch speedy UNITTOKEN
# ==============================
# Britain to tackle poverty, climate change, AIDS during G8 presidency (AFP)
# ==============================
# Sainsbury to Cut Headquarter Jobs, Halve Dividend (Update2)
# ==============================
# Carroll Says He's Not Interested in 49ers (AP)
# ==============================
# Hands-on Vista SP1: Better but slower?
# ==============================
# 'More over-60s' seek debt advice
# ==============================
# Toyota, Partner to Invest MONEYTOKEN Mln in China Venture (Update2)
# ==============================
# F1: Trulli grabs Belgian pole
# ==============================
# Bush-Blair chemistry displayed for final time at G8 \
#     (Reuters)\
#
# ==============================
# Intel to make chips with 65nm process technology
# ==============================
# Latest MP3 players come equipped with songs \
#     (Reuters)\
#
# ==============================
# Israeli firm in 2bn dollar deal with Egypt-Israel gas consortium \
#     (AFP)\
#
# ==============================
# Britain aims for CO2-limit target dates \
#     (AP)\
#
# ==============================
# Alienware's 4GHz Pentium
# ==============================
# Affymetrix Gets GeneChip 3000Dx FDA OK
# ==============================
# G14 back Newcastle bid for Owen compensation \
#     (AFP)\
#
# ==============================
# Pfizer Will Stop Promoting Celebrex to Consumers (Update1)
# ==============================
# Virgin Unveils Super-Small MP3 Player; Goes After iPod mini
# ==============================
# Oil futures rise toward $US54
# ==============================
# Indonesia's Megawati Appeals for Release of Hostages (Update1)
# ==============================
# Stampeding Bills thunder past 49ers
# ==============================
# CAN GREEN COMPUTERS HELP SAVE THE WORLD? ; Computer Makers Are Waking Up to the Fact That Their Products Emit As Much CO2 As Aviation. By Nic Fildes ++ Business Analysis
# ==============================
# RIM officially announces Wi-Fi-enabled BlackBerry 8820
# ==============================
# Creative plans USMONEYTOKEN advertising campaign for its MP3 players
# ==============================
# Ukraine's Yushchenko Says Kuchma Trying to Block Vote (Update1)
# ==============================
# Cancer Test Spots Need for Chemotherapy, Study Says (Update1)
# ==============================
# China defends its role in Africa ahead of G8
# ==============================
# BlackBerry 7100t and SureType
# ==============================
# Japan's Docomo Unveils UNITTOKEN Phones with 3D Sound
# ==============================
# US sees growing importance of G20; wants to avoid dollar spat
# ==============================
# Police clash with protesters at G8
# ==============================
# Sony to boost PS3 software to reverse slump: Nikkei \
#     (Reuters)\
#
# ==============================

# %%
pct_pattern = r"[3,4,5]G"
titles = titles_by_regex(titles_with_numbers, pct_pattern)
# titles.append(titles_by_regex(titles_with_numbers, pct_pattern2))
for title in titles:
    print(title)
    print('='*30)
# Out:
# Total matches: 55
# SingTel poised to launch first 3G service in Southeast Asia (AFP)
# ==============================
# Huawei wins 3G contract from Telfort
# ==============================
# Take a Look at Proven Strategies for 3G & Broadband Mobile Data Services & Applications
# ==============================
# Vodafone 'looking into' 3G femtocells
# ==============================
# Euro iPhone launch will reveal 3G handset for Vodafone, T-Mobile
# ==============================
# Vodafone enters 3G battle against Hutchison
# ==============================
# Panasonic Unveils International 3G Cell Phone
# ==============================
# T-Mobile USA to set up nationwide 3G network \
#     (FT.com)\
#
# ==============================
# 3G kicks off in Norway
# ==============================
# mmO2 to launch speedy 3G
# ==============================
# Alienware's 4GHz Pentium
# ==============================
# Japan's Docomo Unveils 3G Phones with 3D Sound
# ==============================
# DoCoMo and Motorola seal 3G deal
# ==============================
# Orange readies a 3G Christmas
# ==============================
# Business jets get inflight 3G
# ==============================
# HTC Touch Smart Phone Goes 3G
# ==============================
# Orange 3G phones launched in UK
# ==============================
# Japan to build 3G capacity in China
# ==============================
# Motorola, DoCoMo to make 3G phones for business use
# ==============================
# Nokia says row with Qualcomm may hurt 3G uptake \
#     (Reuters)\
#
# ==============================
# U.K. to test improved indoor 3G coverage by year-end
# ==============================
# 3GSM World Congress
# ==============================
# Report: DoCoMo, Cingular to link on 3G technology
# ==============================
# Orange Unveils 3G Phones in Long-Delayed Launch
# ==============================
# LG Unveils iPhone-Like 3G Handset
# ==============================
# Voda plays Santa with 3G bonanza
# ==============================
# Nokia says patent dispute hurts 3G
# ==============================
# Cingular Tips Hand On Wireless Broadband, 3G Plans
# ==============================
# Taiwan's Chunghwa Telecom targets MONEYTOKEN million 3G users by end-YEARTOKEN \
#     (AFP)\
#
# ==============================
# Vodafone unleashes 3G live! service
# ==============================
# SK Telecom previews file sharing for 3G phones
# ==============================
# QUALCOMM Demonstrates Its HSPA, Mobile TV and Position Location Solutions for the Global Mobile Market at 3GSM World Congress YEARTOKEN
# ==============================
# NTT DoCoMo 3G network hit by problems \
#     (InfoWorld)\
#
# ==============================
# NTT DoCoMo's 4G research hits 1Gbps
# ==============================
# Cellcom Chooses RADCOM RANalysis to Optimize the Service Quality of Its 3G Cellular Network
# ==============================
# WordPress boosts free blog storage to 3GB
# ==============================
# China remains mum on 3G
# ==============================
# Cambodia gets 3G but videophone banned to stop porn \
#     (AFP)\
#
# ==============================
# Intel's Ultra Mobile PC Gets 3G Capability \
#     (PC World)\
#
# ==============================
# Chinese 3G may follow Europe
# ==============================
# Vodafone misses out on lucky 3G phone
# ==============================
# Japan's NTT DoCoMo to fund AT&T 3G network in Hawaii
# ==============================
# Operators upgrading 3G networks
# ==============================
# Fuel cell's got the power for 3G handsets
# ==============================
# DoCoMo Hits 1 Gbps Wireless Data Speeds In 4G Tests
# ==============================
# Traffic jam slows down 3G wireless communications
# ==============================
# New 3G technology trial aims to bring broadband to rural areas in Nordic...
# ==============================
# Virgin unveils 5GB mini music player
# ==============================
# Texas Instruments OMAP(TM) 2 Platform Powers Latest NEC 3G FOMA(R) Phone
# ==============================
# Nokia delivers 3G network expansion to MTC in Bahrain (AFP)
# ==============================
# Motorola, DoCoMo to make 3G phones for businesses
# ==============================
# Vodafone launches own-brand low-cost 3G mobile handsets \
#     (AFP)\
#
# ==============================
# Vodafone rings in changes with launch of 3G handsets
# ==============================
# Mobile players look beyond 3G
# ==============================
# Vodafone Targets 10 Million 3G Wireless Users by YEARTOKEN (Update2)
# ==============================

# %%
import pandas as pd
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import csr_matrix, hstack
import unicodedata
import html

from src.config import *


class Preprocessor2:
    
    def __init__(self):
        self.df = None
        self.is_fit = False
        self.vectorizer = None
        self.ohe = None
        self.top_50 = None

    def timestamp_management(self):
        # 1) Parse timestamp: treat invalid placeholders as missing (NaT)
        ts = self.df["timestamp"].replace("0000-00-00 00:00:00", pd.NA)
        ts = pd.to_datetime(ts, errors="coerce")  # invalid -> NaT
        self.df["timestamp"] = ts

        # 2) Missingness flag (important!)
        self.df["timestamp_missing"] = self.df["timestamp"].isna().astype(int)

        # 3) Create time features ONLY where timestamp is valid
        valid = self.df["timestamp"].notna()

        # is_weekend: keep as 0/1; set to 0 for missing (or leave NaN if you prefer)
        self.df["is_weekend"] = 0
        self.df.loc[valid, "is_weekend"] = (
            self.df.loc[valid, "timestamp"].dt.day_of_week.isin([5, 6]).astype(int)
        )

        # hour sin/cos
        self.df["hour_sin"] = 0.0
        self.df["hour_cos"] = 0.0
        h = self.df.loc[valid, "timestamp"].dt.hour.astype(float)
        self.df.loc[valid, "hour_sin"] = np.sin(2 * np.pi * h / 24)
        self.df.loc[valid, "hour_cos"] = np.cos(2 * np.pi * h / 24)

        # month sin/cos
        self.df["month_sin"] = 0.0
        self.df["month_cos"] = 0.0
        m = self.df.loc[valid, "timestamp"].dt.month.astype(float)
        self.df.loc[valid, "month_sin"] = np.sin(2 * np.pi * m / 12)
        self.df.loc[valid, "month_cos"] = np.cos(2 * np.pi * m / 12)

        # year (numeric): set to -1 for missing (or keep NaN)
        self.df["year"] = -1
        self.df.loc[valid, "year"] = self.df.loc[valid, "timestamp"].dt.year.astype(int)

    def pagerank_manegement(self):
        self.df['page_rank'] = self.df['page_rank'].map({2:0, 3:0, 4:1, 5:2})

    def na_management(self): 
        null_title_idx = self.df[self.df['title'].isna()].index 
        self.df.drop(null_title_idx, inplace=True)

    @staticmethod
    def clean_number(s):
        year_pattern = r"\b(19|20)\d{2}s?\b"
        pct_pattern = (r"(\b\d+(\.\d+)?\s?%)"
                    r"|(%\s?\d+(\.\d+)?\b)"
                    r"|\b\d+(?:\.\d+)?\s?percent(?:age)?s?\b"
                        r"\b\d+(?:\.\d+)?\s*[-–]\s*\d+(?:\.\d+)?\s*(?:%|percent(?:age)?s?)\b"
                        r"|\b\d+(?:\.\d+)?\s*%\b"
                        r"|%\s*\d+(?:\.\d+)?\b"
                        r"|\b\d+(?:\.\d+)?\s*percent(?:age)?s?\b"               
        )
        unit_pattern = r"\b\d+(?:\.\d+)?\s?(?:GB|MB|TB|MP|kg|g|km|m|cm|mm)\b"
        money_pattern = r"((\d+((\.|,)\d*)?[$€£]+)|([$€£]+\d+((\.|,)\d*)?))(M|B)*"
        score_pattern = r"\b\d+\s?[-–]\s?\d+\b"
        quarter_pattern = r"\b(?:[1-4]Q|Q[1-4])\b"
        ord_pattern = r"\b\d+(?:st|nd|rd|th)\b"
        num_pattern = r"(?<![A-Za-z])\b\d{1,3}(?:,\d{3})*(?:\.\d+)?\b(?![A-Za-z])"
        iso_pattern = r"\b\d{4,5}:\d{4}\b"

        replacements = [
            (iso_pattern,     "ISOTOKEN"),       # 13485:2003
            (quarter_pattern, "QUARTERTOKEN"),   # 3Q, Q4
            (score_pattern,   "SCORETOKEN"),     # 3-1
            (pct_pattern,     "PCTTOKEN"),       # 6%, %6, 6 percent, 6.0-6.5 percent
            (money_pattern,   "MONEYTOKEN"),     # €100, $100.5, 100€ (vedi nota sotto)
            (unit_pattern,    "UNITTOKEN"),      # 8GB, 80kg, 100m
            (year_pattern,    "YEARTOKEN"),      # 1990, 1990s
            (ord_pattern,     "ORDTOKEN"),       # 3rd, 10th
            (num_pattern,     "NUMTOKEN"),       # numeri standalone rimanenti
        ]
        for pattern, token in replacements:
            s = s.str.replace(
            pattern,
            token,
            regex=True,
            flags=re.IGNORECASE
            )
        return s
    
    @staticmethod
    def clean_text(s):
        s = s.apply(html.unescape)
        s = s.apply(lambda x: unicodedata.normalize("NFKC", x))
        return s

    def title_management(self):
        self.df["title"] = Preprocessor2.clean_text(self.df['title'])
        self.df['title'] = Preprocessor2.clean_number(self.df['title'])

        titles = self.df["title"].fillna("")

        if self.is_fit:
            KEEP_2CHAR = {
                "uk","us","eu","un","ny","nj","nh","la","tv","ip","xp","hp","hq",
                "f1","g7","g8","u2","vw","gm","bp","ft","cd"
            }
            keep2 = "|".join(sorted(KEEP_2CHAR))
            token_pattern = rf"(?u)\b(?!\d+\b)(?:[A-Za-z]{{3,}}|(?:{keep2})|[A-Za-z]\w+)\b"

            self.vectorizer = TfidfVectorizer(stop_words="english", token_pattern=token_pattern, min_df=10, ngram_range=(1,3), sublinear_tf=True, strip_accents="unicode")
            return  self.vectorizer.fit_transform(titles), self.vectorizer.get_feature_names_out()
        else:
            return self.vectorizer.transform(titles)

    def source_management(self):
        df = self.df["source"].fillna("MISSING")

        if self.is_fit:
            self.top_50 = df.value_counts()[:50].index.to_list()
            self.ohe = OneHotEncoder(categories=[self.top_50], handle_unknown="ignore", sparse_output=True)
            X = df.where(df.isin(self.top_50), np.nan).to_frame()
            X_ohe = self.ohe.fit_transform(X)
        else:
            X = df.where(df.isin(self.top_50), np.nan).to_frame()
            X_ohe = self.ohe.transform(X)
        
        return X_ohe

    def full_prep(self,df):
        self.df = df
        self.na_management()
        self.timestamp_management()
        X_ohe = self.source_management()
        tfidf_matrix = self.title_management()
        output = self.df.copy()
        idxs = output.index
        self.df = None


        output.drop(columns=COLUMNS_TO_DROP, inplace=True, errors='ignore')
        output = csr_matrix(output.to_numpy(dtype=np.float32))
        X = hstack([tfidf_matrix, X_ohe, output], format="csr")
        return X, idxs


    def fit_transform(self, df):
        self.is_fit = True
        return self.full_prep(df)

    def transform(self, df):
        if self.vectorizer is None or self.ohe is None or self.top_50 is None:
            raise RuntimeError("Preprocessor.fit_transform called before fit.")
        
        self.is_fit = False
        return self.full_prep(df)

# %%
prep2 = Preprocessor2()
prep2.is_fit = True

prep2.df = news_df
prep2.na_management()
prep2.timestamp_management()
tfidf_matrix, feat = prep2.title_management()

# %%
for f in feat:
    if any(ch.isdigit() for ch in f):
        print(f)
# Out:
# a380
# co2
# f1
# g7
# g8
# mp3
# p2p
# ps3
# sp2
# u2
# update1
# update2
# update3
# update4
# update5
# xp sp2
